# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with data digit images only.
# The best model will be stored as "dig-s1-md-best.h5"
#
#
# ## The Model
#
# Used a the jomjol CNN-S1 network as small model.

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 400                     # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
input_shape = (32, 20,1)            # will be calculated
Batch_Size = 16
use_grayscale = False                # grayscale or rgb
output_dir = "output/" 
output_tmp_dir = "output/tmp/"
model_filename = "dig-class100-s2"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *
from datetime import datetime

date_time = datetime.now().strftime("%Y%m%d-%H%M%S")


try:
    # Disable all GPUS
    tf.config.set_visible_devices([], 'GPU')
    visible_devices = tf.config.get_visible_devices()
    for device in visible_devices:
        assert device.device_type != 'GPU'
except:
    # Invalid device or cannot modify virtual devices once initialized.
    pass

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
# ### Train and Test data
#
# For 1st train the digit meter will be used.
#
# ### digit meter spread
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images', input_shape=input_shape)

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
x_train, x_test, y_train, y_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)
print(xz_train[0].shape)
input_shape=xz_train[2].shape
print(input_shape)
print(f"dataset x_train-size={len(xz_train)}")
plot_dataset(xz_train, yz_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)
# Out:
# Ziffer data count:  18254
# (32, 20, 1)
# (32, 20, 1)
# dataset x_train-size=18254

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train, preprocessing_function=None)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet
from b2n.models.cnn32 import *
from keras import backend as K

print (input_shape)
#def accuracy(y_true, y_pred):
#    return K.mean(K.less_equal(K.abs((K.abs(K.argmax(y_true))- K.abs(K.argmax(y_pred)))), 1 ))


model = CNN_s2(input_shape, nb_classes, activation_top=None)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer=tf.optimizers.Adam(learning_rate=1e-3), metrics = ["accuracy"])

model.summary()
# Out:
# (32, 20, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 32, 20, 1)        4
#  ormalization)
#
#  conv2d (Conv2D)             (None, 32, 20, 32)        320
#
#  batch_normalization_1 (Batc  (None, 32, 20, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 10, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 10, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 10, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 10, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 5, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 5, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 8, 5, 64)         256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 213,416
# Trainable params: 213,094
# Non-trainable params: 322
# _________________________________________________________________

# %% [markdown]
# ### The Training
#
# Standard training of the model with complete dataset.
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

#annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=25, verbose=1,  restore_best_weights=True)
mc = ModelCheckpoint(output_tmp_dir + model_filename + '_best.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, initial_value_threshold=.9)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.85, patience=3, min_lr=1e-5, verbose=1)
history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[earlystop, mc, reduce_lr],
                verbose=1)


#model.save(model_filename + '.h5')

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/400
# 2023-01-08 14:52:34.539341: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 456/457 [============================>.] - ETA: 0s - loss: 4.4200 - accuracy: 0.0524
# Epoch 1: val_loss did not improve from 0.90000
# 457/457 [==============================] - 6s 13ms/step - loss: 4.4172 - accuracy: 0.0527 - val_loss: 3.8742 - val_accuracy: 0.1468 - lr: 0.0010
# Epoch 2/400
# 454/457 [============================>.] - ETA: 0s - loss: 2.4871 - accuracy: 0.3232
# Epoch 2: val_loss did not improve from 0.90000
# 457/457 [==============================] - 6s 12ms/step - loss: 2.4833 - accuracy: 0.3239 - val_loss: 1.3557 - val_accuracy: 0.6127 - lr: 0.0010
# Epoch 3/400
# 455/457 [============================>.] - ETA: 0s - loss: 1.5431 - accuracy: 0.5181
# Epoch 3: val_loss improved from 0.90000 to 0.88822, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 6s 13ms/step - loss: 1.5432 - accuracy: 0.5180 - val_loss: 0.8882 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 4/400
# 454/457 [============================>.] - ETA: 0s - loss: 1.2352 - accuracy: 0.5925
# Epoch 4: val_loss improved from 0.88822 to 0.76803, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 6s 13ms/step - loss: 1.2348 - accuracy: 0.5924 - val_loss: 0.7680 - val_accuracy: 0.7338 - lr: 0.0010
# Epoch 5/400
# 457/457 [==============================] - ETA: 0s - loss: 1.0645 - accuracy: 0.6441
# Epoch 5: val_loss improved from 0.76803 to 0.71868, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 6s 14ms/step - loss: 1.0645 - accuracy: 0.6441 - val_loss: 0.7187 - val_accuracy: 0.7491 - lr: 0.0010
# Epoch 6/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.9597 - accuracy: 0.6686
# Epoch 6: val_loss improved from 0.71868 to 0.63811, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 6s 14ms/step - loss: 0.9590 - accuracy: 0.6690 - val_loss: 0.6381 - val_accuracy: 0.7669 - lr: 0.0010
# Epoch 7/400
# 457/457 [==============================] - ETA: 0s - loss: 0.8833 - accuracy: 0.6912
# Epoch 7: val_loss improved from 0.63811 to 0.58579, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 6s 14ms/step - loss: 0.8833 - accuracy: 0.6912 - val_loss: 0.5858 - val_accuracy: 0.7839 - lr: 0.0010
# Epoch 8/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.8453 - accuracy: 0.7017
# Epoch 8: val_loss improved from 0.58579 to 0.53553, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 6s 14ms/step - loss: 0.8452 - accuracy: 0.7016 - val_loss: 0.5355 - val_accuracy: 0.7987 - lr: 0.0010
# Epoch 9/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.7897 - accuracy: 0.7202
# Epoch 9: val_loss did not improve from 0.53553
# 457/457 [==============================] - 6s 14ms/step - loss: 0.7895 - accuracy: 0.7202 - val_loss: 0.5459 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 10/400
# 457/457 [==============================] - ETA: 0s - loss: 0.7596 - accuracy: 0.7274
# Epoch 10: val_loss improved from 0.53553 to 0.53378, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 14ms/step - loss: 0.7596 - accuracy: 0.7274 - val_loss: 0.5338 - val_accuracy: 0.8074 - lr: 0.0010
# Epoch 11/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.7438 - accuracy: 0.7327
# Epoch 11: val_loss did not improve from 0.53378
# 457/457 [==============================] - 7s 15ms/step - loss: 0.7447 - accuracy: 0.7323 - val_loss: 0.5428 - val_accuracy: 0.7965 - lr: 0.0010
# Epoch 12/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.7190 - accuracy: 0.7379
# Epoch 12: val_loss improved from 0.53378 to 0.52291, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.7189 - accuracy: 0.7375 - val_loss: 0.5229 - val_accuracy: 0.8066 - lr: 0.0010
# Epoch 13/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.7421
# Epoch 13: val_loss improved from 0.52291 to 0.49426, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 16ms/step - loss: 0.7085 - accuracy: 0.7418 - val_loss: 0.4943 - val_accuracy: 0.8085 - lr: 0.0010
# Epoch 14/400
# 457/457 [==============================] - ETA: 0s - loss: 0.6968 - accuracy: 0.7501
# Epoch 14: val_loss did not improve from 0.49426
# 457/457 [==============================] - 7s 16ms/step - loss: 0.6968 - accuracy: 0.7501 - val_loss: 0.5114 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 15/400
# 457/457 [==============================] - ETA: 0s - loss: 0.6779 - accuracy: 0.7520
# Epoch 15: val_loss did not improve from 0.49426
# 457/457 [==============================] - 7s 16ms/step - loss: 0.6779 - accuracy: 0.7520 - val_loss: 0.5164 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 16/400
# 457/457 [==============================] - ETA: 0s - loss: 0.6398 - accuracy: 0.7657
# Epoch 16: val_loss did not improve from 0.49426
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
# 457/457 [==============================] - 7s 16ms/step - loss: 0.6398 - accuracy: 0.7657 - val_loss: 0.5381 - val_accuracy: 0.7990 - lr: 0.0010
# Epoch 17/400
# 457/457 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.7697
# Epoch 17: val_loss improved from 0.49426 to 0.46313, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 16ms/step - loss: 0.6263 - accuracy: 0.7697 - val_loss: 0.4631 - val_accuracy: 0.8340 - lr: 8.5000e-04
# Epoch 18/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.6020 - accuracy: 0.7775
# Epoch 18: val_loss did not improve from 0.46313
# 457/457 [==============================] - 7s 16ms/step - loss: 0.6015 - accuracy: 0.7774 - val_loss: 0.4897 - val_accuracy: 0.8129 - lr: 8.5000e-04
# Epoch 19/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.5921 - accuracy: 0.7844
# Epoch 19: val_loss improved from 0.46313 to 0.45675, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5919 - accuracy: 0.7845 - val_loss: 0.4568 - val_accuracy: 0.8266 - lr: 8.5000e-04
# Epoch 20/400
# 457/457 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.7822
# Epoch 20: val_loss improved from 0.45675 to 0.44805, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5838 - accuracy: 0.7822 - val_loss: 0.4480 - val_accuracy: 0.8329 - lr: 8.5000e-04
# Epoch 21/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.5846 - accuracy: 0.7872
# Epoch 21: val_loss did not improve from 0.44805
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5854 - accuracy: 0.7868 - val_loss: 0.4547 - val_accuracy: 0.8321 - lr: 8.5000e-04
# Epoch 22/400
# 457/457 [==============================] - ETA: 0s - loss: 0.5680 - accuracy: 0.7883
# Epoch 22: val_loss did not improve from 0.44805
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5680 - accuracy: 0.7883 - val_loss: 0.4794 - val_accuracy: 0.8263 - lr: 8.5000e-04
# Epoch 23/400
# 457/457 [==============================] - ETA: 0s - loss: 0.5603 - accuracy: 0.7930
# Epoch 23: val_loss did not improve from 0.44805
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0007225000590551645.
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5603 - accuracy: 0.7930 - val_loss: 0.4498 - val_accuracy: 0.8324 - lr: 8.5000e-04
# Epoch 24/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.5534 - accuracy: 0.7952
# Epoch 24: val_loss improved from 0.44805 to 0.43345, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5551 - accuracy: 0.7948 - val_loss: 0.4335 - val_accuracy: 0.8389 - lr: 7.2250e-04
# Epoch 25/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.5355 - accuracy: 0.8020
# Epoch 25: val_loss improved from 0.43345 to 0.43343, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5354 - accuracy: 0.8019 - val_loss: 0.4334 - val_accuracy: 0.8395 - lr: 7.2250e-04
# Epoch 26/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.5296 - accuracy: 0.8009
# Epoch 26: val_loss improved from 0.43343 to 0.42969, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.5289 - accuracy: 0.8011 - val_loss: 0.4297 - val_accuracy: 0.8389 - lr: 7.2250e-04
# Epoch 27/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.5225 - accuracy: 0.8035
# Epoch 27: val_loss improved from 0.42969 to 0.42778, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 16ms/step - loss: 0.5221 - accuracy: 0.8037 - val_loss: 0.4278 - val_accuracy: 0.8400 - lr: 7.2250e-04
# Epoch 28/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.5116 - accuracy: 0.8043
# Epoch 28: val_loss did not improve from 0.42778
# 457/457 [==============================] - 8s 16ms/step - loss: 0.5119 - accuracy: 0.8042 - val_loss: 0.4350 - val_accuracy: 0.8370 - lr: 7.2250e-04
# Epoch 29/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4917 - accuracy: 0.8121
# Epoch 29: val_loss improved from 0.42778 to 0.41588, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 15ms/step - loss: 0.4920 - accuracy: 0.8120 - val_loss: 0.4159 - val_accuracy: 0.8447 - lr: 7.2250e-04
# Epoch 30/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.5069 - accuracy: 0.8106
# Epoch 30: val_loss did not improve from 0.41588
# 457/457 [==============================] - 7s 16ms/step - loss: 0.5073 - accuracy: 0.8103 - val_loss: 0.4249 - val_accuracy: 0.8455 - lr: 7.2250e-04
# Epoch 31/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4919 - accuracy: 0.8139
# Epoch 31: val_loss improved from 0.41588 to 0.41475, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4917 - accuracy: 0.8138 - val_loss: 0.4147 - val_accuracy: 0.8463 - lr: 7.2250e-04
# Epoch 32/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4970 - accuracy: 0.8083
# Epoch 32: val_loss did not improve from 0.41475
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4970 - accuracy: 0.8083 - val_loss: 0.4217 - val_accuracy: 0.8433 - lr: 7.2250e-04
# Epoch 33/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4935 - accuracy: 0.8116
# Epoch 33: val_loss did not improve from 0.41475
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4936 - accuracy: 0.8116 - val_loss: 0.4163 - val_accuracy: 0.8379 - lr: 7.2250e-04
# Epoch 34/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.4912 - accuracy: 0.8126
# Epoch 34: val_loss did not improve from 0.41475
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0006141250254586339.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4909 - accuracy: 0.8126 - val_loss: 0.4223 - val_accuracy: 0.8387 - lr: 7.2250e-04
# Epoch 35/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.4733 - accuracy: 0.8222
# Epoch 35: val_loss improved from 0.41475 to 0.39657, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4730 - accuracy: 0.8223 - val_loss: 0.3966 - val_accuracy: 0.8535 - lr: 6.1413e-04
# Epoch 36/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4623 - accuracy: 0.8248
# Epoch 36: val_loss did not improve from 0.39657
# 457/457 [==============================] - 8s 16ms/step - loss: 0.4631 - accuracy: 0.8246 - val_loss: 0.4387 - val_accuracy: 0.8329 - lr: 6.1413e-04
# Epoch 37/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.4643 - accuracy: 0.8247
# Epoch 37: val_loss improved from 0.39657 to 0.39523, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4639 - accuracy: 0.8249 - val_loss: 0.3952 - val_accuracy: 0.8565 - lr: 6.1413e-04
# Epoch 38/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.4656 - accuracy: 0.8246
# Epoch 38: val_loss did not improve from 0.39523
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4653 - accuracy: 0.8246 - val_loss: 0.4206 - val_accuracy: 0.8444 - lr: 6.1413e-04
# Epoch 39/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.8323
# Epoch 39: val_loss did not improve from 0.39523
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4522 - accuracy: 0.8323 - val_loss: 0.4417 - val_accuracy: 0.8337 - lr: 6.1413e-04
# Epoch 40/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4571 - accuracy: 0.8294
# Epoch 40: val_loss did not improve from 0.39523
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005220062914304435.
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4571 - accuracy: 0.8294 - val_loss: 0.4206 - val_accuracy: 0.8381 - lr: 6.1413e-04
# Epoch 41/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4464 - accuracy: 0.8318
# Epoch 41: val_loss did not improve from 0.39523
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4460 - accuracy: 0.8318 - val_loss: 0.4273 - val_accuracy: 0.8387 - lr: 5.2201e-04
# Epoch 42/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.8368
# Epoch 42: val_loss did not improve from 0.39523
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4366 - accuracy: 0.8368 - val_loss: 0.4000 - val_accuracy: 0.8529 - lr: 5.2201e-04
# Epoch 43/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4337 - accuracy: 0.8330
# Epoch 43: val_loss improved from 0.39523 to 0.38662, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4337 - accuracy: 0.8330 - val_loss: 0.3866 - val_accuracy: 0.8576 - lr: 5.2201e-04
# Epoch 44/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.4317 - accuracy: 0.8374
# Epoch 44: val_loss did not improve from 0.38662
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4333 - accuracy: 0.8367 - val_loss: 0.3948 - val_accuracy: 0.8507 - lr: 5.2201e-04
# Epoch 45/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.8374
# Epoch 45: val_loss did not improve from 0.38662
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4255 - accuracy: 0.8374 - val_loss: 0.4051 - val_accuracy: 0.8447 - lr: 5.2201e-04
# Epoch 46/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.4218 - accuracy: 0.8419
# Epoch 46: val_loss did not improve from 0.38662
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
# 457/457 [==============================] - 7s 16ms/step - loss: 0.4217 - accuracy: 0.8420 - val_loss: 0.4030 - val_accuracy: 0.8499 - lr: 5.2201e-04
# Epoch 47/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4176 - accuracy: 0.8414
# Epoch 47: val_loss did not improve from 0.38662
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4172 - accuracy: 0.8416 - val_loss: 0.3910 - val_accuracy: 0.8502 - lr: 4.4371e-04
# Epoch 48/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.4159 - accuracy: 0.8410
# Epoch 48: val_loss did not improve from 0.38662
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4156 - accuracy: 0.8411 - val_loss: 0.3876 - val_accuracy: 0.8568 - lr: 4.4371e-04
# Epoch 49/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.4133 - accuracy: 0.8439
# Epoch 49: val_loss did not improve from 0.38662
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4129 - accuracy: 0.8441 - val_loss: 0.4013 - val_accuracy: 0.8474 - lr: 4.4371e-04
# Epoch 50/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.4026 - accuracy: 0.8434
# Epoch 50: val_loss did not improve from 0.38662
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4035 - accuracy: 0.8433 - val_loss: 0.3889 - val_accuracy: 0.8568 - lr: 3.7715e-04
# Epoch 51/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8458
# Epoch 51: val_loss did not improve from 0.38662
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4059 - accuracy: 0.8458 - val_loss: 0.4042 - val_accuracy: 0.8565 - lr: 3.7715e-04
# Epoch 52/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.4039 - accuracy: 0.8447
# Epoch 52: val_loss improved from 0.38662 to 0.37654, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4042 - accuracy: 0.8446 - val_loss: 0.3765 - val_accuracy: 0.8631 - lr: 3.7715e-04
# Epoch 53/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3990 - accuracy: 0.8480
# Epoch 53: val_loss did not improve from 0.37654
# 457/457 [==============================] - 7s 16ms/step - loss: 0.3990 - accuracy: 0.8480 - val_loss: 0.3966 - val_accuracy: 0.8513 - lr: 3.7715e-04
# Epoch 54/400
# 457/457 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.8452
# Epoch 54: val_loss did not improve from 0.37654
# 457/457 [==============================] - 8s 17ms/step - loss: 0.4023 - accuracy: 0.8452 - val_loss: 0.3789 - val_accuracy: 0.8576 - lr: 3.7715e-04
# Epoch 55/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3956 - accuracy: 0.8471
# Epoch 55: val_loss did not improve from 0.37654
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0003205771208740771.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3956 - accuracy: 0.8471 - val_loss: 0.3837 - val_accuracy: 0.8568 - lr: 3.7715e-04
# Epoch 56/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3903 - accuracy: 0.8488
# Epoch 56: val_loss did not improve from 0.37654
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3903 - accuracy: 0.8488 - val_loss: 0.3840 - val_accuracy: 0.8584 - lr: 3.2058e-04
# Epoch 57/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3799 - accuracy: 0.8540
# Epoch 57: val_loss improved from 0.37654 to 0.37459, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3799 - accuracy: 0.8540 - val_loss: 0.3746 - val_accuracy: 0.8595 - lr: 3.2058e-04
# Epoch 58/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3779 - accuracy: 0.8550
# Epoch 58: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3775 - accuracy: 0.8550 - val_loss: 0.3762 - val_accuracy: 0.8606 - lr: 3.2058e-04
# Epoch 59/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3808 - accuracy: 0.8542
# Epoch 59: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3808 - accuracy: 0.8541 - val_loss: 0.4050 - val_accuracy: 0.8526 - lr: 3.2058e-04
# Epoch 60/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3802 - accuracy: 0.8537
# Epoch 60: val_loss did not improve from 0.37459
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002724905527429655.
# 457/457 [==============================] - 7s 16ms/step - loss: 0.3806 - accuracy: 0.8535 - val_loss: 0.3831 - val_accuracy: 0.8581 - lr: 3.2058e-04
# Epoch 61/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3773 - accuracy: 0.8548
# Epoch 61: val_loss did not improve from 0.37459
# 457/457 [==============================] - 7s 16ms/step - loss: 0.3768 - accuracy: 0.8550 - val_loss: 0.3879 - val_accuracy: 0.8570 - lr: 2.7249e-04
# Epoch 62/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3735 - accuracy: 0.8571
# Epoch 62: val_loss did not improve from 0.37459
# 457/457 [==============================] - 7s 16ms/step - loss: 0.3732 - accuracy: 0.8573 - val_loss: 0.3748 - val_accuracy: 0.8639 - lr: 2.7249e-04
# Epoch 63/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.8572
# Epoch 63: val_loss did not improve from 0.37459
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.00023161696735769509.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3721 - accuracy: 0.8572 - val_loss: 0.3780 - val_accuracy: 0.8565 - lr: 2.7249e-04
# Epoch 64/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8593
# Epoch 64: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3700 - accuracy: 0.8593 - val_loss: 0.3834 - val_accuracy: 0.8581 - lr: 2.3162e-04
# Epoch 65/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.8589
# Epoch 65: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3654 - accuracy: 0.8589 - val_loss: 0.3835 - val_accuracy: 0.8551 - lr: 2.3162e-04
# Epoch 66/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3725 - accuracy: 0.8557
# Epoch 66: val_loss did not improve from 0.37459
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.00019687442472786642.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3723 - accuracy: 0.8557 - val_loss: 0.3864 - val_accuracy: 0.8551 - lr: 2.3162e-04
# Epoch 67/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3565 - accuracy: 0.8617
# Epoch 67: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3565 - accuracy: 0.8617 - val_loss: 0.3909 - val_accuracy: 0.8532 - lr: 1.9687e-04
# Epoch 68/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3614 - accuracy: 0.8613
# Epoch 68: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3617 - accuracy: 0.8610 - val_loss: 0.3806 - val_accuracy: 0.8592 - lr: 1.9687e-04
# Epoch 69/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.8615
# Epoch 69: val_loss did not improve from 0.37459
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.00016734325545257888.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3494 - accuracy: 0.8615 - val_loss: 0.3867 - val_accuracy: 0.8546 - lr: 1.9687e-04
# Epoch 70/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3623 - accuracy: 0.8597
# Epoch 70: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3624 - accuracy: 0.8596 - val_loss: 0.3840 - val_accuracy: 0.8576 - lr: 1.6734e-04
# Epoch 71/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3515 - accuracy: 0.8668
# Epoch 71: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3517 - accuracy: 0.8667 - val_loss: 0.3865 - val_accuracy: 0.8554 - lr: 1.6734e-04
# Epoch 72/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3517 - accuracy: 0.8627
# Epoch 72: val_loss did not improve from 0.37459
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.00014224176775314845.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3518 - accuracy: 0.8628 - val_loss: 0.3826 - val_accuracy: 0.8603 - lr: 1.6734e-04
# Epoch 73/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3421 - accuracy: 0.8687
# Epoch 73: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3424 - accuracy: 0.8686 - val_loss: 0.3959 - val_accuracy: 0.8559 - lr: 1.4224e-04
# Epoch 74/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3499 - accuracy: 0.8677
# Epoch 74: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3500 - accuracy: 0.8678 - val_loss: 0.3834 - val_accuracy: 0.8595 - lr: 1.4224e-04
# Epoch 75/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3532 - accuracy: 0.8638
# Epoch 75: val_loss did not improve from 0.37459
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.00012090550444554538.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3534 - accuracy: 0.8637 - val_loss: 0.3859 - val_accuracy: 0.8589 - lr: 1.4224e-04
# Epoch 76/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3523 - accuracy: 0.8648
# Epoch 76: val_loss did not improve from 0.37459
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3523 - accuracy: 0.8648 - val_loss: 0.3863 - val_accuracy: 0.8543 - lr: 1.2091e-04
# Epoch 77/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8678
# Epoch 77: val_loss improved from 0.37459 to 0.37380, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3437 - accuracy: 0.8678 - val_loss: 0.3738 - val_accuracy: 0.8639 - lr: 1.2091e-04
# Epoch 78/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3418 - accuracy: 0.8673
# Epoch 78: val_loss did not improve from 0.37380
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3426 - accuracy: 0.8670 - val_loss: 0.3873 - val_accuracy: 0.8581 - lr: 1.2091e-04
# Epoch 79/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3431 - accuracy: 0.8677
# Epoch 79: val_loss did not improve from 0.37380
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3430 - accuracy: 0.8677 - val_loss: 0.3799 - val_accuracy: 0.8625 - lr: 1.2091e-04
# Epoch 80/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.8689
# Epoch 80: val_loss did not improve from 0.37380
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 0.00010276967877871357.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3414 - accuracy: 0.8689 - val_loss: 0.3810 - val_accuracy: 0.8606 - lr: 1.2091e-04
# Epoch 81/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3436 - accuracy: 0.8690
# Epoch 81: val_loss did not improve from 0.37380
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3439 - accuracy: 0.8689 - val_loss: 0.3799 - val_accuracy: 0.8587 - lr: 1.0277e-04
# Epoch 82/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3437 - accuracy: 0.8660
# Epoch 82: val_loss did not improve from 0.37380
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3432 - accuracy: 0.8661 - val_loss: 0.3807 - val_accuracy: 0.8609 - lr: 1.0277e-04
# Epoch 83/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3412 - accuracy: 0.8673
# Epoch 83: val_loss did not improve from 0.37380
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 8.735422634345013e-05.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3415 - accuracy: 0.8670 - val_loss: 0.3793 - val_accuracy: 0.8578 - lr: 1.0277e-04
# Epoch 84/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3295 - accuracy: 0.8712
# Epoch 84: val_loss did not improve from 0.37380
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3294 - accuracy: 0.8712 - val_loss: 0.3772 - val_accuracy: 0.8609 - lr: 8.7354e-05
# Epoch 85/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3382 - accuracy: 0.8699
# Epoch 85: val_loss improved from 0.37380 to 0.36912, saving model to output/tmp/dig-class100-s2_best.h5
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3381 - accuracy: 0.8699 - val_loss: 0.3691 - val_accuracy: 0.8650 - lr: 8.7354e-05
# Epoch 86/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3283 - accuracy: 0.8737
# Epoch 86: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3281 - accuracy: 0.8737 - val_loss: 0.3794 - val_accuracy: 0.8584 - lr: 8.7354e-05
# Epoch 87/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3401 - accuracy: 0.8669
# Epoch 87: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3402 - accuracy: 0.8668 - val_loss: 0.3789 - val_accuracy: 0.8609 - lr: 8.7354e-05
# Epoch 88/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3378 - accuracy: 0.8670
# Epoch 88: val_loss did not improve from 0.36912
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 7.425108960887882e-05.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3380 - accuracy: 0.8669 - val_loss: 0.3774 - val_accuracy: 0.8595 - lr: 8.7354e-05
# Epoch 89/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.8699
# Epoch 89: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3360 - accuracy: 0.8699 - val_loss: 0.3842 - val_accuracy: 0.8573 - lr: 7.4251e-05
# Epoch 90/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3379 - accuracy: 0.8692
# Epoch 90: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3380 - accuracy: 0.8693 - val_loss: 0.3803 - val_accuracy: 0.8633 - lr: 7.4251e-05
# Epoch 91/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3253 - accuracy: 0.8750
# Epoch 91: val_loss did not improve from 0.36912
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 6.31134258583188e-05.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3251 - accuracy: 0.8750 - val_loss: 0.3779 - val_accuracy: 0.8609 - lr: 7.4251e-05
# Epoch 92/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3314 - accuracy: 0.8735
# Epoch 92: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3317 - accuracy: 0.8735 - val_loss: 0.3789 - val_accuracy: 0.8603 - lr: 6.3113e-05
# Epoch 93/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8670
# Epoch 93: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3402 - accuracy: 0.8671 - val_loss: 0.3809 - val_accuracy: 0.8581 - lr: 6.3113e-05
# Epoch 94/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3281 - accuracy: 0.8725
# Epoch 94: val_loss did not improve from 0.36912
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 5.364641074265819e-05.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3277 - accuracy: 0.8727 - val_loss: 0.3740 - val_accuracy: 0.8636 - lr: 6.3113e-05
# Epoch 95/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3300 - accuracy: 0.8712
# Epoch 95: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3296 - accuracy: 0.8713 - val_loss: 0.3761 - val_accuracy: 0.8655 - lr: 5.3646e-05
# Epoch 96/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3323 - accuracy: 0.8681
# Epoch 96: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3322 - accuracy: 0.8681 - val_loss: 0.3732 - val_accuracy: 0.8655 - lr: 5.3646e-05
# Epoch 97/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3263 - accuracy: 0.8717
# Epoch 97: val_loss did not improve from 0.36912
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 4.559944882203126e-05.
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3263 - accuracy: 0.8717 - val_loss: 0.3821 - val_accuracy: 0.8600 - lr: 5.3646e-05
# Epoch 98/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3263 - accuracy: 0.8749
# Epoch 98: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3266 - accuracy: 0.8748 - val_loss: 0.3805 - val_accuracy: 0.8592 - lr: 4.5599e-05
# Epoch 99/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3253 - accuracy: 0.8750
# Epoch 99: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3256 - accuracy: 0.8748 - val_loss: 0.3789 - val_accuracy: 0.8598 - lr: 4.5599e-05
# Epoch 100/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3291 - accuracy: 0.8708
# Epoch 100: val_loss did not improve from 0.36912
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 3.875953134411247e-05.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3282 - accuracy: 0.8711 - val_loss: 0.3794 - val_accuracy: 0.8598 - lr: 4.5599e-05
# Epoch 101/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3256 - accuracy: 0.8724
# Epoch 101: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3254 - accuracy: 0.8726 - val_loss: 0.3801 - val_accuracy: 0.8606 - lr: 3.8760e-05
# Epoch 102/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.8719
# Epoch 102: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3322 - accuracy: 0.8719 - val_loss: 0.3790 - val_accuracy: 0.8609 - lr: 3.8760e-05
# Epoch 103/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3254 - accuracy: 0.8744
# Epoch 103: val_loss did not improve from 0.36912
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 3.29456021063379e-05.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3258 - accuracy: 0.8743 - val_loss: 0.3764 - val_accuracy: 0.8622 - lr: 3.8760e-05
# Epoch 104/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3205 - accuracy: 0.8757
# Epoch 104: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3205 - accuracy: 0.8758 - val_loss: 0.3766 - val_accuracy: 0.8620 - lr: 3.2946e-05
# Epoch 105/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3238 - accuracy: 0.8771
# Epoch 105: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3236 - accuracy: 0.8771 - val_loss: 0.3780 - val_accuracy: 0.8603 - lr: 3.2946e-05
# Epoch 106/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3242 - accuracy: 0.8735
# Epoch 106: val_loss did not improve from 0.36912
#
# Epoch 106: ReduceLROnPlateau reducing learning rate to 2.8003761326544917e-05.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3243 - accuracy: 0.8737 - val_loss: 0.3771 - val_accuracy: 0.8620 - lr: 3.2946e-05
# Epoch 107/400
# 457/457 [==============================] - ETA: 0s - loss: 0.3286 - accuracy: 0.8745
# Epoch 107: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3286 - accuracy: 0.8745 - val_loss: 0.3766 - val_accuracy: 0.8631 - lr: 2.8004e-05
# Epoch 108/400
# 455/457 [============================>.] - ETA: 0s - loss: 0.3210 - accuracy: 0.8746
# Epoch 108: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 17ms/step - loss: 0.3220 - accuracy: 0.8743 - val_loss: 0.3747 - val_accuracy: 0.8639 - lr: 2.8004e-05
# Epoch 109/400
# 456/457 [============================>.] - ETA: 0s - loss: 0.3167 - accuracy: 0.8781
# Epoch 109: val_loss did not improve from 0.36912
#
# Epoch 109: ReduceLROnPlateau reducing learning rate to 2.3803197746019577e-05.
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3166 - accuracy: 0.8782 - val_loss: 0.3767 - val_accuracy: 0.8617 - lr: 2.8004e-05
# Epoch 110/400
# 454/457 [============================>.] - ETA: 0s - loss: 0.3251 - accuracy: 0.8797Restoring model weights from the end of the best epoch: 85.
#
# Epoch 110: val_loss did not improve from 0.36912
# 457/457 [==============================] - 8s 18ms/step - loss: 0.3258 - accuracy: 0.8795 - val_loss: 0.3765 - val_accuracy: 0.8617 - lr: 2.3803e-05
# Epoch 110: early stopping

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation. The first false predicted will be shown in the diagram.

# %%
model = keras.models.load_model(output_tmp_dir + model_filename + '_best.h5')
false_predicted_files = predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data, 
                                            max_delta=0.11)
fpf = pd.DataFrame(false_predicted_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeterdigits --labelfile=output/tmp/dig-class100-s2_false_predicted.csv
fpf.to_csv(output_tmp_dir + model_filename + '_false_predicted.csv')
# Out:
# Tested images: 18254. 72 false predicted. Accuracy is: 0.9960556590336365

# %%
from dataclasses import dataclass
from b2n.models.prune_quantize import prune, quantization_default
from  tensorflow import keras

# prune the model
model_pruned = model
# pruning reduces the accurracy 
#model_pruned = prune(model=model, x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test)

# quanitize and save the model
tflite_model = quantization_default(model=model_pruned, 
                            x_train=x_test)
# save the model
filename=output_dir + model_filename + "_" + date_time + "_q.tflite"                                                     
open( filename, "wb").write(tflite_model)
# Out:
# 2023-01-08 15:06:33.735625: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqi6vgk9q/assets
# 2023-01-08 15:06:39.676144: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-01-08 15:06:39.676158: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 2023-01-08 15:06:39.676618: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqi6vgk9q
# 2023-01-08 15:06:39.678989: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-01-08 15:06:39.678995: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqi6vgk9q
# 2023-01-08 15:06:39.688213: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-01-08 15:06:39.752811: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqi6vgk9q
# 2023-01-08 15:06:39.774275: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 97658 microseconds.
# 2023-01-08 15:06:39.803935: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:237] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpzzb30ogz/assets
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpzzb30ogz/assets
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.9/site-packages/tensorflow/lite/python/convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2023-01-08 15:06:46.208658: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-01-08 15:06:46.208682: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# 2023-01-08 15:06:46.208770: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpzzb30ogz
# 2023-01-08 15:06:46.211084: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-01-08 15:06:46.211091: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpzzb30ogz
# 2023-01-08 15:06:46.219312: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-01-08 15:06:46.282858: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpzzb30ogz
# 2023-01-08 15:06:46.303642: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 94871 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: 0, output_inference_type: 0
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 225824
