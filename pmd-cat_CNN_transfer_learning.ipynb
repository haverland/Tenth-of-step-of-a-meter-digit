# %% [markdown]
# #### The CNN21 model
#
# Using effent because it should later run on edge AI device.

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 400                      # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "cnn32"

##########################################################################

# %% [markdown]
# ### Class Encoding
#
# To ensure the values are enumerated from 0.0 - 9.9 in categorical and can be used in the C++ code later with argmax() / 10.0, encoding and decoding functions will be used.

# %%
from tensorflow import keras
import math
import numpy as np

def class_encoding(y_train, nb_classes):
    '''like to_categorical.
        y_train must be an array
        nb_classes for the class count, if not all values in y_train
    '''
    ret = np.zeros((len(y_train), nb_classes))
    for i, y in enumerate(y_train):
        ret[i, int((y*10))] = 1
    return ret

def class_decoding(y_train, nb_classes=100):
    ''' from_categorical like function. It returns a float value between 0.0 and 9.9
        y_train the encoded values in an array
        nb_classes should be ignored. will not used
    '''
    ret = np.zeros((len(y_train), 1))
    for i, y in enumerate(y_train):
        ret[i] = (np.argmax(y))/10
    return ret

# %% [markdown]
# #### Augmentation functions
#
# The augmentation of train data uses
# * width shift
# * no height shift
# * random brightness
# * random rotation
# * rgb channel shift
# * random shear
# * random invert of the images
# * random spot light (led reflections)
# * random noising
#
# So the font dataset looks more like a meter digit and the augmentation prevents overfitting.

# %%
import numpy as np
from scipy.stats import norm
import cv2
import random
from keras.preprocessing.image import ImageDataGenerator
import random

def add_noise(img):
    '''Add random noise to an image'''
    VARIABILITY = 3
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img


## https://medium.com/@fanzongshaoxing/adjust-local-brightness-for-image-augmentation-8111c001059b
def generate_spot_light_mask(mask_size,
                             position=None,
                             max_brightness=255,
                             min_brightness=0,
                             mode="gaussian",
                             linear_decay_rate=None,
                             speedup=False):
    """
    Generate decayed light mask generated by spot light given position, direction. Multiple spotlights are accepted.
    Args:
        mask_size: tuple of integers (w, h) defining generated mask size
        position: list of tuple of integers (x, y) defining the center of spotlight light position,
                  which is the reference point during rotating
        max_brightness: integer that max brightness in the mask
        min_brightness: integer that min brightness in the mask
        mode: the way that brightness decay from max to min: linear or gaussian
        linear_decay_rate: only valid in linear_static mode. Suggested value is within [0.2, 2]
        speedup: use `shrinkage then expansion` strategy to speed up vale calculation
    Return:
        light_mask: ndarray in float type consisting value from max_brightness to min_brightness. If in 'linear' mode
                    minimum value could be smaller than given min_brightness.
    """
    if position is None:
        position = [(random.randint(0, mask_size[0]), random.randint(0, mask_size[1]))]
    if linear_decay_rate is None:
        if mode == "linear_static":
            linear_decay_rate = random.uniform(0.25, 1)
    assert mode in ["linear", "gaussian"], \
        "mode must be linear_dynamic, linear_static or gaussian"
    mask = np.zeros(shape=(mask_size[1], mask_size[0]), dtype=np.float32)
    if mode == "gaussian":
        mu = np.sqrt(mask.shape[0]**2+mask.shape[1]**2)
        dev = mu / 3.5
        mask = _decay_value_radically_norm_in_matrix(mask_size, position, max_brightness, min_brightness, dev)
    mask = np.asarray(mask, dtype=np.uint8)
    # add median blur
    mask = cv2.medianBlur(mask, 5)
    mask = 255 - mask
    # cv2.imshow("mask", mask)
    # cv2.waitKey(0)
    return mask

def _decay_value_radically_norm_in_matrix(mask_size, centers, max_value, min_value, dev):
    """
    _decay_value_radically_norm function in matrix format
    """
    center_prob = norm.pdf(0, 0, dev)
    x_value_rate = np.zeros((mask_size[1], mask_size[0]))
    for center in centers:
        coord_x = np.arange(mask_size[0])
        coord_y = np.arange(mask_size[1])
        xv, yv = np.meshgrid(coord_x, coord_y)
        dist_x = xv - center[0]
        dist_y = yv - center[1]
        dist = np.sqrt(np.power(dist_x, 2) + np.power(dist_y, 2))
        x_value_rate += norm.pdf(dist, 0, dev) / center_prob
    mask = x_value_rate * (max_value - min_value) + min_value
    mask[mask > 255] = 255
    return mask



def add_spot_light(image, light_position=None, max_brightness=255, min_brightness=0,
                   mode='gaussian', linear_decay_rate=None, transparency=None):
    """
    Add mask generated from spot light to given image
    """
    if transparency is None:
        transparency = random.uniform(0.2, 0.75)
    frame = image
    height, width, _ = frame.shape
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    mask = generate_spot_light_mask(mask_size=(width, height),
                                    position=light_position,
                                    max_brightness=max_brightness,
                                    min_brightness=min_brightness,
                                    mode=mode,
                                    linear_decay_rate=linear_decay_rate)
    hsv[:, :, 2] = hsv[:, :, 2] * transparency + mask * (1 - transparency)
    frame = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    frame[frame > 255] = 255
    frame = np.asarray(frame, dtype=np.uint8)
    return frame



def invert(imagem):
    if (random.getrandbits(1)):
        return (255)-imagem
    else:
        return imagem

def blur(img):
    k = random.randint(0,3)
    if (k>0):
        return (cv2.blur(img,(3,3)))
    else:
        return img

def preprocessing(img):
    #if (random.getrandbits(1)):
    #    img = blur(img)
    if (random.getrandbits(1)):
        img = add_spot_light(img).astype(np.float32)
    img = invert(img)
    img = add_noise(img)
    
    return img



Width_Shift_Range = 3 # px
Height_Shift_Range = 0 # px
Brightness_Range = [0.4,1.2]
Rotation_Angle = 5
ZoomRange_Out = 0.1
ZoomRange_In = 0.1
ShearRange= 3
Channel_Shift=0.4


def augmentation(x, y, Batch_Size = 32):
    datagen = ImageDataGenerator(width_shift_range=Width_Shift_Range, 
                             height_shift_range=Height_Shift_Range,
                             brightness_range=Brightness_Range,
                             #zoom_range=[1-ZoomRange_In, 1+ZoomRange_Out],
                             rotation_range=Rotation_Angle,
                             channel_shift_range=Channel_Shift,
                             fill_mode='nearest',
                             shear_range=ShearRange
                             ,preprocessing_function=preprocessing
                             ,dtype=float)
    #datagen.fit(x)
    return datagen.flow(x, y, batch_size=Batch_Size)
    
def no_augmentation(x, y, Batch_Size = 32):
    datagen = ImageDataGenerator(dtype=float)
    return datagen.flow(x, y, batch_size=Batch_Size)

# %% [markdown]
# #### Plot functions
#
# Various plot functions for image plottings and loss/accuracy plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def plot_dataset(images, labels, columns=10, rows=5, figsize=(18, 10)):

    fig = plt.figure(figsize=figsize)
    
    for i in range(1, columns*rows +1):
        if (i>len(labels)):
            break
        fig.add_subplot(rows, columns, i)
        plt.title(labels[i-1])  # set title
        plt.xticks([0.2, 0.4, 0.6, 0.8])
        plt.imshow((images[i-1]).astype(np.uint8), aspect='1.6', extent=[0, 1, 0, 1])
        # yellow lines
        for y in np.arange(0.2, 0.8, 0.2):
            plt.axhline(y=y,color='yellow')
        ax=plt.gca()
        ax.get_xaxis().set_visible(False) 
        plt.tight_layout()
    plt.show()

def plot_dataset_it(data_iter, columns=9, rows=5):

    fig = plt.figure(figsize=(18, 11))
    
    for i in range(1, columns*rows +1):
        img, label = data_iter.next()
        fig.add_subplot(rows, columns, i)
        plt.xticks([0.2, 0.4, 0.6, 0.8])
        plt.title(str(class_decoding(label[0].reshape(-1, nb_classes), nb_classes).reshape(-1)[0]))  # set title
        plt.imshow(img[0].astype(np.uint8), aspect='1.6', extent=[0, 1, 0, 1])
        ax=plt.gca()
        ax.get_xaxis().set_visible(False) 
        # yellow lines
        for y in np.arange(0.2, 0.8, 0.2):
                plt.axhline(y=y,color='yellow')
    plt.show()

def plot_acc_loss(history, modelname="modelname"):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.suptitle(modelname)
    fig.set_figwidth(15)

    if "loss" in history.history:
        ax1.plot(history.history['loss'])
    if "accuracy" in history.history:
        ax2.plot(history.history['accuracy'])
    if "val_loss" in history.history:
        ax1.plot(history.history['val_loss'])
    if "val_accuracy" in history.history:
        ax2.plot(history.history['val_accuracy'])
    if "student_loss" in history.history:
        ax1.plot(history.history['student_loss'])
    if "sparse_categorical_accuracy" in history.history:
        ax2.plot(history.history['sparse_categorical_accuracy'])
    if "val_sparse_categorical_accuracy" in history.history:
        ax2.plot(history.history['val_sparse_categorical_accuracy'])
    if "student_accuracy" in history.history:
        ax2.plot(history.history['student_accuracy'])
    if "val_student_accuracy" in history.history:
        ax2.plot(history.history['val_student_accuracy'])
    if "distillation_loss" in history.history:
        ax1.plot(history.history['distillation_loss'])

    ax1.set_title('model loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax1.legend(['train','eval'], loc='upper left')
    axes = plt.gca()
    axes.set_ylim([0.92,1])
    plt.show()


def plot_divergence(divergationset, title1, nb_classes):
    fig = plt.figure(figsize=(40, 10))
    fig.suptitle(title1)
    plt.bar(np.arange (0, nb_classes/10, 0.1), divergationset, width=0.09, align='center')
    plt.ylabel('count')
    plt.xlabel('digit class')
    plt.xticks(np.arange(0, nb_classes/10, 0.1))
    return fig


def confusion_matrix(predicted, y_test, nb_classes):
    ytrue = pd.Series(y_test.reshape(-1), name = 'actual')
    ypred = pd.Series(predicted.reshape(-1), name = 'pred')
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.expand_frame_repr', False)
    pd.set_option('max_colwidth', None)
    return pd.crosstab(ytrue, ypred)


def predict_meter_digits():
    import numpy as np
    from tensorflow import keras

    max_delta = 0.11

    predictions = class_decoding(model.predict(xz_data.astype(np.float32)), 100).reshape(-1)

    # 9.9 <> 0 = 0.1 and 1.1 <> 1.2 = 0.1
    differences = np.minimum(np.abs(predictions-yz_data), np.abs(predictions-(10-yz_data)))

    # used for filtering
    false_differences = differences>max_delta

    # only differences bigger than delta. so small differences can be ignored in early stages
    false_predicted = differences[false_differences]
    false_images = xz_data[false_differences]
    false_labels = [ "Expected: " + str(y) + "\n Predicted: " + str(p) + "\n" + str(f)[-26:-4] for y, p, f in zip(yz_data[false_differences], predictions[false_differences], fz_data[false_differences])]

    print(f"Tested images: {len(yz_data)}. {len(false_predicted)} false predicted. Accuracy is: {1-len(false_predicted)/len(yz_data)}")

    # plot the differences (max difference can only be 5.0)
    plot_divergence(np.bincount(np.array(false_predicted*10).astype(int), minlength=51), "Divergation of false predicted", 51)

    # plot the false predicted images
    plot_dataset(np.array(false_images), false_labels, columns=7, rows=7, figsize=(18,18))

# %% [markdown]
# #### Data loading function TMNIST
#
# The Type face MNIST dataset comes from kaggle and is processed for percental digits.
#
# The complete dataset has 300.000 images. Some fonts are not good for train the meter digits and will be removed by blacklist entries.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

def tmnist_percentals():
    y_train = np.empty((0))
    x_train = np.empty((0, 32, 20,3))
    
    # fonts in blacklist will be removed from dataset
    blacklist_url = "datasets/font-blacklist.txt"
    blacklist_data = pd.read_csv(blacklist_url, index_col=False)
    
    for i in range(28):

        dataset_url = "datasets/TMNIST_PERCENTAL_"+str((i+1)*1000)+"_Data.csv"
        data = pd.read_csv(dataset_url, index_col=False)
        data = data.drop(data[data['names'].isin(blacklist_data.values.reshape(-1))].index)
        
        y_tmnist = data[['labels']]
        
        X = data.drop({'labels','names'},axis=1)

        # resizing needs a new shape
        X_images = (X.values.reshape(-1,28,28,1))
        
        # resize but not all for padding
        X_images = tf.image.resize(X_images, (30,22))
        
        # now pad to make a border (later white)
        # so it looks more like a meter digit
        X_images = tf.image.resize_with_pad(X_images, 32, 20)
        
        # remove the shape for resizing
        X_images = np.array(X_images).reshape(-1,32,20)
        # gray to rgb (split in 3 channels)
        X_images = np.stack((X_images,)*3, axis=-1)
        
        x_train = np.concatenate((X_images, x_train))
        y_train = np.concatenate((y_tmnist.values.reshape(-1), y_train))
    
    return shuffle(x_train,  y_train, n_samples=len(y_train))

# %%
import os
import shutil
from PIL import Image 
from tensorflow import keras

def ziffer_data_files(input_dir):
    imgfiles = []
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if (file.endswith(".jpg") and not file.startswith("10_") and not file.startswith("N")):
                #print(root + "/" + file)
                imgfiles.append(root + "/" + file)
    return  imgfiles

def ziffer_data(input_dir='images'):
    
    files = ziffer_data_files(input_dir)
    
    y_data = np.empty((len(files)))
    y_file = np.empty((len(files)), dtype="S100")
    x_data = np.empty((len(files),32,20,3))

    for i, aktfile in enumerate(files):
        base = os.path.basename(aktfile)

        # get label from filename (1.2_ new or 1_ old),
        if (base[1]=="."):
            target = base[0:3]
        else:
            target = base[0:1]
         
        category = float(target)
        
        test_image = Image.open(aktfile).resize((20, 32))
        test_image = np.array(test_image, dtype="float32")
        y_file[i] =  base
        x_data[i] = test_image
        y_data[i] =  category
    print("Ziffer data count: ", len(y_data))   
    return x_data, y_data, y_file

# %% [markdown]
# ####

# %% [markdown]
# ### Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# The meter digits are all 0-9 ziffer_raw + my own data 0-9.
# At now no images used between two digits. Many images from 0-9 are +/- 0.2 devergent and not correctly labeled. (See the last result)

# %%
from sklearn.model_selection import train_test_split

xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
xz_train, xz_test, yz_train, yz_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)


xt_data, yt_data = tmnist_percentals()


x_data = np.concatenate((xt_data, xz_train))
y_data = np.concatenate((yt_data, yz_train))
x_data, y_data = shuffle(x_data, y_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)

print(x_train.shape)

input_shape=x_train[0].shape
print(f"dataset x_train-size={len(x_train)}")
plot_dataset(x_train, y_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)

yz_train = class_encoding(yz_train, nb_classes)
yz_test = class_encoding(yz_test, nb_classes)
# Out:
# Ziffer data count:  9134
# (221989, 32, 20, 3)
# dataset x_train-size=221989

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting, spot light and noising images.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np

train_iterator = augmentation(x_train, y_train)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.cnn32 import VGG_like
model = VGG_like(input_shape, nb_classes)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=50, verbose=1, baseline=0.04, restore_best_weights=True)
mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[annealer, earlystop, mc],
                verbose=2)

plot_acc_loss(history, "Trainingsresults")

predict_meter_digits()
# Out:
# Epoch 1/400
# 2022-06-07 22:25:48.441426: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-07 22:25:49.094356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6936/6938 [============================>.] - ETA: 0s - loss: 1.4385 - accuracy: 0.6656
# 2022-06-07 22:27:55.043731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.97303, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 139s 19ms/step - loss: 1.4381 - accuracy: 0.6657 - val_loss: 0.0989 - val_accuracy: 0.9730 - lr: 0.0010
# Epoch 2/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9612
# Epoch 2: val_accuracy improved from 0.97303 to 0.98398, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.1414 - accuracy: 0.9612 - val_loss: 0.0600 - val_accuracy: 0.9840 - lr: 9.8000e-04
# Epoch 3/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9719
# Epoch 3: val_accuracy improved from 0.98398 to 0.98503, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 131s 19ms/step - loss: 0.1008 - accuracy: 0.9719 - val_loss: 0.0520 - val_accuracy: 0.9850 - lr: 9.6040e-04
# Epoch 4/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9764
# Epoch 4: val_accuracy improved from 0.98503 to 0.98728, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 130s 19ms/step - loss: 0.0812 - accuracy: 0.9764 - val_loss: 0.0432 - val_accuracy: 0.9873 - lr: 9.4119e-04
# Epoch 5/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9795
# Epoch 5: val_accuracy improved from 0.98728 to 0.98899, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0710 - accuracy: 0.9795 - val_loss: 0.0368 - val_accuracy: 0.9890 - lr: 9.2237e-04
# Epoch 6/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9818
# Epoch 6: val_accuracy improved from 0.98899 to 0.98948, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0619 - accuracy: 0.9818 - val_loss: 0.0352 - val_accuracy: 0.9895 - lr: 9.0392e-04
# Epoch 7/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9833
# Epoch 7: val_accuracy did not improve from 0.98948
# 6938/6938 [==============================] - 134s 19ms/step - loss: 0.0559 - accuracy: 0.9833 - val_loss: 0.0351 - val_accuracy: 0.9892 - lr: 8.8584e-04
# Epoch 8/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9846
# Epoch 8: val_accuracy improved from 0.98948 to 0.99065, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 134s 19ms/step - loss: 0.0509 - accuracy: 0.9846 - val_loss: 0.0300 - val_accuracy: 0.9906 - lr: 8.6813e-04
# Epoch 9/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9857
# Epoch 9: val_accuracy did not improve from 0.99065
# 6938/6938 [==============================] - 131s 19ms/step - loss: 0.0461 - accuracy: 0.9857 - val_loss: 0.0312 - val_accuracy: 0.9898 - lr: 8.5076e-04
# Epoch 10/400
# 6935/6938 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9867
# Epoch 10: val_accuracy did not improve from 0.99065
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0424 - accuracy: 0.9867 - val_loss: 0.0277 - val_accuracy: 0.9906 - lr: 8.3375e-04
# Epoch 11/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9875
# Epoch 11: val_accuracy improved from 0.99065 to 0.99157, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 130s 19ms/step - loss: 0.0392 - accuracy: 0.9874 - val_loss: 0.0268 - val_accuracy: 0.9916 - lr: 8.1707e-04
# Epoch 12/400
# 6935/6938 [============================>.] - ETA: 0s - loss: 0.0372 - accuracy: 0.9880
# Epoch 12: val_accuracy did not improve from 0.99157
# 6938/6938 [==============================] - 130s 19ms/step - loss: 0.0372 - accuracy: 0.9880 - val_loss: 0.0272 - val_accuracy: 0.9915 - lr: 8.0073e-04
# Epoch 13/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9885
# Epoch 13: val_accuracy improved from 0.99157 to 0.99180, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 132s 19ms/step - loss: 0.0357 - accuracy: 0.9885 - val_loss: 0.0239 - val_accuracy: 0.9918 - lr: 7.8472e-04
# Epoch 14/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9890
# Epoch 14: val_accuracy improved from 0.99180 to 0.99220, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 132s 19ms/step - loss: 0.0342 - accuracy: 0.9890 - val_loss: 0.0250 - val_accuracy: 0.9922 - lr: 7.6902e-04
# Epoch 15/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9897
# Epoch 15: val_accuracy did not improve from 0.99220
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0318 - accuracy: 0.9897 - val_loss: 0.0248 - val_accuracy: 0.9918 - lr: 7.5364e-04
# Epoch 16/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9896
# Epoch 16: val_accuracy improved from 0.99220 to 0.99236, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0319 - accuracy: 0.9896 - val_loss: 0.0229 - val_accuracy: 0.9924 - lr: 7.3857e-04
# Epoch 17/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9905
# Epoch 17: val_accuracy improved from 0.99236 to 0.99339, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0306 - accuracy: 0.9905 - val_loss: 0.0228 - val_accuracy: 0.9934 - lr: 7.2380e-04
# Epoch 18/400
# 6935/6938 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9911
# Epoch 18: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 130s 19ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.0233 - val_accuracy: 0.9923 - lr: 7.0932e-04
# Epoch 19/400
# 6935/6938 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9908
# Epoch 19: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 132s 19ms/step - loss: 0.0283 - accuracy: 0.9908 - val_loss: 0.0240 - val_accuracy: 0.9928 - lr: 6.9514e-04
# Epoch 20/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9912
# Epoch 20: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.0222 - val_accuracy: 0.9930 - lr: 6.8123e-04
# Epoch 21/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9913
# Epoch 21: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 136s 20ms/step - loss: 0.0263 - accuracy: 0.9913 - val_loss: 0.0220 - val_accuracy: 0.9930 - lr: 6.6761e-04
# Epoch 22/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9915
# Epoch 22: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 134s 19ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.0228 - val_accuracy: 0.9930 - lr: 6.5426e-04
# Epoch 23/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9919
# Epoch 23: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 135s 19ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.0226 - val_accuracy: 0.9931 - lr: 6.4117e-04
# Epoch 24/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9922
# Epoch 24: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 133s 19ms/step - loss: 0.0237 - accuracy: 0.9922 - val_loss: 0.0218 - val_accuracy: 0.9928 - lr: 6.2835e-04
# Epoch 25/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9923
# Epoch 25: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 134s 19ms/step - loss: 0.0233 - accuracy: 0.9923 - val_loss: 0.0232 - val_accuracy: 0.9931 - lr: 6.1578e-04
# Epoch 26/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9925
# Epoch 26: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 134s 19ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0231 - val_accuracy: 0.9932 - lr: 6.0346e-04
# Epoch 27/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9926
# Epoch 27: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 132s 19ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.0212 - val_accuracy: 0.9932 - lr: 5.9140e-04
# Epoch 28/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9926
# Epoch 28: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 132s 19ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.0238 - val_accuracy: 0.9931 - lr: 5.7957e-04
# Epoch 29/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9930
# Epoch 29: val_accuracy did not improve from 0.99339
# 6938/6938 [==============================] - 130s 19ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.0252 - val_accuracy: 0.9925 - lr: 5.6798e-04
# Epoch 30/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9932
# Epoch 30: val_accuracy improved from 0.99339 to 0.99366, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 130s 19ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 0.0234 - val_accuracy: 0.9937 - lr: 5.5662e-04
# Epoch 31/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9933
# Epoch 31: val_accuracy did not improve from 0.99366
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.0229 - val_accuracy: 0.9936 - lr: 5.4548e-04
# Epoch 32/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9937
# Epoch 32: val_accuracy did not improve from 0.99366
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0214 - val_accuracy: 0.9934 - lr: 5.3457e-04
# Epoch 33/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9935
# Epoch 33: val_accuracy improved from 0.99366 to 0.99395, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0220 - val_accuracy: 0.9939 - lr: 5.2388e-04
# Epoch 34/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9938
# Epoch 34: val_accuracy did not improve from 0.99395
# 6938/6938 [==============================] - 128s 19ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.0234 - val_accuracy: 0.9934 - lr: 5.1341e-04
# Epoch 35/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9937
# Epoch 35: val_accuracy did not improve from 0.99395
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0207 - val_accuracy: 0.9937 - lr: 5.0314e-04
# Epoch 36/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9941
# Epoch 36: val_accuracy did not improve from 0.99395
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0172 - accuracy: 0.9941 - val_loss: 0.0229 - val_accuracy: 0.9937 - lr: 4.9307e-04
# Epoch 37/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9942
# Epoch 37: val_accuracy did not improve from 0.99395
# 6938/6938 [==============================] - 128s 19ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.0213 - val_accuracy: 0.9938 - lr: 4.8321e-04
# Epoch 38/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9942
# Epoch 38: val_accuracy did not improve from 0.99395
# 6938/6938 [==============================] - 128s 19ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0215 - val_accuracy: 0.9939 - lr: 4.7355e-04
# Epoch 39/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9946
# Epoch 39: val_accuracy improved from 0.99395 to 0.99409, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 129s 19ms/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.0204 - val_accuracy: 0.9941 - lr: 4.6408e-04
# Epoch 40/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9941
# Epoch 40: val_accuracy did not improve from 0.99409
# 6938/6938 [==============================] - 128s 18ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0212 - val_accuracy: 0.9937 - lr: 4.5480e-04
# Epoch 41/400
# 6937/6938 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9945
# Epoch 41: val_accuracy did not improve from 0.99409
# 6938/6938 [==============================] - 127s 18ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0206 - val_accuracy: 0.9940 - lr: 4.4570e-04
# Epoch 42/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9947
# Epoch 42: val_accuracy did not improve from 0.99409
# 6938/6938 [==============================] - 127s 18ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.0294 - val_accuracy: 0.9939 - lr: 4.3679e-04
# Epoch 43/400
# 6936/6938 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9948
# Epoch 43: val_accuracy did not improve from 0.99409
# 6938/6938 [==============================] - 126s 18ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.0280 - val_accuracy: 0.9939 - lr: 4.2805e-04
# Epoch 44/400
# 6935/6938 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9946
# Epoch 44: val_accuracy did not improve from 0.99409
# 6938/6938 [==============================] - 126s 18ms/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 0.0259 - val_accuracy: 0.9940 - lr: 4.1949e-04
# Epoch 45/400
# 6938/6938 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9948
# Epoch 45: val_accuracy improved from 0.99409 to 0.99445, saving model to cnn32_best.h5
# 6938/6938 [==============================] - 127s 18ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.0302 - val_accuracy: 0.9945 - lr: 4.1110e-04
# Epoch 46/400
#  633/6938 [=>............................] - ETA: 1:44 - loss: 0.0188 - accuracy: 0.9948

# %%
import numpy as np

model = keras.models.load_model(model_filename + '_best.h5')

# now whith meter digits
train_iterator = augmentation(xz_train, yz_train)
validation_iterator = no_augmentation(xz_test, yz_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator) 

# only the last layer is now trainable
for layer in model.layers[:-1]:
    layer.trainable=False

mc = ModelCheckpoint(model_filename + '_best_transfer.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[annealer, earlystop, mc],
                verbose=1)

plot_acc_loss(history, "Trainingsresults")

predict_meter_digits()
# Out:
# Train data
# Validation data
# Epoch 1/400
#   6/229 [..............................] - ETA: 2s - loss: 0.4848 - accuracy: 0.8333
# 2022-06-08 06:46:55.636881: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - ETA: 0s - loss: 0.5128 - accuracy: 0.8455
# 2022-06-08 06:46:58.930415: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.84018, saving model to cnn32_best_transfer.h5
# 229/229 [==============================] - 4s 16ms/step - loss: 0.5128 - accuracy: 0.8455 - val_loss: 0.6310 - val_accuracy: 0.8402 - lr: 0.0010
# Epoch 2/400
# 229/229 [==============================] - ETA: 0s - loss: 0.4981 - accuracy: 0.8458
# Epoch 2: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 4s 15ms/step - loss: 0.4981 - accuracy: 0.8458 - val_loss: 0.6258 - val_accuracy: 0.8396 - lr: 9.8000e-04
# Epoch 3/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.4788 - accuracy: 0.8491
# Epoch 3: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4768 - accuracy: 0.8495 - val_loss: 0.6215 - val_accuracy: 0.8402 - lr: 9.6040e-04
# Epoch 4/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4856 - accuracy: 0.8552
# Epoch 4: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4846 - accuracy: 0.8553 - val_loss: 0.6197 - val_accuracy: 0.8402 - lr: 9.4119e-04
# Epoch 5/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.4757 - accuracy: 0.8550
# Epoch 5: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 4s 15ms/step - loss: 0.4779 - accuracy: 0.8540 - val_loss: 0.6171 - val_accuracy: 0.8385 - lr: 9.2237e-04
# Epoch 6/400
# 229/229 [==============================] - ETA: 0s - loss: 0.4487 - accuracy: 0.8553
# Epoch 6: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4487 - accuracy: 0.8553 - val_loss: 0.6181 - val_accuracy: 0.8374 - lr: 9.0392e-04
# Epoch 7/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4427 - accuracy: 0.8638
# Epoch 7: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4442 - accuracy: 0.8638 - val_loss: 0.6169 - val_accuracy: 0.8380 - lr: 8.8584e-04
# Epoch 8/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4429 - accuracy: 0.8605
# Epoch 8: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 4s 15ms/step - loss: 0.4416 - accuracy: 0.8607 - val_loss: 0.6125 - val_accuracy: 0.8369 - lr: 8.6813e-04
# Epoch 9/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4307 - accuracy: 0.8615
# Epoch 9: val_accuracy did not improve from 0.84018
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4324 - accuracy: 0.8611 - val_loss: 0.6107 - val_accuracy: 0.8385 - lr: 8.5076e-04
# Epoch 10/400
# 225/229 [============================>.] - ETA: 0s - loss: 0.4468 - accuracy: 0.8660
# Epoch 10: val_accuracy improved from 0.84018 to 0.84127, saving model to cnn32_best_transfer.h5
# 229/229 [==============================] - 4s 15ms/step - loss: 0.4465 - accuracy: 0.8662 - val_loss: 0.6099 - val_accuracy: 0.8413 - lr: 8.3375e-04
# Epoch 11/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4313 - accuracy: 0.8598
# Epoch 11: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4334 - accuracy: 0.8594 - val_loss: 0.6080 - val_accuracy: 0.8391 - lr: 8.1707e-04
# Epoch 12/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4476 - accuracy: 0.8555
# Epoch 12: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4459 - accuracy: 0.8566 - val_loss: 0.6054 - val_accuracy: 0.8358 - lr: 8.0073e-04
# Epoch 13/400
# 229/229 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8605
# Epoch 13: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4217 - accuracy: 0.8605 - val_loss: 0.6016 - val_accuracy: 0.8380 - lr: 7.8472e-04
# Epoch 14/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.4310 - accuracy: 0.8660
# Epoch 14: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4306 - accuracy: 0.8662 - val_loss: 0.6004 - val_accuracy: 0.8402 - lr: 7.6902e-04
# Epoch 15/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.4263 - accuracy: 0.8639
# Epoch 15: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4266 - accuracy: 0.8636 - val_loss: 0.5989 - val_accuracy: 0.8413 - lr: 7.5364e-04
# Epoch 16/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4347 - accuracy: 0.8627
# Epoch 16: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4369 - accuracy: 0.8622 - val_loss: 0.5992 - val_accuracy: 0.8407 - lr: 7.3857e-04
# Epoch 17/400
# 229/229 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8679
# Epoch 17: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 4s 16ms/step - loss: 0.4356 - accuracy: 0.8679 - val_loss: 0.5972 - val_accuracy: 0.8407 - lr: 7.2380e-04
# Epoch 18/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4326 - accuracy: 0.8644
# Epoch 18: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4307 - accuracy: 0.8647 - val_loss: 0.5950 - val_accuracy: 0.8385 - lr: 7.0932e-04
# Epoch 19/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.4289 - accuracy: 0.8663
# Epoch 19: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4295 - accuracy: 0.8657 - val_loss: 0.5951 - val_accuracy: 0.8380 - lr: 6.9514e-04
# Epoch 20/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4195 - accuracy: 0.8656
# Epoch 20: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4185 - accuracy: 0.8652 - val_loss: 0.5911 - val_accuracy: 0.8380 - lr: 6.8123e-04
# Epoch 21/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4258 - accuracy: 0.8626
# Epoch 21: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4248 - accuracy: 0.8631 - val_loss: 0.5897 - val_accuracy: 0.8385 - lr: 6.6761e-04
# Epoch 22/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4066 - accuracy: 0.8746
# Epoch 22: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4081 - accuracy: 0.8749 - val_loss: 0.5892 - val_accuracy: 0.8385 - lr: 6.5426e-04
# Epoch 23/400
# 229/229 [==============================] - ETA: 0s - loss: 0.4068 - accuracy: 0.8705
# Epoch 23: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4068 - accuracy: 0.8705 - val_loss: 0.5881 - val_accuracy: 0.8363 - lr: 6.4117e-04
# Epoch 24/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.4156 - accuracy: 0.8644
# Epoch 24: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4159 - accuracy: 0.8642 - val_loss: 0.5868 - val_accuracy: 0.8374 - lr: 6.2835e-04
# Epoch 25/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4153 - accuracy: 0.8651
# Epoch 25: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4148 - accuracy: 0.8651 - val_loss: 0.5867 - val_accuracy: 0.8374 - lr: 6.1578e-04
# Epoch 26/400
# 229/229 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.8742
# Epoch 26: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3857 - accuracy: 0.8742 - val_loss: 0.5861 - val_accuracy: 0.8374 - lr: 6.0346e-04
# Epoch 27/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4017 - accuracy: 0.8691
# Epoch 27: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4001 - accuracy: 0.8693 - val_loss: 0.5853 - val_accuracy: 0.8396 - lr: 5.9140e-04
# Epoch 28/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4178 - accuracy: 0.8671
# Epoch 28: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4189 - accuracy: 0.8668 - val_loss: 0.5835 - val_accuracy: 0.8407 - lr: 5.7957e-04
# Epoch 29/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.3957 - accuracy: 0.8723
# Epoch 29: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3944 - accuracy: 0.8727 - val_loss: 0.5825 - val_accuracy: 0.8396 - lr: 5.6798e-04
# Epoch 30/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4153 - accuracy: 0.8660
# Epoch 30: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4142 - accuracy: 0.8666 - val_loss: 0.5822 - val_accuracy: 0.8391 - lr: 5.5662e-04
# Epoch 31/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.4028 - accuracy: 0.8666
# Epoch 31: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4021 - accuracy: 0.8667 - val_loss: 0.5815 - val_accuracy: 0.8391 - lr: 5.4548e-04
# Epoch 32/400
# 229/229 [==============================] - ETA: 0s - loss: 0.4156 - accuracy: 0.8649
# Epoch 32: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4156 - accuracy: 0.8649 - val_loss: 0.5799 - val_accuracy: 0.8385 - lr: 5.3457e-04
# Epoch 33/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.4210 - accuracy: 0.8649
# Epoch 33: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4203 - accuracy: 0.8651 - val_loss: 0.5805 - val_accuracy: 0.8358 - lr: 5.2388e-04
# Epoch 34/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.4071 - accuracy: 0.8609
# Epoch 34: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4086 - accuracy: 0.8605 - val_loss: 0.5794 - val_accuracy: 0.8363 - lr: 5.1341e-04
# Epoch 35/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.4284 - accuracy: 0.8694
# Epoch 35: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4291 - accuracy: 0.8686 - val_loss: 0.5782 - val_accuracy: 0.8352 - lr: 5.0314e-04
# Epoch 36/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.3937 - accuracy: 0.8744
# Epoch 36: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3961 - accuracy: 0.8744 - val_loss: 0.5775 - val_accuracy: 0.8380 - lr: 4.9307e-04
# Epoch 37/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.4095 - accuracy: 0.8669
# Epoch 37: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4097 - accuracy: 0.8670 - val_loss: 0.5759 - val_accuracy: 0.8380 - lr: 4.8321e-04
# Epoch 38/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.4105 - accuracy: 0.8691
# Epoch 38: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4098 - accuracy: 0.8693 - val_loss: 0.5747 - val_accuracy: 0.8380 - lr: 4.7355e-04
# Epoch 39/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.3999 - accuracy: 0.8778
# Epoch 39: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4021 - accuracy: 0.8774 - val_loss: 0.5737 - val_accuracy: 0.8374 - lr: 4.6408e-04
# Epoch 40/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.3914 - accuracy: 0.8696
# Epoch 40: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3921 - accuracy: 0.8693 - val_loss: 0.5733 - val_accuracy: 0.8391 - lr: 4.5480e-04
# Epoch 41/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.3874 - accuracy: 0.8729
# Epoch 41: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3864 - accuracy: 0.8733 - val_loss: 0.5740 - val_accuracy: 0.8385 - lr: 4.4570e-04
# Epoch 42/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.3794 - accuracy: 0.8746
# Epoch 42: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3795 - accuracy: 0.8745 - val_loss: 0.5747 - val_accuracy: 0.8380 - lr: 4.3679e-04
# Epoch 43/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.3803 - accuracy: 0.8710
# Epoch 43: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3795 - accuracy: 0.8712 - val_loss: 0.5750 - val_accuracy: 0.8407 - lr: 4.2805e-04
# Epoch 44/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.3859 - accuracy: 0.8690
# Epoch 44: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3854 - accuracy: 0.8683 - val_loss: 0.5754 - val_accuracy: 0.8391 - lr: 4.1949e-04
# Epoch 45/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.3969 - accuracy: 0.8713
# Epoch 45: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3957 - accuracy: 0.8715 - val_loss: 0.5744 - val_accuracy: 0.8391 - lr: 4.1110e-04
# Epoch 46/400
# 228/229 [============================>.] - ETA: 0s - loss: 0.4075 - accuracy: 0.8730
# Epoch 46: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.4082 - accuracy: 0.8726 - val_loss: 0.5745 - val_accuracy: 0.8380 - lr: 4.0288e-04
# Epoch 47/400
# 227/229 [============================>.] - ETA: 0s - loss: 0.3676 - accuracy: 0.8796
# Epoch 47: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3688 - accuracy: 0.8794 - val_loss: 0.5742 - val_accuracy: 0.8369 - lr: 3.9482e-04
# Epoch 48/400
# 229/229 [==============================] - ETA: 0s - loss: 0.3770 - accuracy: 0.8753
# Epoch 48: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3770 - accuracy: 0.8753 - val_loss: 0.5741 - val_accuracy: 0.8380 - lr: 3.8692e-04
# Epoch 49/400
# 229/229 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8722
# Epoch 49: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3831 - accuracy: 0.8722 - val_loss: 0.5743 - val_accuracy: 0.8391 - lr: 3.7919e-04
# Epoch 50/400
# 226/229 [============================>.] - ETA: 0s - loss: 0.3885 - accuracy: 0.8702Restoring model weights from the end of the best epoch: 40.
#
# Epoch 50: val_accuracy did not improve from 0.84127
# 229/229 [==============================] - 3s 15ms/step - loss: 0.3879 - accuracy: 0.8703 - val_loss: 0.5734 - val_accuracy: 0.8380 - lr: 3.7160e-04
# Epoch 50: early stopping
# 2022-06-08 06:49:50.132558: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 9134. 33 false predicted. Accuracy is: 0.9963871250273703

# %% [markdown]
# ### Ziffer images
#
# The model is build for predicting meter digit images (Ziffer). So we test *all* meter digit images of the dataset (not only the validation set)
#
# max_delta can set a value, that ignored convergence +/- of the value and accept it as predicted correctly.
#
# Because of the meter digit dataset (only 0.0, 1.0, ... 9.0) We have no real answer how good the images between two digits are predicted.
