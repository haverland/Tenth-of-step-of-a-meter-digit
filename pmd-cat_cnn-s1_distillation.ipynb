# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with mixed data digit images and TMNIST percental images.
# The best model will be stored as "cnn3-best.h5"
#
# ### 2nd train
#
# Runs only on the last layer again. The convolutional layers will not trained.
#
# ### The Model
#
# Used a classic CNN (see summary) network as small model.
#
# <https://github.com/arthurdouillard/keras-effnet>

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 40                      # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "output/cnn-s1_dist"
teacher_filename = "output/cnn32_best_transfer.h5"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *

# %% [markdown]
# ####

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
#
# ### Percental TMNIST
#
# 300.000 images of type face fonts in 0.1 steps from 0.0 to 9.9
#
# See https://www.kaggle.com/datasets/frankhaverland/percentile-tmnist-for-electric-meters
#
#
# ## Train and Test data
#
# For 1st train both dataset mixed are used.
#
# ### digit meter spread
#
# The percental TMNIST has for every label the same count of data.
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
xz_train, xz_test, yz_train, yz_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)


xt_data, yt_data = tmnist_percentals()

# mixing the datasets
x_data = np.concatenate((xt_data, xz_train))
y_data = np.concatenate((yt_data, yz_train))
x_data, y_data = shuffle(x_data, y_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)

input_shape=x_train[0].shape
print(f"dataset x_train-size={len(x_train)}")
plot_dataset(x_train, y_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)

yz_train = class_encoding(yz_train, nb_classes)
yz_test = class_encoding(yz_test, nb_classes)
# Out:
# Ziffer data count:  12477
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-06-14 11:07:59.933342: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-14 11:07:59.933460: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# dataset x_train-size=224128

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
# Spot light is not used. It makes the train difficult without better results.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train, preprocessing_function=invert_noise)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.cnn32 import CNN_s1

teacher = keras.models.load_model(teacher_filename)
teacher._name = "Teacher_" + teacher._name

student = CNN_s1(input_shape, nb_classes, activation_top=None)
student._name="cnn-s1"

student.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])
student.summary()

distiller = Distiller(student=student, teacher=teacher)
distiller._name = student._name
distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.CategoricalAccuracy()],
    student_loss_fn=keras.losses.CategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)
# Out:
# Model: "cnn-s1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 32, 20, 3)        12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 32, 20, 32)        896
#
#  batch_normalization_1 (Batc  (None, 32, 20, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 10, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 10, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 10, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 10, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 5, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 5, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 8, 5, 64)         256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 2, 64)          0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 214,000
# Trainable params: 213,674
# Non-trainable params: 326
# _________________________________________________________________

# %% [markdown]
# ### The Training
#
# The pre_trained teacher model helps to improve the training of the student model.
#
# See <https://keras.io/examples/vision/knowledge_distillation/>
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_categorical_accuracy', mode='max' , patience=25, verbose=1, baseline=0.04, restore_best_weights=True)
mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

history = distiller.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[annealer, earlystop, mc],
                verbose=1)

model = distiller.student

model.save(model_filename + '_dist.h5')

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/40
# 2022-06-14 11:08:26.719561: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-14 11:08:27.125079: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.8883 - student_loss: 0.6445 - distillation_loss: 0.4176
# 2022-06-14 11:10:23.856544: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_categorical_accuracy improved from -inf to 0.97407, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 127s 18ms/step - categorical_accuracy: 0.8883 - student_loss: 0.6444 - distillation_loss: 0.4176 - val_categorical_accuracy: 0.9741 - val_student_loss: 0.0000e+00 - lr: 0.0010
# Epoch 2/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9662 - student_loss: 0.1942 - distillation_loss: 0.1199
# Epoch 2: val_categorical_accuracy improved from 0.97407 to 0.97941, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 127s 18ms/step - categorical_accuracy: 0.9662 - student_loss: 0.1942 - distillation_loss: 0.1199 - val_categorical_accuracy: 0.9794 - val_student_loss: 0.0000e+00 - lr: 9.8000e-04
# Epoch 3/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9715 - student_loss: 0.1548 - distillation_loss: 0.0962
# Epoch 3: val_categorical_accuracy improved from 0.97941 to 0.98246, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 127s 18ms/step - categorical_accuracy: 0.9715 - student_loss: 0.1547 - distillation_loss: 0.0963 - val_categorical_accuracy: 0.9825 - val_student_loss: 0.0000e+00 - lr: 9.6040e-04
# Epoch 4/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9745 - student_loss: 0.1295 - distillation_loss: 0.0840
# Epoch 4: val_categorical_accuracy improved from 0.98246 to 0.98396, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 127s 18ms/step - categorical_accuracy: 0.9745 - student_loss: 0.1295 - distillation_loss: 0.0840 - val_categorical_accuracy: 0.9840 - val_student_loss: 0.0000e+00 - lr: 9.4119e-04
# Epoch 5/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9765 - student_loss: 0.1155 - distillation_loss: 0.0770
# Epoch 5: val_categorical_accuracy improved from 0.98396 to 0.98478, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 127s 18ms/step - categorical_accuracy: 0.9765 - student_loss: 0.1156 - distillation_loss: 0.0770 - val_categorical_accuracy: 0.9848 - val_student_loss: 0.0000e+00 - lr: 9.2237e-04
# Epoch 6/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9782 - student_loss: 0.1058 - distillation_loss: 0.0714
# Epoch 6: val_categorical_accuracy improved from 0.98478 to 0.98595, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9782 - student_loss: 0.1058 - distillation_loss: 0.0714 - val_categorical_accuracy: 0.9860 - val_student_loss: 0.0000e+00 - lr: 9.0392e-04
# Epoch 7/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9791 - student_loss: 0.0987 - distillation_loss: 0.0677
# Epoch 7: val_categorical_accuracy improved from 0.98595 to 0.98708, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9791 - student_loss: 0.0986 - distillation_loss: 0.0677 - val_categorical_accuracy: 0.9871 - val_student_loss: 0.0000e+00 - lr: 8.8584e-04
# Epoch 8/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9802 - student_loss: 0.0891 - distillation_loss: 0.0640
# Epoch 8: val_categorical_accuracy improved from 0.98708 to 0.98724, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 122s 17ms/step - categorical_accuracy: 0.9802 - student_loss: 0.0890 - distillation_loss: 0.0640 - val_categorical_accuracy: 0.9872 - val_student_loss: 0.0000e+00 - lr: 8.6813e-04
# Epoch 9/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9808 - student_loss: 0.0884 - distillation_loss: 0.0615
# Epoch 9: val_categorical_accuracy did not improve from 0.98724
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9808 - student_loss: 0.0884 - distillation_loss: 0.0615 - val_categorical_accuracy: 0.9868 - val_student_loss: 0.0000e+00 - lr: 8.5076e-04
# Epoch 10/40
# 7001/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9813 - student_loss: 0.0836 - distillation_loss: 0.0595
# Epoch 10: val_categorical_accuracy did not improve from 0.98724
# 7004/7004 [==============================] - 123s 17ms/step - categorical_accuracy: 0.9813 - student_loss: 0.0837 - distillation_loss: 0.0595 - val_categorical_accuracy: 0.9871 - val_student_loss: 0.0000e+00 - lr: 8.3375e-04
# Epoch 11/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9813 - student_loss: 0.0812 - distillation_loss: 0.0578
# Epoch 11: val_categorical_accuracy improved from 0.98724 to 0.98827, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9813 - student_loss: 0.0812 - distillation_loss: 0.0578 - val_categorical_accuracy: 0.9883 - val_student_loss: 0.0000e+00 - lr: 8.1707e-04
# Epoch 12/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9824 - student_loss: 0.0773 - distillation_loss: 0.0559
# Epoch 12: val_categorical_accuracy did not improve from 0.98827
# 7004/7004 [==============================] - 122s 17ms/step - categorical_accuracy: 0.9824 - student_loss: 0.0773 - distillation_loss: 0.0559 - val_categorical_accuracy: 0.9870 - val_student_loss: 0.0000e+00 - lr: 8.0073e-04
# Epoch 13/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9821 - student_loss: 0.0760 - distillation_loss: 0.0549
# Epoch 13: val_categorical_accuracy did not improve from 0.98827
# 7004/7004 [==============================] - 122s 17ms/step - categorical_accuracy: 0.9821 - student_loss: 0.0760 - distillation_loss: 0.0549 - val_categorical_accuracy: 0.9873 - val_student_loss: 0.0000e+00 - lr: 7.8472e-04
# Epoch 14/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9825 - student_loss: 0.0743 - distillation_loss: 0.0537
# Epoch 14: val_categorical_accuracy did not improve from 0.98827
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9825 - student_loss: 0.0745 - distillation_loss: 0.0537 - val_categorical_accuracy: 0.9878 - val_student_loss: 0.0000e+00 - lr: 7.6902e-04
# Epoch 15/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9828 - student_loss: 0.0725 - distillation_loss: 0.0526
# Epoch 15: val_categorical_accuracy did not improve from 0.98827
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9827 - student_loss: 0.0725 - distillation_loss: 0.0526 - val_categorical_accuracy: 0.9878 - val_student_loss: 0.0000e+00 - lr: 7.5364e-04
# Epoch 16/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9832 - student_loss: 0.0707 - distillation_loss: 0.0516
# Epoch 16: val_categorical_accuracy improved from 0.98827 to 0.98856, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9832 - student_loss: 0.0706 - distillation_loss: 0.0516 - val_categorical_accuracy: 0.9886 - val_student_loss: 0.0000e+00 - lr: 7.3857e-04
# Epoch 17/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9835 - student_loss: 0.0686 - distillation_loss: 0.0506
# Epoch 17: val_categorical_accuracy did not improve from 0.98856
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9835 - student_loss: 0.0686 - distillation_loss: 0.0506 - val_categorical_accuracy: 0.9876 - val_student_loss: 0.0000e+00 - lr: 7.2380e-04
# Epoch 18/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9838 - student_loss: 0.0659 - distillation_loss: 0.0501
# Epoch 18: val_categorical_accuracy did not improve from 0.98856
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9838 - student_loss: 0.0659 - distillation_loss: 0.0501 - val_categorical_accuracy: 0.9884 - val_student_loss: 0.0000e+00 - lr: 7.0932e-04
# Epoch 19/40
# 7001/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9839 - student_loss: 0.0646 - distillation_loss: 0.0493
# Epoch 19: val_categorical_accuracy did not improve from 0.98856
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9839 - student_loss: 0.0646 - distillation_loss: 0.0493 - val_categorical_accuracy: 0.9884 - val_student_loss: 0.0000e+00 - lr: 6.9514e-04
# Epoch 20/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9839 - student_loss: 0.0653 - distillation_loss: 0.0487
# Epoch 20: val_categorical_accuracy improved from 0.98856 to 0.98911, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9839 - student_loss: 0.0653 - distillation_loss: 0.0487 - val_categorical_accuracy: 0.9891 - val_student_loss: 0.0000e+00 - lr: 6.8123e-04
# Epoch 21/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9841 - student_loss: 0.0655 - distillation_loss: 0.0481
# Epoch 21: val_categorical_accuracy did not improve from 0.98911
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9841 - student_loss: 0.0655 - distillation_loss: 0.0481 - val_categorical_accuracy: 0.9884 - val_student_loss: 0.0000e+00 - lr: 6.6761e-04
# Epoch 22/40
# 7001/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9847 - student_loss: 0.0632 - distillation_loss: 0.0475
# Epoch 22: val_categorical_accuracy did not improve from 0.98911
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9847 - student_loss: 0.0631 - distillation_loss: 0.0475 - val_categorical_accuracy: 0.9889 - val_student_loss: 0.0000e+00 - lr: 6.5426e-04
# Epoch 23/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9844 - student_loss: 0.0630 - distillation_loss: 0.0467
# Epoch 23: val_categorical_accuracy improved from 0.98911 to 0.98924, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9844 - student_loss: 0.0630 - distillation_loss: 0.0467 - val_categorical_accuracy: 0.9892 - val_student_loss: 0.0000e+00 - lr: 6.4117e-04
# Epoch 24/40
# 7001/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9849 - student_loss: 0.0610 - distillation_loss: 0.0465
# Epoch 24: val_categorical_accuracy did not improve from 0.98924
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9849 - student_loss: 0.0610 - distillation_loss: 0.0465 - val_categorical_accuracy: 0.9892 - val_student_loss: 0.0000e+00 - lr: 6.2835e-04
# Epoch 25/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9846 - student_loss: 0.0606 - distillation_loss: 0.0461
# Epoch 25: val_categorical_accuracy did not improve from 0.98924
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9846 - student_loss: 0.0606 - distillation_loss: 0.0461 - val_categorical_accuracy: 0.9889 - val_student_loss: 0.0000e+00 - lr: 6.1578e-04
# Epoch 26/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9850 - student_loss: 0.0600 - distillation_loss: 0.0458
# Epoch 26: val_categorical_accuracy improved from 0.98924 to 0.98963, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9850 - student_loss: 0.0600 - distillation_loss: 0.0458 - val_categorical_accuracy: 0.9896 - val_student_loss: 0.0000e+00 - lr: 6.0346e-04
# Epoch 27/40
# 7001/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9852 - student_loss: 0.0602 - distillation_loss: 0.0452
# Epoch 27: val_categorical_accuracy did not improve from 0.98963
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9852 - student_loss: 0.0602 - distillation_loss: 0.0452 - val_categorical_accuracy: 0.9891 - val_student_loss: 0.0000e+00 - lr: 5.9140e-04
# Epoch 28/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9851 - student_loss: 0.0579 - distillation_loss: 0.0448
# Epoch 28: val_categorical_accuracy did not improve from 0.98963
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9851 - student_loss: 0.0579 - distillation_loss: 0.0448 - val_categorical_accuracy: 0.9895 - val_student_loss: 0.0000e+00 - lr: 5.7957e-04
# Epoch 29/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9852 - student_loss: 0.0590 - distillation_loss: 0.0445
# Epoch 29: val_categorical_accuracy did not improve from 0.98963
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9852 - student_loss: 0.0590 - distillation_loss: 0.0445 - val_categorical_accuracy: 0.9895 - val_student_loss: 0.0000e+00 - lr: 5.6798e-04
# Epoch 30/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9855 - student_loss: 0.0574 - distillation_loss: 0.0442
# Epoch 30: val_categorical_accuracy improved from 0.98963 to 0.98977, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9855 - student_loss: 0.0573 - distillation_loss: 0.0442 - val_categorical_accuracy: 0.9898 - val_student_loss: 0.0000e+00 - lr: 5.5662e-04
# Epoch 31/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9853 - student_loss: 0.0574 - distillation_loss: 0.0441
# Epoch 31: val_categorical_accuracy did not improve from 0.98977
# 7004/7004 [==============================] - 123s 17ms/step - categorical_accuracy: 0.9853 - student_loss: 0.0574 - distillation_loss: 0.0441 - val_categorical_accuracy: 0.9897 - val_student_loss: 0.0000e+00 - lr: 5.4548e-04
# Epoch 32/40
# 7001/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9853 - student_loss: 0.0579 - distillation_loss: 0.0437
# Epoch 32: val_categorical_accuracy did not improve from 0.98977
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9853 - student_loss: 0.0579 - distillation_loss: 0.0437 - val_categorical_accuracy: 0.9896 - val_student_loss: 4.2397e-04 - lr: 5.3457e-04
# Epoch 33/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9856 - student_loss: 0.0556 - distillation_loss: 0.0433
# Epoch 33: val_categorical_accuracy did not improve from 0.98977
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9856 - student_loss: 0.0556 - distillation_loss: 0.0433 - val_categorical_accuracy: 0.9898 - val_student_loss: 0.0000e+00 - lr: 5.2388e-04
# Epoch 34/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9860 - student_loss: 0.0534 - distillation_loss: 0.0429
# Epoch 34: val_categorical_accuracy did not improve from 0.98977
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9860 - student_loss: 0.0534 - distillation_loss: 0.0429 - val_categorical_accuracy: 0.9892 - val_student_loss: 0.0000e+00 - lr: 5.1341e-04
# Epoch 35/40
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9858 - student_loss: 0.0560 - distillation_loss: 0.0428
# Epoch 35: val_categorical_accuracy improved from 0.98977 to 0.98983, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 123s 18ms/step - categorical_accuracy: 0.9858 - student_loss: 0.0560 - distillation_loss: 0.0428 - val_categorical_accuracy: 0.9898 - val_student_loss: 0.0000e+00 - lr: 5.0314e-04
# Epoch 36/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9858 - student_loss: 0.0543 - distillation_loss: 0.0424
# Epoch 36: val_categorical_accuracy improved from 0.98983 to 0.98995, saving model to output/cnn-s1_dist_best.h5
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9858 - student_loss: 0.0543 - distillation_loss: 0.0424 - val_categorical_accuracy: 0.9900 - val_student_loss: 0.0000e+00 - lr: 4.9307e-04
# Epoch 37/40
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9858 - student_loss: 0.0546 - distillation_loss: 0.0421
# Epoch 37: val_categorical_accuracy did not improve from 0.98995
# 7004/7004 [==============================] - 124s 18ms/step - categorical_accuracy: 0.9858 - student_loss: 0.0546 - distillation_loss: 0.0421 - val_categorical_accuracy: 0.9895 - val_student_loss: 0.0000e+00 - lr: 4.8321e-04
# Epoch 38/40
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9862 - student_loss: 0.0521 - distillation_loss: 0.0420

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)

# %% [markdown]
# ### 2nd train
#
# Now the model will be trained like transfer learning <https://keras.io/guides/transfer_learning/>.
#
# All layers except the top layer will be fixed and not trained in the 2nd training.
#
# As dataset the digit meter images are used.

# %%
import numpy as np

model = keras.models.load_model(model_filename + '_dist.h5')

# now whith meter digits
train_iterator = augmentation(xz_train, yz_train)
validation_iterator = no_augmentation(xz_test, yz_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator) 

# only the last layer is now trainable
for layer in model.layers[:-1]:
    layer.trainable=False

mc = ModelCheckpoint(model_filename + '_best_transfer.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

history = distiller.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = 20,
                callbacks=[annealer, earlystop, mc],
                verbose=2)


model.save(model_filename + "_dist_transfer.h5")

plot_acc_loss(history, "Trainingsresults")

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
