# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with data digit images only.
# The best model will be stored as "dig-s1-md-best.h5"
#
#
# ## The Model
#
# Used a the jomjol CNN-S1 network as small model.

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 400                     # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "output/dig-s1-md"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
# ### Train and Test data
#
# For 1st train the digit meter will be used.
#
# ### digit meter spread
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
x_train, x_test, y_train, y_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)

input_shape=xz_train[0].shape
print(f"dataset x_train-size={len(xz_train)}")
plot_dataset(xz_train, yz_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)
# Out:
# Ziffer data count:  16500
# dataset x_train-size=16500

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet
from b2n.models.cnn32 import *
from keras import backend as K

def accuracy(y_true, y_pred):
    return K.mean(K.less_equal(K.abs((K.abs(K.argmax(y_true))- K.abs(K.argmax(y_pred)))), 1 ))


model = CNN_s1(input_shape, nb_classes, activation_top=None)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer=tf.optimizers.Adam(learning_rate=1e-3), metrics = [accuracy])
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-07-16 20:59:29.148847: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-16 20:59:29.149242: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### The Training
#
# Standard training of the model with complete dataset.
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

#annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_accuracy', mode='max' , patience=25, verbose=1,  restore_best_weights=True)
mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, min_lr=1e-5, verbose=1)
history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[earlystop, mc, reduce_lr],
                verbose=1)


#model.save(model_filename + '.h5')

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/400
# 2022-07-16 20:59:29.419022: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-16 20:59:29.849820: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 411/413 [============================>.] - ETA: 0s - loss: 4.6970 - accuracy: 0.0377
# 2022-07-16 20:59:37.338144: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.05919, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 20ms/step - loss: 4.6965 - accuracy: 0.0377 - val_loss: 4.6259 - val_accuracy: 0.0592 - lr: 0.0010
# Epoch 2/400
# 410/413 [============================>.] - ETA: 0s - loss: 4.3554 - accuracy: 0.0844
# Epoch 2: val_accuracy improved from 0.05919 to 0.28516, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 11s 27ms/step - loss: 4.3521 - accuracy: 0.0850 - val_loss: 3.4518 - val_accuracy: 0.2852 - lr: 0.0010
# Epoch 3/400
# 413/413 [==============================] - ETA: 0s - loss: 2.9328 - accuracy: 0.4195
# Epoch 3: val_accuracy improved from 0.28516 to 0.76082, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 23ms/step - loss: 2.9328 - accuracy: 0.4195 - val_loss: 1.7843 - val_accuracy: 0.7608 - lr: 0.0010
# Epoch 4/400
# 412/413 [============================>.] - ETA: 0s - loss: 1.9381 - accuracy: 0.7009
# Epoch 4: val_accuracy improved from 0.76082 to 0.88792, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 22ms/step - loss: 1.9363 - accuracy: 0.7012 - val_loss: 1.1190 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 5/400
# 413/413 [==============================] - ETA: 0s - loss: 1.5231 - accuracy: 0.8176
# Epoch 5: val_accuracy improved from 0.88792 to 0.94201, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 23ms/step - loss: 1.5231 - accuracy: 0.8176 - val_loss: 0.8937 - val_accuracy: 0.9420 - lr: 0.0010
# Epoch 6/400
# 412/413 [============================>.] - ETA: 0s - loss: 1.3224 - accuracy: 0.8731
# Epoch 6: val_accuracy improved from 0.94201 to 0.95313, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 21ms/step - loss: 1.3223 - accuracy: 0.8730 - val_loss: 0.8091 - val_accuracy: 0.9531 - lr: 0.0010
# Epoch 7/400
# 410/413 [============================>.] - ETA: 0s - loss: 1.2167 - accuracy: 0.8934
# Epoch 7: val_accuracy improved from 0.95313 to 0.96785, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 23ms/step - loss: 1.2175 - accuracy: 0.8929 - val_loss: 0.7640 - val_accuracy: 0.9678 - lr: 0.0010
# Epoch 8/400
# 412/413 [============================>.] - ETA: 0s - loss: 1.1455 - accuracy: 0.9064
# Epoch 8: val_accuracy did not improve from 0.96785
# 413/413 [==============================] - 9s 21ms/step - loss: 1.1460 - accuracy: 0.9062 - val_loss: 0.7592 - val_accuracy: 0.9654 - lr: 0.0010
# Epoch 9/400
# 412/413 [============================>.] - ETA: 0s - loss: 1.0930 - accuracy: 0.9164
# Epoch 9: val_accuracy improved from 0.96785 to 0.97025, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 9s 22ms/step - loss: 1.0924 - accuracy: 0.9165 - val_loss: 0.7560 - val_accuracy: 0.9703 - lr: 0.0010
# Epoch 10/400
# 411/413 [============================>.] - ETA: 0s - loss: 1.0382 - accuracy: 0.9266
# Epoch 10: val_accuracy improved from 0.97025 to 0.97055, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 1.0375 - accuracy: 0.9269 - val_loss: 0.7857 - val_accuracy: 0.9706 - lr: 0.0010
# Epoch 11/400
# 413/413 [==============================] - ETA: 0s - loss: 0.9947 - accuracy: 0.9336
# Epoch 11: val_accuracy improved from 0.97055 to 0.97446, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.9947 - accuracy: 0.9336 - val_loss: 0.7022 - val_accuracy: 0.9745 - lr: 0.0010
# Epoch 12/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.9756 - accuracy: 0.9353
# Epoch 12: val_accuracy improved from 0.97446 to 0.97837, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.9759 - accuracy: 0.9352 - val_loss: 0.7031 - val_accuracy: 0.9784 - lr: 0.0010
# Epoch 13/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.9361 - accuracy: 0.9421
# Epoch 13: val_accuracy did not improve from 0.97837
# 413/413 [==============================] - 7s 17ms/step - loss: 0.9377 - accuracy: 0.9420 - val_loss: 0.7242 - val_accuracy: 0.9742 - lr: 0.0010
# Epoch 14/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.9051 - accuracy: 0.9428
# Epoch 14: val_accuracy improved from 0.97837 to 0.98468, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.9044 - accuracy: 0.9429 - val_loss: 0.6638 - val_accuracy: 0.9847 - lr: 0.0010
# Epoch 15/400
# 413/413 [==============================] - ETA: 0s - loss: 0.8971 - accuracy: 0.9500
# Epoch 15: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.8971 - accuracy: 0.9500 - val_loss: 0.6371 - val_accuracy: 0.9808 - lr: 0.0010
# Epoch 16/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.8684 - accuracy: 0.9516
# Epoch 16: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.8678 - accuracy: 0.9516 - val_loss: 0.6528 - val_accuracy: 0.9757 - lr: 0.0010
# Epoch 17/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.8537 - accuracy: 0.9505
# Epoch 17: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.8540 - accuracy: 0.9507 - val_loss: 0.6673 - val_accuracy: 0.9787 - lr: 0.0010
# Epoch 18/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.8482 - accuracy: 0.9514
# Epoch 18: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.8478 - accuracy: 0.9516 - val_loss: 0.6349 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 19/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.8076 - accuracy: 0.9579
# Epoch 19: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.8081 - accuracy: 0.9579 - val_loss: 0.6266 - val_accuracy: 0.9805 - lr: 0.0010
# Epoch 20/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.8182 - accuracy: 0.9545
# Epoch 20: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.8184 - accuracy: 0.9545 - val_loss: 0.6599 - val_accuracy: 0.9799 - lr: 0.0010
# Epoch 21/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.7873 - accuracy: 0.9622
# Epoch 21: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 9s 23ms/step - loss: 0.7875 - accuracy: 0.9622 - val_loss: 0.6159 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 22/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.7638 - accuracy: 0.9615
# Epoch 22: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 18ms/step - loss: 0.7633 - accuracy: 0.9616 - val_loss: 0.6231 - val_accuracy: 0.9820 - lr: 0.0010
# Epoch 23/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.7684 - accuracy: 0.9604
# Epoch 23: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 18ms/step - loss: 0.7687 - accuracy: 0.9604 - val_loss: 0.5957 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 24/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.7495 - accuracy: 0.9630
# Epoch 24: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.7491 - accuracy: 0.9629 - val_loss: 0.5961 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 25/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.7260 - accuracy: 0.9685
# Epoch 25: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.7258 - accuracy: 0.9683 - val_loss: 0.5766 - val_accuracy: 0.9841 - lr: 0.0010
# Epoch 26/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.9635
# Epoch 26: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.7300 - accuracy: 0.9635 - val_loss: 0.5643 - val_accuracy: 0.9841 - lr: 0.0010
# Epoch 27/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.9708
# Epoch 27: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.7104 - accuracy: 0.9708 - val_loss: 0.6146 - val_accuracy: 0.9793 - lr: 0.0010
# Epoch 28/400
# 413/413 [==============================] - ETA: 0s - loss: 0.7151 - accuracy: 0.9660
# Epoch 28: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.7151 - accuracy: 0.9660 - val_loss: 0.6114 - val_accuracy: 0.9832 - lr: 0.0010
# Epoch 29/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.6989 - accuracy: 0.9674
# Epoch 29: val_accuracy did not improve from 0.98468
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6980 - accuracy: 0.9675 - val_loss: 0.5758 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 30/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.6886 - accuracy: 0.9702
# Epoch 30: val_accuracy improved from 0.98468 to 0.98648, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6884 - accuracy: 0.9702 - val_loss: 0.5475 - val_accuracy: 0.9865 - lr: 0.0010
# Epoch 31/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.6856 - accuracy: 0.9713
# Epoch 31: val_accuracy did not improve from 0.98648
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6856 - accuracy: 0.9712 - val_loss: 0.5808 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 32/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.6879 - accuracy: 0.9693
# Epoch 32: val_accuracy did not improve from 0.98648
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6882 - accuracy: 0.9692 - val_loss: 0.5456 - val_accuracy: 0.9865 - lr: 0.0010
# Epoch 33/400
# 413/413 [==============================] - ETA: 0s - loss: 0.6725 - accuracy: 0.9723
# Epoch 33: val_accuracy did not improve from 0.98648
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6725 - accuracy: 0.9723 - val_loss: 0.5575 - val_accuracy: 0.9859 - lr: 0.0010
# Epoch 34/400
# 413/413 [==============================] - ETA: 0s - loss: 0.6589 - accuracy: 0.9728
# Epoch 34: val_accuracy did not improve from 0.98648
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6589 - accuracy: 0.9728 - val_loss: 0.5560 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 35/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.6592 - accuracy: 0.9735
# Epoch 35: val_accuracy did not improve from 0.98648
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6598 - accuracy: 0.9735 - val_loss: 0.5481 - val_accuracy: 0.9847 - lr: 0.0010
# Epoch 36/400
# 413/413 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.9721
# Epoch 36: val_accuracy improved from 0.98648 to 0.98738, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6422 - accuracy: 0.9721 - val_loss: 0.5495 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 37/400
# 413/413 [==============================] - ETA: 0s - loss: 0.6507 - accuracy: 0.9737
# Epoch 37: val_accuracy improved from 0.98738 to 0.98948, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6507 - accuracy: 0.9737 - val_loss: 0.5366 - val_accuracy: 0.9895 - lr: 0.0010
# Epoch 38/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.6395 - accuracy: 0.9745
# Epoch 38: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6394 - accuracy: 0.9745 - val_loss: 0.5410 - val_accuracy: 0.9862 - lr: 0.0010
# Epoch 39/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.6315 - accuracy: 0.9741
# Epoch 39: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6322 - accuracy: 0.9740 - val_loss: 0.5309 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 40/400
# 413/413 [==============================] - ETA: 0s - loss: 0.6347 - accuracy: 0.9743
# Epoch 40: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 8s 19ms/step - loss: 0.6347 - accuracy: 0.9743 - val_loss: 0.5365 - val_accuracy: 0.9883 - lr: 0.0010
# Epoch 41/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.9738
# Epoch 41: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6345 - accuracy: 0.9738 - val_loss: 0.5269 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 42/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.6202 - accuracy: 0.9757
# Epoch 42: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 8s 19ms/step - loss: 0.6196 - accuracy: 0.9759 - val_loss: 0.5430 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 43/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.9741
# Epoch 43: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6296 - accuracy: 0.9740 - val_loss: 0.5255 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 44/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.6089 - accuracy: 0.9774
# Epoch 44: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6090 - accuracy: 0.9775 - val_loss: 0.5298 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 45/400
# 410/413 [============================>.] - ETA: 0s - loss: 0.5974 - accuracy: 0.9795
# Epoch 45: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 18ms/step - loss: 0.5977 - accuracy: 0.9793 - val_loss: 0.5308 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 46/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.6075 - accuracy: 0.9774
# Epoch 46: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6085 - accuracy: 0.9773 - val_loss: 0.5407 - val_accuracy: 0.9868 - lr: 0.0010
# Epoch 47/400
# 412/413 [============================>.] - ETA: 0s - loss: 0.6026 - accuracy: 0.9765
# Epoch 47: val_accuracy did not improve from 0.98948
# 413/413 [==============================] - 7s 17ms/step - loss: 0.6024 - accuracy: 0.9765 - val_loss: 0.5271 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 48/400
# 411/413 [============================>.] - ETA: 0s - loss: 0.6047 - accuracy: 0.9751
# Epoch 48: val_accuracy improved from 0.98948 to 0.98978, saving model to output/cnn-s1-md_best.h5
# 413/413 [==============================] - 7s 18ms/step - loss: 0.6053 - accuracy: 0.9752 - val_loss: 0.5138 - val_accuracy: 0.9898 - lr: 0.0010
# Epoch 49/400
#  80/413 [====>.........................] - ETA: 5s - loss: 0.5807 - accuracy: 0.9777

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation. The first false predicted will be shown in the diagram.

# %%
model = keras.models.load_model(model_filename + '_best.h5')
false_predicted_files = predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data, 
                                            max_delta=0.11)
fpf = pd.DataFrame(false_predicted_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeterdigits --labelfile=output/eff100md_false_predicted.csv
fpf.to_csv(model_filename + '_false_predicted.csv')
