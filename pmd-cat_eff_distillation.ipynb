# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with mixed data digit images and TMNIST percental images.
# The best model will be stored as "cnn3-best.h5"
#
# ### 2nd train
#
# Runs only on the last layer again. The convolutional layers will not trained.
#
# ### The Model
#
# Used a smaller variant of Efficientnet (effnet) network as small model.
#
# <https://github.com/arthurdouillard/keras-effnet>

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 400                      # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "output/eff100dist"
teacher_filename = "output/cnn32_best_transfer.h5"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *

# %% [markdown]
# ####

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
#
# ### Percental TMNIST
#
# 300.000 images of type face fonts in 0.1 steps from 0.0 to 9.9
#
# See https://www.kaggle.com/datasets/frankhaverland/percentile-tmnist-for-electric-meters
#
#
# ## Train and Test data
#
# For 1st train both dataset mixed are used.
#
# ### digit meter spread
#
# The percental TMNIST has for every label the same count of data.
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
xz_train, xz_test, yz_train, yz_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)


xt_data, yt_data = tmnist_percentals()

# mixing the datasets
x_data = np.concatenate((xt_data, xz_train))
y_data = np.concatenate((yt_data, yz_train))
x_data, y_data = shuffle(x_data, y_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)

input_shape=x_train[0].shape
print(f"dataset x_train-size={len(x_train)}")
plot_dataset(x_train, y_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)

yz_train = class_encoding(yz_train, nb_classes)
yz_test = class_encoding(yz_test, nb_classes)
# Out:
# Ziffer data count:  12477
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-06-14 15:29:47.928759: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-14 15:29:47.928870: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# dataset x_train-size=224128

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
# Spot light is not used. It makes the train difficult without better results.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train, preprocessing_function=invert_noise)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet

teacher = keras.models.load_model(teacher_filename)
teacher._name = "Teacher_" + teacher._name

student = Effnet(input_shape, nb_classes, activation_top=None)
student._name="Effnet"

student.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

distiller = Distiller(student=student, teacher=teacher)
distiller._name = student._name
distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.CategoricalAccuracy()],
    student_loss_fn=keras.losses.CategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)

# %% [markdown]
# ### The Training
#
# The pre_trained teacher model helps to improve the training of the student model.
#
# See <https://keras.io/examples/vision/knowledge_distillation/>
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_categorical_accuracy', mode='max' , patience=25, verbose=1, baseline=0.89, restore_best_weights=True)
mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

history = distiller.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[annealer, earlystop, mc],
                verbose=1)

model = distiller.student

model.save(model_filename + '_dist.h5')

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/400
# 2022-06-14 15:30:12.118660: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-14 15:30:12.650488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9439 - student_loss: 0.3494 - distillation_loss: 0.2302
# 2022-06-14 15:32:40.614775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_categorical_accuracy improved from -inf to 0.97307, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9439 - student_loss: 0.3496 - distillation_loss: 0.2301 - val_categorical_accuracy: 0.9731 - val_student_loss: 0.0000e+00 - lr: 0.0010
# Epoch 2/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9747 - student_loss: 0.1381 - distillation_loss: 0.0874
# Epoch 2: val_categorical_accuracy did not improve from 0.97307
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9747 - student_loss: 0.1380 - distillation_loss: 0.0873 - val_categorical_accuracy: 0.9731 - val_student_loss: 0.0000e+00 - lr: 9.8000e-04
# Epoch 3/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9797 - student_loss: 0.1008 - distillation_loss: 0.0694
# Epoch 3: val_categorical_accuracy improved from 0.97307 to 0.98023, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9797 - student_loss: 0.1007 - distillation_loss: 0.0694 - val_categorical_accuracy: 0.9802 - val_student_loss: 0.0000e+00 - lr: 9.6040e-04
# Epoch 4/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9821 - student_loss: 0.0816 - distillation_loss: 0.0598
# Epoch 4: val_categorical_accuracy improved from 0.98023 to 0.98322, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9821 - student_loss: 0.0816 - distillation_loss: 0.0598 - val_categorical_accuracy: 0.9832 - val_student_loss: 0.0000e+00 - lr: 9.4119e-04
# Epoch 5/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9842 - student_loss: 0.0684 - distillation_loss: 0.0536
# Epoch 5: val_categorical_accuracy did not improve from 0.98322
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9842 - student_loss: 0.0684 - distillation_loss: 0.0536 - val_categorical_accuracy: 0.9825 - val_student_loss: 0.0000e+00 - lr: 9.2237e-04
# Epoch 6/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9856 - student_loss: 0.0614 - distillation_loss: 0.0489
# Epoch 6: val_categorical_accuracy improved from 0.98322 to 0.98496, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9856 - student_loss: 0.0614 - distillation_loss: 0.0489 - val_categorical_accuracy: 0.9850 - val_student_loss: 0.0000e+00 - lr: 9.0392e-04
# Epoch 7/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9863 - student_loss: 0.0543 - distillation_loss: 0.0458
# Epoch 7: val_categorical_accuracy improved from 0.98496 to 0.98554, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9863 - student_loss: 0.0542 - distillation_loss: 0.0458 - val_categorical_accuracy: 0.9855 - val_student_loss: 0.0000e+00 - lr: 8.8584e-04
# Epoch 8/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9873 - student_loss: 0.0503 - distillation_loss: 0.0430
# Epoch 8: val_categorical_accuracy improved from 0.98554 to 0.98783, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9873 - student_loss: 0.0503 - distillation_loss: 0.0430 - val_categorical_accuracy: 0.9878 - val_student_loss: 0.0000e+00 - lr: 8.6813e-04
# Epoch 9/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9883 - student_loss: 0.0459 - distillation_loss: 0.0410
# Epoch 9: val_categorical_accuracy did not improve from 0.98783
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9883 - student_loss: 0.0459 - distillation_loss: 0.0410 - val_categorical_accuracy: 0.9872 - val_student_loss: 0.0000e+00 - lr: 8.5076e-04
# Epoch 10/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9884 - student_loss: 0.0441 - distillation_loss: 0.0390
# Epoch 10: val_categorical_accuracy did not improve from 0.98783
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9884 - student_loss: 0.0441 - distillation_loss: 0.0390 - val_categorical_accuracy: 0.9876 - val_student_loss: 0.0000e+00 - lr: 8.3375e-04
# Epoch 11/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9891 - student_loss: 0.0397 - distillation_loss: 0.0374
# Epoch 11: val_categorical_accuracy improved from 0.98783 to 0.98844, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9891 - student_loss: 0.0397 - distillation_loss: 0.0374 - val_categorical_accuracy: 0.9884 - val_student_loss: 0.0000e+00 - lr: 8.1707e-04
# Epoch 12/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9895 - student_loss: 0.0388 - distillation_loss: 0.0363
# Epoch 12: val_categorical_accuracy did not improve from 0.98844
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9895 - student_loss: 0.0388 - distillation_loss: 0.0363 - val_categorical_accuracy: 0.9883 - val_student_loss: 0.0000e+00 - lr: 8.0073e-04
# Epoch 13/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9902 - student_loss: 0.0358 - distillation_loss: 0.0348
# Epoch 13: val_categorical_accuracy did not improve from 0.98844
# 7004/7004 [==============================] - 158s 23ms/step - categorical_accuracy: 0.9902 - student_loss: 0.0358 - distillation_loss: 0.0348 - val_categorical_accuracy: 0.9881 - val_student_loss: 0.0000e+00 - lr: 7.8472e-04
# Epoch 14/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9902 - student_loss: 0.0344 - distillation_loss: 0.0338
# Epoch 14: val_categorical_accuracy improved from 0.98844 to 0.98870, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 155s 22ms/step - categorical_accuracy: 0.9902 - student_loss: 0.0345 - distillation_loss: 0.0338 - val_categorical_accuracy: 0.9887 - val_student_loss: 0.0000e+00 - lr: 7.6902e-04
# Epoch 15/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9905 - student_loss: 0.0333 - distillation_loss: 0.0330
# Epoch 15: val_categorical_accuracy improved from 0.98870 to 0.98894, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9905 - student_loss: 0.0333 - distillation_loss: 0.0330 - val_categorical_accuracy: 0.9889 - val_student_loss: 0.0000e+00 - lr: 7.5364e-04
# Epoch 16/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9907 - student_loss: 0.0315 - distillation_loss: 0.0321
# Epoch 16: val_categorical_accuracy improved from 0.98894 to 0.98931, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9907 - student_loss: 0.0315 - distillation_loss: 0.0321 - val_categorical_accuracy: 0.9893 - val_student_loss: 0.0000e+00 - lr: 7.3857e-04
# Epoch 17/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9910 - student_loss: 0.0306 - distillation_loss: 0.0314
# Epoch 17: val_categorical_accuracy did not improve from 0.98931
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9910 - student_loss: 0.0306 - distillation_loss: 0.0314 - val_categorical_accuracy: 0.9886 - val_student_loss: 7.4367e-07 - lr: 7.2380e-04
# Epoch 18/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9912 - student_loss: 0.0299 - distillation_loss: 0.0307
# Epoch 18: val_categorical_accuracy did not improve from 0.98931
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9912 - student_loss: 0.0299 - distillation_loss: 0.0307 - val_categorical_accuracy: 0.9891 - val_student_loss: 6.6930e-06 - lr: 7.0932e-04
# Epoch 19/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9916 - student_loss: 0.0293 - distillation_loss: 0.0300
# Epoch 19: val_categorical_accuracy improved from 0.98931 to 0.98958, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9916 - student_loss: 0.0293 - distillation_loss: 0.0300 - val_categorical_accuracy: 0.9896 - val_student_loss: 0.0000e+00 - lr: 6.9514e-04
# Epoch 20/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9919 - student_loss: 0.0273 - distillation_loss: 0.0292
# Epoch 20: val_categorical_accuracy did not improve from 0.98958
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9919 - student_loss: 0.0273 - distillation_loss: 0.0292 - val_categorical_accuracy: 0.9892 - val_student_loss: 0.0000e+00 - lr: 6.8123e-04
# Epoch 21/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9919 - student_loss: 0.0268 - distillation_loss: 0.0288
# Epoch 21: val_categorical_accuracy improved from 0.98958 to 0.98974, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9919 - student_loss: 0.0268 - distillation_loss: 0.0288 - val_categorical_accuracy: 0.9897 - val_student_loss: 0.0000e+00 - lr: 6.6761e-04
# Epoch 22/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9923 - student_loss: 0.0258 - distillation_loss: 0.0283
# Epoch 22: val_categorical_accuracy improved from 0.98974 to 0.99002, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9923 - student_loss: 0.0258 - distillation_loss: 0.0283 - val_categorical_accuracy: 0.9900 - val_student_loss: 0.0000e+00 - lr: 6.5426e-04
# Epoch 23/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9923 - student_loss: 0.0255 - distillation_loss: 0.0278
# Epoch 23: val_categorical_accuracy improved from 0.99002 to 0.99031, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9923 - student_loss: 0.0256 - distillation_loss: 0.0278 - val_categorical_accuracy: 0.9903 - val_student_loss: 0.0000e+00 - lr: 6.4117e-04
# Epoch 24/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9921 - student_loss: 0.0252 - distillation_loss: 0.0274
# Epoch 24: val_categorical_accuracy did not improve from 0.99031
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9921 - student_loss: 0.0252 - distillation_loss: 0.0274 - val_categorical_accuracy: 0.9901 - val_student_loss: 0.0000e+00 - lr: 6.2835e-04
# Epoch 25/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9924 - student_loss: 0.0243 - distillation_loss: 0.0269
# Epoch 25: val_categorical_accuracy improved from 0.99031 to 0.99059, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9924 - student_loss: 0.0243 - distillation_loss: 0.0269 - val_categorical_accuracy: 0.9906 - val_student_loss: 0.0000e+00 - lr: 6.1578e-04
# Epoch 26/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9927 - student_loss: 0.0227 - distillation_loss: 0.0263
# Epoch 26: val_categorical_accuracy did not improve from 0.99059
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9927 - student_loss: 0.0227 - distillation_loss: 0.0263 - val_categorical_accuracy: 0.9904 - val_student_loss: 0.0000e+00 - lr: 6.0346e-04
# Epoch 27/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9931 - student_loss: 0.0219 - distillation_loss: 0.0262
# Epoch 27: val_categorical_accuracy did not improve from 0.99059
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9931 - student_loss: 0.0219 - distillation_loss: 0.0262 - val_categorical_accuracy: 0.9904 - val_student_loss: 0.0000e+00 - lr: 5.9140e-04
# Epoch 28/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9931 - student_loss: 0.0224 - distillation_loss: 0.0257
# Epoch 28: val_categorical_accuracy did not improve from 0.99059
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9931 - student_loss: 0.0224 - distillation_loss: 0.0257 - val_categorical_accuracy: 0.9902 - val_student_loss: 0.2331 - lr: 5.7957e-04
# Epoch 29/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9932 - student_loss: 0.0218 - distillation_loss: 0.0253
# Epoch 29: val_categorical_accuracy did not improve from 0.99059
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9932 - student_loss: 0.0218 - distillation_loss: 0.0253 - val_categorical_accuracy: 0.9903 - val_student_loss: 0.0000e+00 - lr: 5.6798e-04
# Epoch 30/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9934 - student_loss: 0.0211 - distillation_loss: 0.0249
# Epoch 30: val_categorical_accuracy did not improve from 0.99059
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9934 - student_loss: 0.0211 - distillation_loss: 0.0249 - val_categorical_accuracy: 0.9903 - val_student_loss: 0.0000e+00 - lr: 5.5662e-04
# Epoch 31/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9933 - student_loss: 0.0215 - distillation_loss: 0.0247
# Epoch 31: val_categorical_accuracy improved from 0.99059 to 0.99083, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 157s 22ms/step - categorical_accuracy: 0.9933 - student_loss: 0.0215 - distillation_loss: 0.0247 - val_categorical_accuracy: 0.9908 - val_student_loss: 0.0000e+00 - lr: 5.4548e-04
# Epoch 32/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9935 - student_loss: 0.0202 - distillation_loss: 0.0245
# Epoch 32: val_categorical_accuracy did not improve from 0.99083
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9935 - student_loss: 0.0202 - distillation_loss: 0.0245 - val_categorical_accuracy: 0.9907 - val_student_loss: 0.0000e+00 - lr: 5.3457e-04
# Epoch 33/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9934 - student_loss: 0.0204 - distillation_loss: 0.0241
# Epoch 33: val_categorical_accuracy did not improve from 0.99083
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9934 - student_loss: 0.0204 - distillation_loss: 0.0241 - val_categorical_accuracy: 0.9889 - val_student_loss: 0.0000e+00 - lr: 5.2388e-04
# Epoch 34/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9937 - student_loss: 0.0200 - distillation_loss: 0.0238
# Epoch 34: val_categorical_accuracy improved from 0.99083 to 0.99090, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9937 - student_loss: 0.0200 - distillation_loss: 0.0238 - val_categorical_accuracy: 0.9909 - val_student_loss: 0.0000e+00 - lr: 5.1341e-04
# Epoch 35/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9937 - student_loss: 0.0196 - distillation_loss: 0.0236
# Epoch 35: val_categorical_accuracy did not improve from 0.99090
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9937 - student_loss: 0.0196 - distillation_loss: 0.0236 - val_categorical_accuracy: 0.9907 - val_student_loss: 0.0000e+00 - lr: 5.0314e-04
# Epoch 36/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9941 - student_loss: 0.0179 - distillation_loss: 0.0232
# Epoch 36: val_categorical_accuracy improved from 0.99090 to 0.99136, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9941 - student_loss: 0.0179 - distillation_loss: 0.0232 - val_categorical_accuracy: 0.9914 - val_student_loss: 0.0000e+00 - lr: 4.9307e-04
# Epoch 37/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9938 - student_loss: 0.0185 - distillation_loss: 0.0230
# Epoch 37: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 158s 23ms/step - categorical_accuracy: 0.9938 - student_loss: 0.0185 - distillation_loss: 0.0230 - val_categorical_accuracy: 0.9908 - val_student_loss: 0.0000e+00 - lr: 4.8321e-04
# Epoch 38/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9941 - student_loss: 0.0183 - distillation_loss: 0.0228
# Epoch 38: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9941 - student_loss: 0.0183 - distillation_loss: 0.0228 - val_categorical_accuracy: 0.9902 - val_student_loss: 0.0000e+00 - lr: 4.7355e-04
# Epoch 39/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9941 - student_loss: 0.0178 - distillation_loss: 0.0226
# Epoch 39: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9941 - student_loss: 0.0178 - distillation_loss: 0.0226 - val_categorical_accuracy: 0.9905 - val_student_loss: 0.0000e+00 - lr: 4.6408e-04
# Epoch 40/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9941 - student_loss: 0.0180 - distillation_loss: 0.0224
# Epoch 40: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9941 - student_loss: 0.0180 - distillation_loss: 0.0224 - val_categorical_accuracy: 0.9906 - val_student_loss: 0.0000e+00 - lr: 4.5480e-04
# Epoch 41/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9942 - student_loss: 0.0171 - distillation_loss: 0.0222
# Epoch 41: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9942 - student_loss: 0.0171 - distillation_loss: 0.0222 - val_categorical_accuracy: 0.9910 - val_student_loss: 0.0000e+00 - lr: 4.4570e-04
# Epoch 42/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9947 - student_loss: 0.0166 - distillation_loss: 0.0219
# Epoch 42: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9947 - student_loss: 0.0165 - distillation_loss: 0.0219 - val_categorical_accuracy: 0.9911 - val_student_loss: 0.0000e+00 - lr: 4.3679e-04
# Epoch 43/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9943 - student_loss: 0.0169 - distillation_loss: 0.0218
# Epoch 43: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9943 - student_loss: 0.0169 - distillation_loss: 0.0218 - val_categorical_accuracy: 0.9911 - val_student_loss: 0.0000e+00 - lr: 4.2805e-04
# Epoch 44/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9945 - student_loss: 0.0160 - distillation_loss: 0.0215
# Epoch 44: val_categorical_accuracy did not improve from 0.99136
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9945 - student_loss: 0.0160 - distillation_loss: 0.0215 - val_categorical_accuracy: 0.9913 - val_student_loss: 0.0000e+00 - lr: 4.1949e-04
# Epoch 45/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9945 - student_loss: 0.0160 - distillation_loss: 0.0213
# Epoch 45: val_categorical_accuracy improved from 0.99136 to 0.99154, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9945 - student_loss: 0.0160 - distillation_loss: 0.0213 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 4.1110e-04
# Epoch 46/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9946 - student_loss: 0.0157 - distillation_loss: 0.0212
# Epoch 46: val_categorical_accuracy improved from 0.99154 to 0.99158, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9946 - student_loss: 0.0157 - distillation_loss: 0.0212 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 4.0288e-04
# Epoch 47/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9945 - student_loss: 0.0157 - distillation_loss: 0.0210
# Epoch 47: val_categorical_accuracy did not improve from 0.99158
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9945 - student_loss: 0.0157 - distillation_loss: 0.0210 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 3.9482e-04
# Epoch 48/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9947 - student_loss: 0.0156 - distillation_loss: 0.0208
# Epoch 48: val_categorical_accuracy did not improve from 0.99158
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9947 - student_loss: 0.0155 - distillation_loss: 0.0208 - val_categorical_accuracy: 0.9914 - val_student_loss: 0.0000e+00 - lr: 3.8692e-04
# Epoch 49/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9949 - student_loss: 0.0153 - distillation_loss: 0.0206
# Epoch 49: val_categorical_accuracy did not improve from 0.99158
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9949 - student_loss: 0.0153 - distillation_loss: 0.0206 - val_categorical_accuracy: 0.9906 - val_student_loss: 0.0000e+00 - lr: 3.7919e-04
# Epoch 50/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9949 - student_loss: 0.0149 - distillation_loss: 0.0203
# Epoch 50: val_categorical_accuracy did not improve from 0.99158
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9949 - student_loss: 0.0149 - distillation_loss: 0.0203 - val_categorical_accuracy: 0.9911 - val_student_loss: 0.0000e+00 - lr: 3.7160e-04
# Epoch 51/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9949 - student_loss: 0.0151 - distillation_loss: 0.0204
# Epoch 51: val_categorical_accuracy did not improve from 0.99158
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9949 - student_loss: 0.0151 - distillation_loss: 0.0204 - val_categorical_accuracy: 0.9910 - val_student_loss: 0.0000e+00 - lr: 3.6417e-04
# Epoch 52/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9948 - student_loss: 0.0148 - distillation_loss: 0.0201
# Epoch 52: val_categorical_accuracy did not improve from 0.99158
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9948 - student_loss: 0.0148 - distillation_loss: 0.0201 - val_categorical_accuracy: 0.9911 - val_student_loss: 0.0000e+00 - lr: 3.5689e-04
# Epoch 53/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9951 - student_loss: 0.0142 - distillation_loss: 0.0200
# Epoch 53: val_categorical_accuracy improved from 0.99158 to 0.99161, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9951 - student_loss: 0.0142 - distillation_loss: 0.0200 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0455 - lr: 3.4975e-04
# Epoch 54/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9953 - student_loss: 0.0139 - distillation_loss: 0.0199
# Epoch 54: val_categorical_accuracy improved from 0.99161 to 0.99204, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9953 - student_loss: 0.0139 - distillation_loss: 0.0199 - val_categorical_accuracy: 0.9920 - val_student_loss: 0.0000e+00 - lr: 3.4275e-04
# Epoch 55/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9952 - student_loss: 0.0141 - distillation_loss: 0.0197
# Epoch 55: val_categorical_accuracy did not improve from 0.99204
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9952 - student_loss: 0.0141 - distillation_loss: 0.0197 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 3.3590e-04
# Epoch 56/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9952 - student_loss: 0.0142 - distillation_loss: 0.0196
# Epoch 56: val_categorical_accuracy did not improve from 0.99204
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9952 - student_loss: 0.0142 - distillation_loss: 0.0196 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 3.2918e-04
# Epoch 57/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9953 - student_loss: 0.0134 - distillation_loss: 0.0196
# Epoch 57: val_categorical_accuracy did not improve from 0.99204
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9953 - student_loss: 0.0134 - distillation_loss: 0.0196 - val_categorical_accuracy: 0.9917 - val_student_loss: 0.0000e+00 - lr: 3.2260e-04
# Epoch 58/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9952 - student_loss: 0.0136 - distillation_loss: 0.0193
# Epoch 58: val_categorical_accuracy did not improve from 0.99204
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9952 - student_loss: 0.0136 - distillation_loss: 0.0193 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 3.1614e-04
# Epoch 59/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9953 - student_loss: 0.0133 - distillation_loss: 0.0193
# Epoch 59: val_categorical_accuracy did not improve from 0.99204
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9953 - student_loss: 0.0133 - distillation_loss: 0.0193 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 3.0982e-04
# Epoch 60/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9955 - student_loss: 0.0132 - distillation_loss: 0.0191
# Epoch 60: val_categorical_accuracy did not improve from 0.99204
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9955 - student_loss: 0.0131 - distillation_loss: 0.0191 - val_categorical_accuracy: 0.9914 - val_student_loss: 0.0000e+00 - lr: 3.0363e-04
# Epoch 61/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9955 - student_loss: 0.0125 - distillation_loss: 0.0190
# Epoch 61: val_categorical_accuracy improved from 0.99204 to 0.99215, saving model to output/eff100dist_best.h5
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9955 - student_loss: 0.0125 - distillation_loss: 0.0190 - val_categorical_accuracy: 0.9921 - val_student_loss: 0.0000e+00 - lr: 2.9755e-04
# Epoch 62/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9957 - student_loss: 0.0129 - distillation_loss: 0.0189
# Epoch 62: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9957 - student_loss: 0.0129 - distillation_loss: 0.0189 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 2.9160e-04
# Epoch 63/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9953 - student_loss: 0.0129 - distillation_loss: 0.0189
# Epoch 63: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9953 - student_loss: 0.0129 - distillation_loss: 0.0189 - val_categorical_accuracy: 0.9918 - val_student_loss: 0.0000e+00 - lr: 2.8577e-04
# Epoch 64/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9956 - student_loss: 0.0126 - distillation_loss: 0.0186
# Epoch 64: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 165s 24ms/step - categorical_accuracy: 0.9956 - student_loss: 0.0126 - distillation_loss: 0.0186 - val_categorical_accuracy: 0.9914 - val_student_loss: 0.0000e+00 - lr: 2.8005e-04
# Epoch 65/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9958 - student_loss: 0.0123 - distillation_loss: 0.0187
# Epoch 65: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 165s 24ms/step - categorical_accuracy: 0.9958 - student_loss: 0.0123 - distillation_loss: 0.0187 - val_categorical_accuracy: 0.9914 - val_student_loss: 0.0000e+00 - lr: 2.7445e-04
# Epoch 66/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9957 - student_loss: 0.0124 - distillation_loss: 0.0186
# Epoch 66: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 164s 23ms/step - categorical_accuracy: 0.9957 - student_loss: 0.0124 - distillation_loss: 0.0185 - val_categorical_accuracy: 0.9919 - val_student_loss: 0.0000e+00 - lr: 2.6896e-04
# Epoch 67/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9957 - student_loss: 0.0125 - distillation_loss: 0.0184
# Epoch 67: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9957 - student_loss: 0.0125 - distillation_loss: 0.0184 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 2.6359e-04
# Epoch 68/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9958 - student_loss: 0.0119 - distillation_loss: 0.0184
# Epoch 68: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 165s 23ms/step - categorical_accuracy: 0.9958 - student_loss: 0.0119 - distillation_loss: 0.0184 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 2.5831e-04
# Epoch 69/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9956 - student_loss: 0.0128 - distillation_loss: 0.0183
# Epoch 69: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 165s 23ms/step - categorical_accuracy: 0.9956 - student_loss: 0.0128 - distillation_loss: 0.0183 - val_categorical_accuracy: 0.9918 - val_student_loss: 0.0000e+00 - lr: 2.5315e-04
# Epoch 70/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9956 - student_loss: 0.0121 - distillation_loss: 0.0182
# Epoch 70: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 166s 24ms/step - categorical_accuracy: 0.9956 - student_loss: 0.0121 - distillation_loss: 0.0182 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 2.4808e-04
# Epoch 71/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9958 - student_loss: 0.0116 - distillation_loss: 0.0181
# Epoch 71: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9958 - student_loss: 0.0116 - distillation_loss: 0.0181 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0011 - lr: 2.4312e-04
# Epoch 72/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9958 - student_loss: 0.0114 - distillation_loss: 0.0181
# Epoch 72: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9958 - student_loss: 0.0114 - distillation_loss: 0.0181 - val_categorical_accuracy: 0.9918 - val_student_loss: 0.0000e+00 - lr: 2.3826e-04
# Epoch 73/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9957 - student_loss: 0.0120 - distillation_loss: 0.0179
# Epoch 73: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9957 - student_loss: 0.0120 - distillation_loss: 0.0179 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 2.3349e-04
# Epoch 74/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9959 - student_loss: 0.0115 - distillation_loss: 0.0178
# Epoch 74: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9959 - student_loss: 0.0115 - distillation_loss: 0.0178 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 2.2883e-04
# Epoch 75/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9959 - student_loss: 0.0115 - distillation_loss: 0.0178
# Epoch 75: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9959 - student_loss: 0.0115 - distillation_loss: 0.0178 - val_categorical_accuracy: 0.9917 - val_student_loss: 0.0000e+00 - lr: 2.2425e-04
# Epoch 76/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9961 - student_loss: 0.0110 - distillation_loss: 0.0177
# Epoch 76: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9961 - student_loss: 0.0110 - distillation_loss: 0.0177 - val_categorical_accuracy: 0.9919 - val_student_loss: 0.0000e+00 - lr: 2.1976e-04
# Epoch 77/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9961 - student_loss: 0.0110 - distillation_loss: 0.0177
# Epoch 77: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9961 - student_loss: 0.0110 - distillation_loss: 0.0177 - val_categorical_accuracy: 0.9915 - val_student_loss: 0.0000e+00 - lr: 2.1537e-04
# Epoch 78/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9959 - student_loss: 0.0110 - distillation_loss: 0.0176
# Epoch 78: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 158s 23ms/step - categorical_accuracy: 0.9959 - student_loss: 0.0110 - distillation_loss: 0.0176 - val_categorical_accuracy: 0.9907 - val_student_loss: 0.0000e+00 - lr: 2.1106e-04
# Epoch 79/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9960 - student_loss: 0.0113 - distillation_loss: 0.0175
# Epoch 79: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 157s 22ms/step - categorical_accuracy: 0.9960 - student_loss: 0.0113 - distillation_loss: 0.0175 - val_categorical_accuracy: 0.9913 - val_student_loss: 1.1779 - lr: 2.0684e-04
# Epoch 80/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9961 - student_loss: 0.0109 - distillation_loss: 0.0175
# Epoch 80: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 157s 22ms/step - categorical_accuracy: 0.9961 - student_loss: 0.0109 - distillation_loss: 0.0175 - val_categorical_accuracy: 0.9918 - val_student_loss: 0.0000e+00 - lr: 2.0270e-04
# Epoch 81/400
# 7002/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9962 - student_loss: 0.0105 - distillation_loss: 0.0174
# Epoch 81: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 163s 23ms/step - categorical_accuracy: 0.9962 - student_loss: 0.0105 - distillation_loss: 0.0174 - val_categorical_accuracy: 0.9921 - val_student_loss: 0.0000e+00 - lr: 1.9865e-04
# Epoch 82/400
# 7003/7004 [============================>.] - ETA: 0s - categorical_accuracy: 0.9961 - student_loss: 0.0107 - distillation_loss: 0.0173
# Epoch 82: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 164s 23ms/step - categorical_accuracy: 0.9961 - student_loss: 0.0107 - distillation_loss: 0.0173 - val_categorical_accuracy: 0.9916 - val_student_loss: 0.0000e+00 - lr: 1.9468e-04
# Epoch 83/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9963 - student_loss: 0.0103 - distillation_loss: 0.0173
# Epoch 83: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 162s 23ms/step - categorical_accuracy: 0.9963 - student_loss: 0.0103 - distillation_loss: 0.0173 - val_categorical_accuracy: 0.9919 - val_student_loss: 0.0000e+00 - lr: 1.9078e-04
# Epoch 84/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9965 - student_loss: 0.0101 - distillation_loss: 0.0172
# Epoch 84: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 161s 23ms/step - categorical_accuracy: 0.9965 - student_loss: 0.0101 - distillation_loss: 0.0172 - val_categorical_accuracy: 0.9918 - val_student_loss: 0.0000e+00 - lr: 1.8697e-04
# Epoch 85/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9963 - student_loss: 0.0104 - distillation_loss: 0.0172
# Epoch 85: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9963 - student_loss: 0.0104 - distillation_loss: 0.0172 - val_categorical_accuracy: 0.9921 - val_student_loss: 0.0000e+00 - lr: 1.8323e-04
# Epoch 86/400
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9964 - student_loss: 0.0100 - distillation_loss: 0.0171Restoring model weights from the end of the best epoch: 61.
#
# Epoch 86: val_categorical_accuracy did not improve from 0.99215
# 7004/7004 [==============================] - 160s 23ms/step - categorical_accuracy: 0.9964 - student_loss: 0.0100 - distillation_loss: 0.0171 - val_categorical_accuracy: 0.9919 - val_student_loss: 0.0000e+00 - lr: 1.7956e-04
# Epoch 86: early stopping

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
# Out:
# 2022-06-14 19:20:44.593663: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 12477. 81 false predicted. Accuracy is: 0.9935080548208705

# %% [markdown]
# ### 2nd train
#
# Now the model will be trained like transfer learning <https://keras.io/guides/transfer_learning/>.
#
# All layers except the top layer will be fixed and not trained in the 2nd training.
#
# As dataset the digit meter images are used.

# %%
import numpy as np

model = keras.models.load_model(model_filename + '_dist.h5')

# now whith meter digits
train_iterator = augmentation(xz_train, yz_train)
validation_iterator = no_augmentation(xz_test, yz_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator) 

# only the last layer is now trainable
for layer in model.layers[:-1]:
    layer.trainable=False

mc = ModelCheckpoint(model_filename + '_best_transfer.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

history = distiller.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = 20,
                callbacks=[annealer, earlystop, mc],
                verbose=2)


model.save(model_filename + "_dist_transfer.h5")

plot_acc_loss(history, "Trainingsresults")
# Out:
# Train data
# Validation data
# Epoch 1/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.7017 - student_loss: 0.4648 - distillation_loss: 0.0866 - val_categorical_accuracy: 0.8061 - val_student_loss: 0.5867 - lr: 0.0010 - 7s/epoch - 22ms/step
# Epoch 2/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.7982 - student_loss: 0.8040 - distillation_loss: 0.0748 - val_categorical_accuracy: 0.8165 - val_student_loss: 0.8176 - lr: 9.8000e-04 - 7s/epoch - 21ms/step
# Epoch 3/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8269 - student_loss: 0.2791 - distillation_loss: 0.0656 - val_categorical_accuracy: 0.8117 - val_student_loss: 0.2910 - lr: 9.6040e-04 - 7s/epoch - 22ms/step
# Epoch 4/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8360 - student_loss: 0.5682 - distillation_loss: 0.0682 - val_categorical_accuracy: 0.8321 - val_student_loss: 0.3261 - lr: 9.4119e-04 - 7s/epoch - 21ms/step
# Epoch 5/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8456 - student_loss: 0.2025 - distillation_loss: 0.0524 - val_categorical_accuracy: 0.8361 - val_student_loss: 0.7098 - lr: 9.2237e-04 - 7s/epoch - 21ms/step
# Epoch 6/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8527 - student_loss: 0.4642 - distillation_loss: 0.0609 - val_categorical_accuracy: 0.8261 - val_student_loss: 0.7268 - lr: 9.0392e-04 - 7s/epoch - 22ms/step
# Epoch 7/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8559 - student_loss: 0.5051 - distillation_loss: 0.0613 - val_categorical_accuracy: 0.8421 - val_student_loss: 0.6312 - lr: 8.8584e-04 - 7s/epoch - 21ms/step
# Epoch 8/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8609 - student_loss: 0.4124 - distillation_loss: 0.0636 - val_categorical_accuracy: 0.8289 - val_student_loss: 0.3026 - lr: 8.6813e-04 - 7s/epoch - 21ms/step
# Epoch 9/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8675 - student_loss: 0.5309 - distillation_loss: 0.0525 - val_categorical_accuracy: 0.8329 - val_student_loss: 0.5195 - lr: 8.5076e-04 - 7s/epoch - 22ms/step
# Epoch 10/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8703 - student_loss: 0.3097 - distillation_loss: 0.0604 - val_categorical_accuracy: 0.8301 - val_student_loss: 0.5379 - lr: 8.3375e-04 - 7s/epoch - 21ms/step
# Epoch 11/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8703 - student_loss: 0.3821 - distillation_loss: 0.0508 - val_categorical_accuracy: 0.8305 - val_student_loss: 0.4418 - lr: 8.1707e-04 - 7s/epoch - 21ms/step
# Epoch 12/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8728 - student_loss: 0.3579 - distillation_loss: 0.0561 - val_categorical_accuracy: 0.8385 - val_student_loss: 0.5098 - lr: 8.0073e-04 - 7s/epoch - 21ms/step
# Epoch 13/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8807 - student_loss: 0.5076 - distillation_loss: 0.0445 - val_categorical_accuracy: 0.8369 - val_student_loss: 0.2785 - lr: 7.8472e-04 - 7s/epoch - 21ms/step
# Epoch 14/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8812 - student_loss: 0.3009 - distillation_loss: 0.0422 - val_categorical_accuracy: 0.8377 - val_student_loss: 0.8909 - lr: 7.6902e-04 - 7s/epoch - 21ms/step
# Epoch 15/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8781 - student_loss: 0.2740 - distillation_loss: 0.0561 - val_categorical_accuracy: 0.8381 - val_student_loss: 0.8330 - lr: 7.5364e-04 - 7s/epoch - 21ms/step
# Epoch 16/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8801 - student_loss: 0.2862 - distillation_loss: 0.0428 - val_categorical_accuracy: 0.8321 - val_student_loss: 0.8322 - lr: 7.3857e-04 - 7s/epoch - 21ms/step
# Epoch 17/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8819 - student_loss: 0.5793 - distillation_loss: 0.0425 - val_categorical_accuracy: 0.8458 - val_student_loss: 0.8715 - lr: 7.2380e-04 - 7s/epoch - 21ms/step
# Epoch 18/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8900 - student_loss: 0.1515 - distillation_loss: 0.0527 - val_categorical_accuracy: 0.8305 - val_student_loss: 0.3906 - lr: 7.0932e-04 - 7s/epoch - 21ms/step
# Epoch 19/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8888 - student_loss: 0.2064 - distillation_loss: 0.0599 - val_categorical_accuracy: 0.8429 - val_student_loss: 0.4152 - lr: 6.9514e-04 - 7s/epoch - 21ms/step
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 312/312 - 7s - categorical_accuracy: 0.8903 - student_loss: 0.3811 - distillation_loss: 0.0470 - val_categorical_accuracy: 0.8357 - val_student_loss: 0.5684 - lr: 6.8123e-04 - 7s/epoch - 21ms/step

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
# Out:
# 2022-06-14 19:23:07.029343: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 12477. 81 false predicted. Accuracy is: 0.9935080548208705
