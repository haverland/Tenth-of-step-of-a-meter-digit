# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with mixed data digit images and TMNIST percental images.
# The best model will be stored as "cnn3-best.h5"
#
# ### 2nd train
#
# Runs only on the last layer again. The convolutional layers will not trained.
#
# ### The Model
#
# Used a smaller variant of Efficientnet (effnet) network as small model.
#
# <https://github.com/arthurdouillard/keras-effnet>

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 40                      # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "output/eff100dist"
teacher_filename = "output/cnn32_best_transfer.h5"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *

# %% [markdown]
# ####

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
#
# ### Percental TMNIST
#
# 300.000 images of type face fonts in 0.1 steps from 0.0 to 9.9
#
# See https://www.kaggle.com/datasets/frankhaverland/percentile-tmnist-for-electric-meters
#
#
# ## Train and Test data
#
# For 1st train both dataset mixed are used.
#
# ### digit meter spread
#
# The percental TMNIST has for every label the same count of data.
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
xz_train, xz_test, yz_train, yz_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)


xt_data, yt_data = tmnist_percentals()

# mixing the datasets
x_data = np.concatenate((xt_data, xz_train))
y_data = np.concatenate((yt_data, yz_train))
x_data, y_data = shuffle(x_data, y_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)

input_shape=x_train[0].shape
print(f"dataset x_train-size={len(x_train)}")
plot_dataset(x_train, y_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)

yz_train = class_encoding(yz_train, nb_classes)
yz_test = class_encoding(yz_test, nb_classes)
# Out:
# Ziffer data count:  12477
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-06-13 13:09:10.867119: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-13 13:09:10.867259: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# dataset x_train-size=224128

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
# Spot light is not used. It makes the train difficult without better results.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train, preprocessing_function=invert_noise)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet

teacher = keras.models.load_model(teacher_filename)
teacher._name = "Teacher_" + teacher._name

student = Effnet(input_shape, nb_classes, activation_top=None)
student._name="Effnet"

student.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

distiller = Distiller(student=student, teacher=teacher)
distiller._name = student._name
distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.CategoricalAccuracy()],
    student_loss_fn=keras.losses.CategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)

# %% [markdown]
# ### The Training
#
# The pre_trained teacher model helps to improve the training of the student model.
#
# See <https://keras.io/examples/vision/knowledge_distillation/>
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_categorical_accuracy', mode='max' , patience=25, verbose=1, baseline=0.04, restore_best_weights=True)
#mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

history = distiller.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[annealer, earlystop],
                verbose=1)

model = distiller.student

model.save(model_filename + '_dist.h5')

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/40
# 2022-06-13 13:09:36.004925: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-13 13:09:36.677160: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 7004/7004 [==============================] - ETA: 0s - categorical_accuracy: 0.9438 - student_loss: 0.3554 - distillation_loss: 0.2322
# 2022-06-13 13:11:58.282083: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 7004/7004 [==============================] - 155s 22ms/step - categorical_accuracy: 0.9438 - student_loss: 0.3554 - distillation_loss: 0.2322 - val_categorical_accuracy: 0.9689 - val_student_loss: 0.0000e+00 - lr: 0.0010
# Epoch 2/40
# 7004/7004 [==============================] - 154s 22ms/step - categorical_accuracy: 0.9735 - student_loss: 0.1460 - distillation_loss: 0.0911 - val_categorical_accuracy: 0.9782 - val_student_loss: 0.0000e+00 - lr: 9.8000e-04
# Epoch 3/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9788 - student_loss: 0.1079 - distillation_loss: 0.0720 - val_categorical_accuracy: 0.9813 - val_student_loss: 1.6694 - lr: 9.6040e-04
# Epoch 4/40
# 7004/7004 [==============================] - 151s 22ms/step - categorical_accuracy: 0.9818 - student_loss: 0.0844 - distillation_loss: 0.0620 - val_categorical_accuracy: 0.9822 - val_student_loss: 0.0000e+00 - lr: 9.4119e-04
# Epoch 5/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9839 - student_loss: 0.0717 - distillation_loss: 0.0550 - val_categorical_accuracy: 0.9844 - val_student_loss: 0.0000e+00 - lr: 9.2237e-04
# Epoch 6/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9854 - student_loss: 0.0620 - distillation_loss: 0.0505 - val_categorical_accuracy: 0.9845 - val_student_loss: 0.0000e+00 - lr: 9.0392e-04
# Epoch 7/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9863 - student_loss: 0.0563 - distillation_loss: 0.0470 - val_categorical_accuracy: 0.9847 - val_student_loss: 0.0000e+00 - lr: 8.8584e-04
# Epoch 8/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9869 - student_loss: 0.0523 - distillation_loss: 0.0443 - val_categorical_accuracy: 0.9855 - val_student_loss: 0.0000e+00 - lr: 8.6813e-04
# Epoch 9/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9877 - student_loss: 0.0476 - distillation_loss: 0.0420 - val_categorical_accuracy: 0.9881 - val_student_loss: 0.0000e+00 - lr: 8.5076e-04
# Epoch 10/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9884 - student_loss: 0.0445 - distillation_loss: 0.0401 - val_categorical_accuracy: 0.9886 - val_student_loss: 0.0000e+00 - lr: 8.3375e-04
# Epoch 11/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9890 - student_loss: 0.0415 - distillation_loss: 0.0384 - val_categorical_accuracy: 0.9872 - val_student_loss: 1.6526e-07 - lr: 8.1707e-04
# Epoch 12/40
# 7004/7004 [==============================] - 150s 21ms/step - categorical_accuracy: 0.9890 - student_loss: 0.0400 - distillation_loss: 0.0373 - val_categorical_accuracy: 0.9886 - val_student_loss: 0.0000e+00 - lr: 8.0073e-04
# Epoch 13/40
# 7004/7004 [==============================] - 149s 21ms/step - categorical_accuracy: 0.9895 - student_loss: 0.0379 - distillation_loss: 0.0358 - val_categorical_accuracy: 0.9876 - val_student_loss: 0.0000e+00 - lr: 7.8472e-04
# Epoch 14/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9898 - student_loss: 0.0363 - distillation_loss: 0.0348 - val_categorical_accuracy: 0.9882 - val_student_loss: 0.0000e+00 - lr: 7.6902e-04
# Epoch 15/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9905 - student_loss: 0.0330 - distillation_loss: 0.0336 - val_categorical_accuracy: 0.9893 - val_student_loss: 0.0000e+00 - lr: 7.5364e-04
# Epoch 16/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9907 - student_loss: 0.0345 - distillation_loss: 0.0328 - val_categorical_accuracy: 0.9888 - val_student_loss: 0.0000e+00 - lr: 7.3857e-04
# Epoch 17/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9909 - student_loss: 0.0314 - distillation_loss: 0.0319 - val_categorical_accuracy: 0.9890 - val_student_loss: 0.0000e+00 - lr: 7.2380e-04
# Epoch 18/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9912 - student_loss: 0.0294 - distillation_loss: 0.0312 - val_categorical_accuracy: 0.9896 - val_student_loss: 0.0000e+00 - lr: 7.0932e-04
# Epoch 19/40
# 7004/7004 [==============================] - 159s 23ms/step - categorical_accuracy: 0.9916 - student_loss: 0.0283 - distillation_loss: 0.0304 - val_categorical_accuracy: 0.9888 - val_student_loss: 0.0000e+00 - lr: 6.9514e-04
# Epoch 20/40
# 7004/7004 [==============================] - 155s 22ms/step - categorical_accuracy: 0.9915 - student_loss: 0.0292 - distillation_loss: 0.0300 - val_categorical_accuracy: 0.9893 - val_student_loss: 0.0000e+00 - lr: 6.8123e-04
# Epoch 21/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9919 - student_loss: 0.0273 - distillation_loss: 0.0293 - val_categorical_accuracy: 0.9898 - val_student_loss: 0.0000e+00 - lr: 6.6761e-04
# Epoch 22/40
# 7004/7004 [==============================] - 150s 21ms/step - categorical_accuracy: 0.9919 - student_loss: 0.0260 - distillation_loss: 0.0287 - val_categorical_accuracy: 0.9900 - val_student_loss: 0.0000e+00 - lr: 6.5426e-04
# Epoch 23/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9923 - student_loss: 0.0256 - distillation_loss: 0.0282 - val_categorical_accuracy: 0.9895 - val_student_loss: 0.0000e+00 - lr: 6.4117e-04
# Epoch 24/40
# 7004/7004 [==============================] - 151s 22ms/step - categorical_accuracy: 0.9925 - student_loss: 0.0245 - distillation_loss: 0.0278 - val_categorical_accuracy: 0.9897 - val_student_loss: 0.0000e+00 - lr: 6.2835e-04
# Epoch 25/40
# 7004/7004 [==============================] - 151s 22ms/step - categorical_accuracy: 0.9925 - student_loss: 0.0245 - distillation_loss: 0.0273 - val_categorical_accuracy: 0.9895 - val_student_loss: 0.0000e+00 - lr: 6.1578e-04
# Epoch 26/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9927 - student_loss: 0.0231 - distillation_loss: 0.0270 - val_categorical_accuracy: 0.9900 - val_student_loss: 0.0000e+00 - lr: 6.0346e-04
# Epoch 27/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9926 - student_loss: 0.0231 - distillation_loss: 0.0266 - val_categorical_accuracy: 0.9900 - val_student_loss: 0.0000e+00 - lr: 5.9140e-04
# Epoch 28/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9930 - student_loss: 0.0222 - distillation_loss: 0.0261 - val_categorical_accuracy: 0.9911 - val_student_loss: 0.0000e+00 - lr: 5.7957e-04
# Epoch 29/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9931 - student_loss: 0.0216 - distillation_loss: 0.0258 - val_categorical_accuracy: 0.9903 - val_student_loss: 0.0000e+00 - lr: 5.6798e-04
# Epoch 30/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9932 - student_loss: 0.0213 - distillation_loss: 0.0256 - val_categorical_accuracy: 0.9897 - val_student_loss: 0.0000e+00 - lr: 5.5662e-04
# Epoch 31/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9933 - student_loss: 0.0214 - distillation_loss: 0.0252 - val_categorical_accuracy: 0.9907 - val_student_loss: 0.0000e+00 - lr: 5.4548e-04
# Epoch 32/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9934 - student_loss: 0.0208 - distillation_loss: 0.0249 - val_categorical_accuracy: 0.9911 - val_student_loss: 0.0000e+00 - lr: 5.3457e-04
# Epoch 33/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9935 - student_loss: 0.0201 - distillation_loss: 0.0246 - val_categorical_accuracy: 0.9902 - val_student_loss: 0.0000e+00 - lr: 5.2388e-04
# Epoch 34/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9936 - student_loss: 0.0199 - distillation_loss: 0.0243 - val_categorical_accuracy: 0.9908 - val_student_loss: 0.0000e+00 - lr: 5.1341e-04
# Epoch 35/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9938 - student_loss: 0.0186 - distillation_loss: 0.0241 - val_categorical_accuracy: 0.9903 - val_student_loss: 0.0000e+00 - lr: 5.0314e-04
# Epoch 36/40
# 7004/7004 [==============================] - 153s 22ms/step - categorical_accuracy: 0.9937 - student_loss: 0.0193 - distillation_loss: 0.0236 - val_categorical_accuracy: 0.9909 - val_student_loss: 0.0000e+00 - lr: 4.9307e-04
# Epoch 37/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9938 - student_loss: 0.0189 - distillation_loss: 0.0235 - val_categorical_accuracy: 0.9910 - val_student_loss: 0.0000e+00 - lr: 4.8321e-04
# Epoch 38/40
# 7004/7004 [==============================] - 152s 22ms/step - categorical_accuracy: 0.9938 - student_loss: 0.0184 - distillation_loss: 0.0233 - val_categorical_accuracy: 0.9913 - val_student_loss: 2.4789e-07 - lr: 4.7355e-04
# Epoch 39/40
# 7004/7004 [==============================] - 150s 21ms/step - categorical_accuracy: 0.9942 - student_loss: 0.0175 - distillation_loss: 0.0230 - val_categorical_accuracy: 0.9907 - val_student_loss: 0.0000e+00 - lr: 4.6408e-04
# Epoch 40/40
# 7004/7004 [==============================] - 151s 22ms/step - categorical_accuracy: 0.9942 - student_loss: 0.0174 - distillation_loss: 0.0227 - val_categorical_accuracy: 0.9906 - val_student_loss: 0.0000e+00 - lr: 4.5480e-04

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
# Out:
# 2022-06-13 14:50:51.575528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 12477. 151 false predicted. Accuracy is: 0.9878977318265608

# %% [markdown]
# ### 2nd train
#
# Now the model will be trained like transfer learning <https://keras.io/guides/transfer_learning/>.
#
# All layers except the top layer will be fixed and not trained in the 2nd training.
#
# As dataset the digit meter images are used.

# %%
import numpy as np

model = keras.models.load_model(model_filename + '_dist.h5')

# now whith meter digits
train_iterator = augmentation(xz_train, yz_train)
validation_iterator = no_augmentation(xz_test, yz_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator) 

# only the last layer is now trainable
for layer in model.layers[:-1]:
    layer.trainable=False

#mc = ModelCheckpoint(model_filename + '_best_transfer.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

history = distiller.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = 20,
                callbacks=[annealer, earlystop],
                verbose=2)


model.save(model_filename + "_dist_transfer.h5")

plot_acc_loss(history, "Trainingsresults")
# Out:
# Train data
# Validation data
# Epoch 1/20
# 312/312 - 9s - categorical_accuracy: 0.7069 - student_loss: 0.9633 - distillation_loss: 0.0781 - val_categorical_accuracy: 0.7829 - val_student_loss: 0.4899 - lr: 0.0010 - 9s/epoch - 28ms/step
# Epoch 2/20
# 312/312 - 7s - categorical_accuracy: 0.8050 - student_loss: 0.6505 - distillation_loss: 0.0695 - val_categorical_accuracy: 0.8085 - val_student_loss: 0.5421 - lr: 9.8000e-04 - 7s/epoch - 21ms/step
# Epoch 3/20
# 312/312 - 6s - categorical_accuracy: 0.8218 - student_loss: 0.3343 - distillation_loss: 0.0629 - val_categorical_accuracy: 0.8033 - val_student_loss: 0.2403 - lr: 9.6040e-04 - 6s/epoch - 20ms/step
# Epoch 4/20
# 312/312 - 7s - categorical_accuracy: 0.8323 - student_loss: 0.4837 - distillation_loss: 0.0694 - val_categorical_accuracy: 0.8145 - val_student_loss: 0.6060 - lr: 9.4119e-04 - 7s/epoch - 21ms/step
# Epoch 5/20
# 312/312 - 6s - categorical_accuracy: 0.8446 - student_loss: 0.5121 - distillation_loss: 0.0619 - val_categorical_accuracy: 0.8121 - val_student_loss: 0.6887 - lr: 9.2237e-04 - 6s/epoch - 20ms/step
# Epoch 6/20
# 312/312 - 6s - categorical_accuracy: 0.8540 - student_loss: 0.4570 - distillation_loss: 0.0501 - val_categorical_accuracy: 0.8137 - val_student_loss: 0.6491 - lr: 9.0392e-04 - 6s/epoch - 20ms/step
# Epoch 7/20
# 312/312 - 6s - categorical_accuracy: 0.8538 - student_loss: 0.6073 - distillation_loss: 0.0573 - val_categorical_accuracy: 0.8213 - val_student_loss: 0.2336 - lr: 8.8584e-04 - 6s/epoch - 20ms/step
# Epoch 8/20
# 312/312 - 6s - categorical_accuracy: 0.8559 - student_loss: 0.3518 - distillation_loss: 0.0666 - val_categorical_accuracy: 0.8225 - val_student_loss: 0.2351 - lr: 8.6813e-04 - 6s/epoch - 20ms/step
# Epoch 9/20
# 312/312 - 6s - categorical_accuracy: 0.8605 - student_loss: 0.7270 - distillation_loss: 0.0527 - val_categorical_accuracy: 0.8161 - val_student_loss: 0.6371 - lr: 8.5076e-04 - 6s/epoch - 20ms/step
# Epoch 10/20
# 312/312 - 7s - categorical_accuracy: 0.8683 - student_loss: 0.2678 - distillation_loss: 0.0445 - val_categorical_accuracy: 0.8225 - val_student_loss: 0.4034 - lr: 8.3375e-04 - 7s/epoch - 21ms/step
# Epoch 11/20
# 312/312 - 6s - categorical_accuracy: 0.8672 - student_loss: 0.1767 - distillation_loss: 0.0412 - val_categorical_accuracy: 0.8225 - val_student_loss: 0.7830 - lr: 8.1707e-04 - 6s/epoch - 20ms/step
# Epoch 12/20
# 312/312 - 6s - categorical_accuracy: 0.8801 - student_loss: 0.4131 - distillation_loss: 0.0566 - val_categorical_accuracy: 0.8225 - val_student_loss: 0.6906 - lr: 8.0073e-04 - 6s/epoch - 20ms/step
# Epoch 13/20
# 312/312 - 6s - categorical_accuracy: 0.8769 - student_loss: 0.1726 - distillation_loss: 0.0458 - val_categorical_accuracy: 0.8189 - val_student_loss: 0.7489 - lr: 7.8472e-04 - 6s/epoch - 21ms/step
# Epoch 14/20
# 312/312 - 6s - categorical_accuracy: 0.8790 - student_loss: 0.1932 - distillation_loss: 0.0520 - val_categorical_accuracy: 0.8225 - val_student_loss: 0.2749 - lr: 7.6902e-04 - 6s/epoch - 21ms/step
# Epoch 15/20
# 312/312 - 6s - categorical_accuracy: 0.8815 - student_loss: 0.5116 - distillation_loss: 0.0563 - val_categorical_accuracy: 0.8245 - val_student_loss: 0.4602 - lr: 7.5364e-04 - 6s/epoch - 20ms/step
# Epoch 16/20
# 312/312 - 6s - categorical_accuracy: 0.8794 - student_loss: 0.3621 - distillation_loss: 0.0544 - val_categorical_accuracy: 0.8261 - val_student_loss: 0.3678 - lr: 7.3857e-04 - 6s/epoch - 20ms/step
# Epoch 17/20
# 312/312 - 6s - categorical_accuracy: 0.8806 - student_loss: 0.3252 - distillation_loss: 0.0493 - val_categorical_accuracy: 0.8269 - val_student_loss: 0.6052 - lr: 7.2380e-04 - 6s/epoch - 20ms/step
# Epoch 18/20
# 312/312 - 6s - categorical_accuracy: 0.8881 - student_loss: 0.3054 - distillation_loss: 0.0551 - val_categorical_accuracy: 0.8217 - val_student_loss: 0.4898 - lr: 7.0932e-04 - 6s/epoch - 20ms/step
# Epoch 19/20
# 312/312 - 6s - categorical_accuracy: 0.8875 - student_loss: 0.2425 - distillation_loss: 0.0553 - val_categorical_accuracy: 0.8241 - val_student_loss: 0.7006 - lr: 6.9514e-04 - 6s/epoch - 20ms/step
# Epoch 20/20
# 312/312 - 6s - categorical_accuracy: 0.8861 - student_loss: 0.3939 - distillation_loss: 0.0508 - val_categorical_accuracy: 0.8209 - val_student_loss: 0.6784 - lr: 6.8123e-04 - 6s/epoch - 20ms/step

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
# Out:
# 2022-06-13 14:53:10.018013: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 12477. 151 false predicted. Accuracy is: 0.9878977318265608
