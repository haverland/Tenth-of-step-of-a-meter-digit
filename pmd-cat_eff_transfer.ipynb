# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with mixed data digit images and TMNIST percental images.
# The best model will be stored as "eff100-best.h5"
#
# ### 2nd train
#
# Runs only on the last layer again. The convolutional layers will not trained.
#
# ## The Model
#
# Used a smaller variant of Efficientnet (effnet) network as small model.
#
# <https://github.com/arthurdouillard/keras-effnet>

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 40                      # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "output/eff100"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
#
# ### Percental TMNIST
#
# 300.000 images of type face fonts in 0.1 steps from 0.0 to 9.9
#
# See https://www.kaggle.com/datasets/frankhaverland/percentile-tmnist-for-electric-meters
#
#
# ### Train and Test data
#
# For 1st train both dataset mixed are used.
#
# ### digit meter spread
#
# The percental TMNIST has for every label the same count of data.
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
xz_train, xz_test, yz_train, yz_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)


xt_data, yt_data = tmnist_percentals()

# mixing the datasets
x_data = np.concatenate((xt_data, xz_train))
y_data = np.concatenate((yt_data, yz_train))
x_data, y_data = shuffle(x_data, y_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)

input_shape=x_train[0].shape
print(f"dataset x_train-size={len(x_train)}")
plot_dataset(x_train, y_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)

yz_train = class_encoding(yz_train, nb_classes)
yz_test = class_encoding(yz_test, nb_classes)
# Out:
# Ziffer data count:  12477
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-06-14 22:20:41.462474: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-14 22:20:41.462592: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# dataset x_train-size=224128

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
# Spot light is not used. It makes the train difficult without better results.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train, preprocessing_function=invert_noise)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet

model = Effnet(input_shape, nb_classes, activation_top=None)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

# %% [markdown]
# ### The Training
#
# Standard training of the model with complete dataset.
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.98 ** x, verbose=0)
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=20, verbose=1, baseline=0.04, restore_best_weights=True)
mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[annealer, earlystop, mc],
                verbose=1)


model.save(model_filename + '.h5')

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/40
# 2022-06-12 20:26:42.763753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 7005/7005 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.9182
# 2022-06-12 20:28:36.634867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.96577, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.3138 - accuracy: 0.9182 - val_loss: 0.1144 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 2/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9654
# Epoch 2: val_accuracy improved from 0.96577 to 0.97552, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.1151 - accuracy: 0.9654 - val_loss: 0.0772 - val_accuracy: 0.9755 - lr: 9.8000e-04
# Epoch 3/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0853 - accuracy: 0.9734
# Epoch 3: val_accuracy improved from 0.97552 to 0.97912, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0853 - accuracy: 0.9734 - val_loss: 0.0651 - val_accuracy: 0.9791 - lr: 9.6040e-04
# Epoch 4/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9778
# Epoch 4: val_accuracy improved from 0.97912 to 0.98010, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 130s 19ms/step - loss: 0.0697 - accuracy: 0.9778 - val_loss: 0.0625 - val_accuracy: 0.9801 - lr: 9.4119e-04
# Epoch 5/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9801
# Epoch 5: val_accuracy improved from 0.98010 to 0.98406, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0611 - accuracy: 0.9801 - val_loss: 0.0514 - val_accuracy: 0.9841 - lr: 9.2237e-04
# Epoch 6/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9823
# Epoch 6: val_accuracy improved from 0.98406 to 0.98480, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 129s 18ms/step - loss: 0.0536 - accuracy: 0.9823 - val_loss: 0.0484 - val_accuracy: 0.9848 - lr: 9.0392e-04
# Epoch 7/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0487 - accuracy: 0.9843
# Epoch 7: val_accuracy improved from 0.98480 to 0.98581, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0487 - accuracy: 0.9843 - val_loss: 0.0451 - val_accuracy: 0.9858 - lr: 8.8584e-04
# Epoch 8/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9852
# Epoch 8: val_accuracy did not improve from 0.98581
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0446 - accuracy: 0.9852 - val_loss: 0.0481 - val_accuracy: 0.9837 - lr: 8.6813e-04
# Epoch 9/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9864
# Epoch 9: val_accuracy improved from 0.98581 to 0.98597, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0421 - accuracy: 0.9864 - val_loss: 0.0417 - val_accuracy: 0.9860 - lr: 8.5076e-04
# Epoch 10/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9868
# Epoch 10: val_accuracy did not improve from 0.98597
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.0440 - val_accuracy: 0.9857 - lr: 8.3375e-04
# Epoch 11/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9878
# Epoch 11: val_accuracy improved from 0.98597 to 0.98769, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 129s 18ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 0.0396 - val_accuracy: 0.9877 - lr: 8.1707e-04
# Epoch 12/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9884
# Epoch 12: val_accuracy did not improve from 0.98769
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0350 - accuracy: 0.9884 - val_loss: 0.0424 - val_accuracy: 0.9874 - lr: 8.0073e-04
# Epoch 13/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9889
# Epoch 13: val_accuracy did not improve from 0.98769
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.0663 - val_accuracy: 0.9774 - lr: 7.8472e-04
# Epoch 14/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9894
# Epoch 14: val_accuracy did not improve from 0.98769
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0312 - accuracy: 0.9894 - val_loss: 0.0413 - val_accuracy: 0.9873 - lr: 7.6902e-04
# Epoch 15/40
# 7003/7005 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9897
# Epoch 15: val_accuracy did not improve from 0.98769
# 7005/7005 [==============================] - 129s 18ms/step - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.0470 - val_accuracy: 0.9850 - lr: 7.5364e-04
# Epoch 16/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9904
# Epoch 16: val_accuracy improved from 0.98769 to 0.98779, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 131s 19ms/step - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.0392 - val_accuracy: 0.9878 - lr: 7.3857e-04
# Epoch 17/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9905
# Epoch 17: val_accuracy did not improve from 0.98779
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.0425 - val_accuracy: 0.9875 - lr: 7.2380e-04
# Epoch 18/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9909
# Epoch 18: val_accuracy improved from 0.98779 to 0.98904, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 131s 19ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 0.0353 - val_accuracy: 0.9890 - lr: 7.0932e-04
# Epoch 19/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9912
# Epoch 19: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0256 - accuracy: 0.9912 - val_loss: 0.0418 - val_accuracy: 0.9881 - lr: 6.9514e-04
# Epoch 20/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9916
# Epoch 20: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0246 - accuracy: 0.9916 - val_loss: 0.0379 - val_accuracy: 0.9883 - lr: 6.8123e-04
# Epoch 21/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9919
# Epoch 21: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.0395 - val_accuracy: 0.9878 - lr: 6.6761e-04
# Epoch 22/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9920
# Epoch 22: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 125s 18ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.0400 - val_accuracy: 0.9881 - lr: 6.5426e-04
# Epoch 23/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9923
# Epoch 23: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0219 - accuracy: 0.9923 - val_loss: 0.0378 - val_accuracy: 0.9887 - lr: 6.4117e-04
# Epoch 24/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 0.9926
# Epoch 24: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 125s 18ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0380 - val_accuracy: 0.9883 - lr: 6.2835e-04
# Epoch 25/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9930
# Epoch 25: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 125s 18ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0376 - val_accuracy: 0.9884 - lr: 6.1578e-04
# Epoch 26/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9930
# Epoch 26: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.0453 - val_accuracy: 0.9872 - lr: 6.0346e-04
# Epoch 27/40
# 7003/7005 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9933
# Epoch 27: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.0392 - val_accuracy: 0.9889 - lr: 5.9140e-04
# Epoch 28/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9933
# Epoch 28: val_accuracy did not improve from 0.98904
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0191 - accuracy: 0.9933 - val_loss: 0.0382 - val_accuracy: 0.9888 - lr: 5.7957e-04
# Epoch 29/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0180 - accuracy: 0.9938
# Epoch 29: val_accuracy improved from 0.98904 to 0.98944, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0180 - accuracy: 0.9938 - val_loss: 0.0365 - val_accuracy: 0.9894 - lr: 5.6798e-04
# Epoch 30/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9937
# Epoch 30: val_accuracy did not improve from 0.98944
# 7005/7005 [==============================] - 124s 18ms/step - loss: 0.0176 - accuracy: 0.9937 - val_loss: 0.0396 - val_accuracy: 0.9891 - lr: 5.5662e-04
# Epoch 31/40
# 7003/7005 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9940
# Epoch 31: val_accuracy improved from 0.98944 to 0.98945, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 125s 18ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0365 - val_accuracy: 0.9895 - lr: 5.4548e-04
# Epoch 32/40
# 7002/7005 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9938
# Epoch 32: val_accuracy did not improve from 0.98945
# 7005/7005 [==============================] - 129s 18ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.0382 - val_accuracy: 0.9891 - lr: 5.3457e-04
# Epoch 33/40
# 7003/7005 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9943
# Epoch 33: val_accuracy improved from 0.98945 to 0.98967, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 128s 18ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.0367 - val_accuracy: 0.9897 - lr: 5.2388e-04
# Epoch 34/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9943
# Epoch 34: val_accuracy improved from 0.98967 to 0.98981, saving model to output/eff100_best.h5
# 7005/7005 [==============================] - 126s 18ms/step - loss: 0.0156 - accuracy: 0.9943 - val_loss: 0.0378 - val_accuracy: 0.9898 - lr: 5.1341e-04
# Epoch 35/40
# 7003/7005 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9944
# Epoch 35: val_accuracy did not improve from 0.98981
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0366 - val_accuracy: 0.9897 - lr: 5.0314e-04
# Epoch 36/40
# 7005/7005 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9947
# Epoch 36: val_accuracy did not improve from 0.98981
# 7005/7005 [==============================] - 130s 18ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.0397 - val_accuracy: 0.9893 - lr: 4.9307e-04
# Epoch 37/40
# 7003/7005 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9948
# Epoch 37: val_accuracy did not improve from 0.98981
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0381 - val_accuracy: 0.9896 - lr: 4.8321e-04
# Epoch 38/40
# 7004/7005 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9948Restoring model weights from the end of the best epoch: 18.
#
# Epoch 38: val_accuracy did not improve from 0.98981
# 7005/7005 [==============================] - 127s 18ms/step - loss: 0.0146 - accuracy: 0.9948 - val_loss: 0.0390 - val_accuracy: 0.9895 - lr: 4.7355e-04
# Epoch 38: early stopping

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
# Out:
# 2022-06-12 21:49:56.994584: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 12498. 172 false predicted. Accuracy is: 0.9862377980476876

# %% [markdown]
# ### 2nd train
#
# Now the model will be trained like transfer learning <https://keras.io/guides/transfer_learning/>.
#
# All layers except the top layer will be fixed and not trained in the 2nd training.
#
# As dataset the digit meter images are used.

# %%
import numpy as np

model = keras.models.load_model(model_filename + '_best.h5')

# now whith meter digits
train_iterator = augmentation(xz_train, yz_train)
validation_iterator = no_augmentation(xz_test, yz_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator) 

# only the last layer is now trainable
for layer in model.layers[:-1]:
    layer.trainable=False

mc = ModelCheckpoint(model_filename + '_best_transfer.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = 20,
                callbacks=[annealer, earlystop, mc],
                verbose=2)


model.save(model_filename + "_best_transfer.h5")

plot_acc_loss(history, "Trainingsresults")
# Out:
# Train data
# Validation data
# Epoch 1/20
# 2022-06-12 21:50:53.216800: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-06-12 21:50:57.524954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.81280, saving model to output/eff100_best_transfer.h5
# 313/313 - 5s - loss: 0.4994 - accuracy: 0.8412 - val_loss: 0.6385 - val_accuracy: 0.8128 - lr: 0.0010 - 5s/epoch - 17ms/step
# Epoch 2/20
#
# Epoch 2: val_accuracy improved from 0.81280 to 0.81360, saving model to output/eff100_best_transfer.h5
# 313/313 - 5s - loss: 0.4696 - accuracy: 0.8484 - val_loss: 0.6249 - val_accuracy: 0.8136 - lr: 9.8000e-04 - 5s/epoch - 15ms/step
# Epoch 3/20
#
# Epoch 3: val_accuracy improved from 0.81360 to 0.82080, saving model to output/eff100_best_transfer.h5
# 313/313 - 5s - loss: 0.4343 - accuracy: 0.8575 - val_loss: 0.6155 - val_accuracy: 0.8208 - lr: 9.6040e-04 - 5s/epoch - 16ms/step
# Epoch 4/20
#
# Epoch 4: val_accuracy improved from 0.82080 to 0.82160, saving model to output/eff100_best_transfer.h5
# 313/313 - 5s - loss: 0.4328 - accuracy: 0.8598 - val_loss: 0.6045 - val_accuracy: 0.8216 - lr: 9.4119e-04 - 5s/epoch - 15ms/step
# Epoch 5/20
#
# Epoch 5: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.4323 - accuracy: 0.8528 - val_loss: 0.6052 - val_accuracy: 0.8176 - lr: 9.2237e-04 - 5s/epoch - 15ms/step
# Epoch 6/20
#
# Epoch 6: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3981 - accuracy: 0.8621 - val_loss: 0.6051 - val_accuracy: 0.8160 - lr: 9.0392e-04 - 5s/epoch - 15ms/step
# Epoch 7/20
#
# Epoch 7: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3958 - accuracy: 0.8678 - val_loss: 0.6147 - val_accuracy: 0.8200 - lr: 8.8584e-04 - 5s/epoch - 15ms/step
# Epoch 8/20
#
# Epoch 8: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3883 - accuracy: 0.8694 - val_loss: 0.6055 - val_accuracy: 0.8176 - lr: 8.6813e-04 - 5s/epoch - 15ms/step
# Epoch 9/20
#
# Epoch 9: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3830 - accuracy: 0.8685 - val_loss: 0.6136 - val_accuracy: 0.8180 - lr: 8.5076e-04 - 5s/epoch - 15ms/step
# Epoch 10/20
#
# Epoch 10: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3784 - accuracy: 0.8780 - val_loss: 0.5979 - val_accuracy: 0.8212 - lr: 8.3375e-04 - 5s/epoch - 15ms/step
# Epoch 11/20
#
# Epoch 11: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3646 - accuracy: 0.8801 - val_loss: 0.6043 - val_accuracy: 0.8144 - lr: 8.1707e-04 - 5s/epoch - 15ms/step
# Epoch 12/20
#
# Epoch 12: val_accuracy did not improve from 0.82160
# 313/313 - 5s - loss: 0.3507 - accuracy: 0.8772 - val_loss: 0.5960 - val_accuracy: 0.8152 - lr: 8.0073e-04 - 5s/epoch - 15ms/step
# Epoch 13/20
#
# Epoch 13: val_accuracy improved from 0.82160 to 0.82240, saving model to output/eff100_best_transfer.h5
# 313/313 - 5s - loss: 0.3600 - accuracy: 0.8750 - val_loss: 0.6001 - val_accuracy: 0.8224 - lr: 7.8472e-04 - 5s/epoch - 15ms/step
# Epoch 14/20
#
# Epoch 14: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3616 - accuracy: 0.8760 - val_loss: 0.5958 - val_accuracy: 0.8160 - lr: 7.6902e-04 - 5s/epoch - 15ms/step
# Epoch 15/20
#
# Epoch 15: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3481 - accuracy: 0.8804 - val_loss: 0.5924 - val_accuracy: 0.8184 - lr: 7.5364e-04 - 5s/epoch - 15ms/step
# Epoch 16/20
#
# Epoch 16: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3514 - accuracy: 0.8794 - val_loss: 0.6012 - val_accuracy: 0.8204 - lr: 7.3857e-04 - 5s/epoch - 15ms/step
# Epoch 17/20
#
# Epoch 17: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3447 - accuracy: 0.8808 - val_loss: 0.5944 - val_accuracy: 0.8168 - lr: 7.2380e-04 - 5s/epoch - 15ms/step
# Epoch 18/20
#
# Epoch 18: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3255 - accuracy: 0.8869 - val_loss: 0.5938 - val_accuracy: 0.8180 - lr: 7.0932e-04 - 5s/epoch - 15ms/step
# Epoch 19/20
#
# Epoch 19: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3392 - accuracy: 0.8839 - val_loss: 0.5965 - val_accuracy: 0.8172 - lr: 6.9514e-04 - 5s/epoch - 15ms/step
# Epoch 20/20
# Restoring model weights from the end of the best epoch: 15.
#
# Epoch 20: val_accuracy did not improve from 0.82240
# 313/313 - 5s - loss: 0.3347 - accuracy: 0.8853 - val_loss: 0.5982 - val_accuracy: 0.8192 - lr: 6.8123e-04 - 5s/epoch - 15ms/step
# Epoch 20: early stopping

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
model = keras.models.load_model(model_filename + "_best_transfer.h5")
predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data)
# Out:
# 2022-06-14 22:21:15.648285: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-14 22:21:15.736618: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Tested images: 12477. 70 false predicted. Accuracy is: 0.9943896770056905
