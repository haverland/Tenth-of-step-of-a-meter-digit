# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with mixed data digit images and TMNIST percental images.
# The best model will be stored as "eff100-best.h5"
#
# ### 2nd train
#
# Runs only on the last layer again. The convolutional layers will not trained.
#
# ## The Model
#
# Used a smaller variant of Efficientnet (effnet) network as small model.
#
# <https://github.com/arthurdouillard/keras-effnet>

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 400                     # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
model_filename = "output/eff100"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.tmnist import tmnist_percentals
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *

try:
    # Disable all GPUS
    tf.config.set_visible_devices([], 'GPU')
    visible_devices = tf.config.get_visible_devices()
    for device in visible_devices:
        assert device.device_type != 'GPU'
except:
    # Invalid device or cannot modify virtual devices once initialized.
    pass

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
#
# ### Percental TMNIST
#
# 300.000 images of type face fonts in 0.1 steps from 0.0 to 9.9
#
# See https://www.kaggle.com/datasets/frankhaverland/percentile-tmnist-for-electric-meters
#
#
# ### Train and Test data
#
# For 1st train both dataset mixed are used.
#
# ### digit meter spread
#
# The percental TMNIST has for every label the same count of data.
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
xz_train, xz_test, yz_train, yz_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)


xt_data, yt_data = tmnist_percentals(max_count=1)

# mixing the datasets
x_data = np.concatenate((xt_data, xz_train))
y_data = np.concatenate((yt_data, yz_train))
x_data, y_data = shuffle(x_data, y_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)

input_shape=x_train[0].shape
print(f"dataset x_train-size={len(x_train)}")
plot_dataset(x_train, y_train)

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)

yz_train = class_encoding(yz_train, nb_classes)
yz_test = class_encoding(yz_test, nb_classes)
# Out:
# Ziffer data count:  16500
# dataset x_train-size=18312

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
# Spot light is not used. It makes the train difficult without better results.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %%
import numpy as np
from b2n.augmentation.generator import augmentation, no_augmentation
from b2n.plotfunctions import plot_dataset_it

train_iterator = augmentation(x_train, y_train)
validation_iterator = no_augmentation(x_test, y_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator)
# Out:
# Train data
# Validation data

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet
from b2n.models.cnn32 import *

model = CNN_s1(input_shape, nb_classes, activation_top=None)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

# %% [markdown]
# ### The Training
#
# Standard training of the model with complete dataset.
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits

earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=25, verbose=1,  restore_best_weights=True)
mc = ModelCheckpoint(model_filename + '_best.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, initial_value_threshold=.9)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, min_lr=1e-5, verbose=1)
history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[earlystop, mc, reduce_lr],
                verbose=1)


plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/400
# 572/573 [============================>.] - ETA: 0s - loss: 4.6962 - accuracy: 0.0138
# Epoch 1: val_loss did not improve from 0.90000
# 573/573 [==============================] - 23s 38ms/step - loss: 4.6960 - accuracy: 0.0139 - val_loss: 4.5657 - val_accuracy: 0.0159 - lr: 0.0010
# Epoch 2/400
# 573/573 [==============================] - ETA: 0s - loss: 4.4149 - accuracy: 0.0304
# Epoch 2: val_loss did not improve from 0.90000
# 573/573 [==============================] - 22s 39ms/step - loss: 4.4149 - accuracy: 0.0304 - val_loss: 3.3714 - val_accuracy: 0.1540 - lr: 0.0010
# Epoch 3/400
# 573/573 [==============================] - ETA: 0s - loss: 2.7794 - accuracy: 0.2442
# Epoch 3: val_loss did not improve from 0.90000
# 573/573 [==============================] - 28s 48ms/step - loss: 2.7794 - accuracy: 0.2442 - val_loss: 1.1026 - val_accuracy: 0.6215 - lr: 0.0010
# Epoch 4/400
# 572/573 [============================>.] - ETA: 0s - loss: 1.7785 - accuracy: 0.4322
# Epoch 4: val_loss improved from 0.90000 to 0.75934, saving model to output/eff100_best.h5
# 573/573 [==============================] - 23s 41ms/step - loss: 1.7778 - accuracy: 0.4325 - val_loss: 0.7593 - val_accuracy: 0.7270 - lr: 0.0010
# Epoch 5/400
# 573/573 [==============================] - ETA: 0s - loss: 1.4098 - accuracy: 0.5155
# Epoch 5: val_loss improved from 0.75934 to 0.63617, saving model to output/eff100_best.h5
# 573/573 [==============================] - 29s 50ms/step - loss: 1.4098 - accuracy: 0.5155 - val_loss: 0.6362 - val_accuracy: 0.7720 - lr: 0.0010
# Epoch 6/400
# 572/573 [============================>.] - ETA: 0s - loss: 1.2402 - accuracy: 0.5599
# Epoch 6: val_loss improved from 0.63617 to 0.58806, saving model to output/eff100_best.h5
# 573/573 [==============================] - 165s 288ms/step - loss: 1.2402 - accuracy: 0.5599 - val_loss: 0.5881 - val_accuracy: 0.7713 - lr: 0.0010
# Epoch 7/400
# 572/573 [============================>.] - ETA: 0s - loss: 1.1153 - accuracy: 0.6015
# Epoch 7: val_loss improved from 0.58806 to 0.56134, saving model to output/eff100_best.h5
# 573/573 [==============================] - 24s 42ms/step - loss: 1.1166 - accuracy: 0.6012 - val_loss: 0.5613 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 8/400
# 573/573 [==============================] - ETA: 0s - loss: 1.0320 - accuracy: 0.6208
# Epoch 8: val_loss improved from 0.56134 to 0.53470, saving model to output/eff100_best.h5
# 573/573 [==============================] - 25s 44ms/step - loss: 1.0320 - accuracy: 0.6208 - val_loss: 0.5347 - val_accuracy: 0.7942 - lr: 0.0010
# Epoch 9/400
# 573/573 [==============================] - ETA: 0s - loss: 0.9751 - accuracy: 0.6407
# Epoch 9: val_loss improved from 0.53470 to 0.50607, saving model to output/eff100_best.h5
# 573/573 [==============================] - 25s 43ms/step - loss: 0.9751 - accuracy: 0.6407 - val_loss: 0.5061 - val_accuracy: 0.8060 - lr: 0.0010
# Epoch 10/400
# 573/573 [==============================] - ETA: 0s - loss: 0.9440 - accuracy: 0.6505
# Epoch 10: val_loss did not improve from 0.50607
# 573/573 [==============================] - 25s 43ms/step - loss: 0.9440 - accuracy: 0.6505 - val_loss: 0.5224 - val_accuracy: 0.7999 - lr: 0.0010
# Epoch 11/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.8908 - accuracy: 0.6670
# Epoch 11: val_loss improved from 0.50607 to 0.48622, saving model to output/eff100_best.h5
# 573/573 [==============================] - 23s 41ms/step - loss: 0.8905 - accuracy: 0.6669 - val_loss: 0.4862 - val_accuracy: 0.8161 - lr: 0.0010
# Epoch 12/400
# 573/573 [==============================] - ETA: 0s - loss: 0.8475 - accuracy: 0.6785
# Epoch 12: val_loss improved from 0.48622 to 0.48231, saving model to output/eff100_best.h5
# 573/573 [==============================] - 23s 41ms/step - loss: 0.8475 - accuracy: 0.6785 - val_loss: 0.4823 - val_accuracy: 0.8030 - lr: 0.0010
# Epoch 13/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.8263 - accuracy: 0.6933
# Epoch 13: val_loss improved from 0.48231 to 0.46327, saving model to output/eff100_best.h5
# 573/573 [==============================] - 24s 42ms/step - loss: 0.8262 - accuracy: 0.6933 - val_loss: 0.4633 - val_accuracy: 0.8156 - lr: 0.0010
# Epoch 14/400
# 573/573 [==============================] - ETA: 0s - loss: 0.8129 - accuracy: 0.6932
# Epoch 14: val_loss improved from 0.46327 to 0.44979, saving model to output/eff100_best.h5
# 573/573 [==============================] - 25s 43ms/step - loss: 0.8129 - accuracy: 0.6932 - val_loss: 0.4498 - val_accuracy: 0.8161 - lr: 0.0010
# Epoch 15/400
# 573/573 [==============================] - ETA: 0s - loss: 0.7690 - accuracy: 0.7054
# Epoch 15: val_loss improved from 0.44979 to 0.42903, saving model to output/eff100_best.h5
# 573/573 [==============================] - 24s 42ms/step - loss: 0.7690 - accuracy: 0.7054 - val_loss: 0.4290 - val_accuracy: 0.8279 - lr: 0.0010
# Epoch 16/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.7656 - accuracy: 0.7064
# Epoch 16: val_loss did not improve from 0.42903
# 573/573 [==============================] - 25s 44ms/step - loss: 0.7652 - accuracy: 0.7066 - val_loss: 0.4555 - val_accuracy: 0.8204 - lr: 0.0010
# Epoch 17/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.7363 - accuracy: 0.7195
# Epoch 17: val_loss improved from 0.42903 to 0.41820, saving model to output/eff100_best.h5
# 573/573 [==============================] - 25s 44ms/step - loss: 0.7360 - accuracy: 0.7196 - val_loss: 0.4182 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 18/400
# 573/573 [==============================] - ETA: 0s - loss: 0.7183 - accuracy: 0.7240
# Epoch 18: val_loss improved from 0.41820 to 0.40684, saving model to output/eff100_best.h5
# 573/573 [==============================] - 25s 43ms/step - loss: 0.7183 - accuracy: 0.7240 - val_loss: 0.4068 - val_accuracy: 0.8349 - lr: 0.0010
# Epoch 19/400
# 573/573 [==============================] - ETA: 0s - loss: 0.6961 - accuracy: 0.7320
# Epoch 19: val_loss did not improve from 0.40684
# 573/573 [==============================] - 24s 41ms/step - loss: 0.6961 - accuracy: 0.7320 - val_loss: 0.4172 - val_accuracy: 0.8279 - lr: 0.0010
# Epoch 20/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.6880 - accuracy: 0.7378
# Epoch 20: val_loss improved from 0.40684 to 0.40192, saving model to output/eff100_best.h5
# 573/573 [==============================] - 23s 40ms/step - loss: 0.6880 - accuracy: 0.7376 - val_loss: 0.4019 - val_accuracy: 0.8412 - lr: 0.0010
# Epoch 21/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.6881 - accuracy: 0.7352
# Epoch 21: val_loss improved from 0.40192 to 0.39155, saving model to output/eff100_best.h5
# 573/573 [==============================] - 25s 43ms/step - loss: 0.6881 - accuracy: 0.7351 - val_loss: 0.3915 - val_accuracy: 0.8355 - lr: 0.0010
# Epoch 22/400
# 573/573 [==============================] - ETA: 0s - loss: 0.6742 - accuracy: 0.7373
# Epoch 22: val_loss did not improve from 0.39155
# 573/573 [==============================] - 24s 41ms/step - loss: 0.6742 - accuracy: 0.7373 - val_loss: 0.4125 - val_accuracy: 0.8353 - lr: 0.0010
# Epoch 23/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.6645 - accuracy: 0.7412
# Epoch 23: val_loss did not improve from 0.39155
# 573/573 [==============================] - 25s 43ms/step - loss: 0.6644 - accuracy: 0.7412 - val_loss: 0.3972 - val_accuracy: 0.8377 - lr: 0.0010
# Epoch 24/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.6409 - accuracy: 0.7525
# Epoch 24: val_loss did not improve from 0.39155
# 573/573 [==============================] - 24s 41ms/step - loss: 0.6405 - accuracy: 0.7527 - val_loss: 0.3924 - val_accuracy: 0.8340 - lr: 0.0010
# Epoch 25/400
# 573/573 [==============================] - ETA: 0s - loss: 0.6382 - accuracy: 0.7549
# Epoch 25: val_loss improved from 0.39155 to 0.36643, saving model to output/eff100_best.h5
# 573/573 [==============================] - 24s 42ms/step - loss: 0.6382 - accuracy: 0.7549 - val_loss: 0.3664 - val_accuracy: 0.8469 - lr: 0.0010
# Epoch 26/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.6368 - accuracy: 0.7518
# Epoch 26: val_loss did not improve from 0.36643
# 573/573 [==============================] - 25s 43ms/step - loss: 0.6366 - accuracy: 0.7519 - val_loss: 0.3831 - val_accuracy: 0.8381 - lr: 0.0010
# Epoch 27/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.7565
# Epoch 27: val_loss improved from 0.36643 to 0.36153, saving model to output/eff100_best.h5
# 573/573 [==============================] - 24s 42ms/step - loss: 0.6246 - accuracy: 0.7566 - val_loss: 0.3615 - val_accuracy: 0.8462 - lr: 0.0010
# Epoch 28/400
# 573/573 [==============================] - ETA: 0s - loss: 0.6197 - accuracy: 0.7604
# Epoch 28: val_loss did not improve from 0.36153
# 573/573 [==============================] - 24s 42ms/step - loss: 0.6197 - accuracy: 0.7604 - val_loss: 0.3702 - val_accuracy: 0.8486 - lr: 0.0010
# Epoch 29/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.7699
# Epoch 29: val_loss did not improve from 0.36153
# 573/573 [==============================] - 24s 42ms/step - loss: 0.5976 - accuracy: 0.7699 - val_loss: 0.3618 - val_accuracy: 0.8521 - lr: 0.0010
# Epoch 30/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.7700
# Epoch 30: val_loss improved from 0.36153 to 0.35122, saving model to output/eff100_best.h5
# 573/573 [==============================] - 21s 37ms/step - loss: 0.5955 - accuracy: 0.7700 - val_loss: 0.3512 - val_accuracy: 0.8532 - lr: 0.0010
# Epoch 31/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5910 - accuracy: 0.7687
# Epoch 31: val_loss did not improve from 0.35122
# 573/573 [==============================] - 21s 36ms/step - loss: 0.5909 - accuracy: 0.7688 - val_loss: 0.3810 - val_accuracy: 0.8478 - lr: 0.0010
# Epoch 32/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.7694
# Epoch 32: val_loss did not improve from 0.35122
# 573/573 [==============================] - 19s 32ms/step - loss: 0.5921 - accuracy: 0.7694 - val_loss: 0.3585 - val_accuracy: 0.8491 - lr: 0.0010
# Epoch 33/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5851 - accuracy: 0.7696
# Epoch 33: val_loss did not improve from 0.35122
# 573/573 [==============================] - 19s 32ms/step - loss: 0.5848 - accuracy: 0.7696 - val_loss: 0.3578 - val_accuracy: 0.8554 - lr: 0.0010
# Epoch 34/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.7751
# Epoch 34: val_loss did not improve from 0.35122
# 573/573 [==============================] - 19s 33ms/step - loss: 0.5722 - accuracy: 0.7751 - val_loss: 0.3641 - val_accuracy: 0.8447 - lr: 0.0010
# Epoch 35/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5690 - accuracy: 0.7768
# Epoch 35: val_loss improved from 0.35122 to 0.34393, saving model to output/eff100_best.h5
# 573/573 [==============================] - 19s 33ms/step - loss: 0.5688 - accuracy: 0.7768 - val_loss: 0.3439 - val_accuracy: 0.8578 - lr: 0.0010
# Epoch 36/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5609 - accuracy: 0.7821
# Epoch 36: val_loss did not improve from 0.34393
# 573/573 [==============================] - 18s 32ms/step - loss: 0.5610 - accuracy: 0.7822 - val_loss: 0.3463 - val_accuracy: 0.8582 - lr: 0.0010
# Epoch 37/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5580 - accuracy: 0.7820
# Epoch 37: val_loss improved from 0.34393 to 0.34199, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 32ms/step - loss: 0.5580 - accuracy: 0.7820 - val_loss: 0.3420 - val_accuracy: 0.8545 - lr: 0.0010
# Epoch 38/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5461 - accuracy: 0.7851
# Epoch 38: val_loss did not improve from 0.34199
# 573/573 [==============================] - 18s 31ms/step - loss: 0.5461 - accuracy: 0.7851 - val_loss: 0.3457 - val_accuracy: 0.8541 - lr: 0.0010
# Epoch 39/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7876
# Epoch 39: val_loss improved from 0.34199 to 0.33946, saving model to output/eff100_best.h5
# 573/573 [==============================] - 19s 33ms/step - loss: 0.5474 - accuracy: 0.7877 - val_loss: 0.3395 - val_accuracy: 0.8580 - lr: 0.0010
# Epoch 40/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5437 - accuracy: 0.7850
# Epoch 40: val_loss improved from 0.33946 to 0.33716, saving model to output/eff100_best.h5
# 573/573 [==============================] - 19s 33ms/step - loss: 0.5439 - accuracy: 0.7850 - val_loss: 0.3372 - val_accuracy: 0.8602 - lr: 0.0010
# Epoch 41/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7854
# Epoch 41: val_loss did not improve from 0.33716
# 573/573 [==============================] - 19s 33ms/step - loss: 0.5362 - accuracy: 0.7856 - val_loss: 0.3454 - val_accuracy: 0.8467 - lr: 0.0010
# Epoch 42/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5329 - accuracy: 0.7941
# Epoch 42: val_loss improved from 0.33716 to 0.33248, saving model to output/eff100_best.h5
# 573/573 [==============================] - 19s 32ms/step - loss: 0.5330 - accuracy: 0.7940 - val_loss: 0.3325 - val_accuracy: 0.8571 - lr: 0.0010
# Epoch 43/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5387 - accuracy: 0.7881
# Epoch 43: val_loss did not improve from 0.33248
# 573/573 [==============================] - 19s 33ms/step - loss: 0.5385 - accuracy: 0.7881 - val_loss: 0.3430 - val_accuracy: 0.8543 - lr: 0.0010
# Epoch 44/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5182 - accuracy: 0.7954
# Epoch 44: val_loss did not improve from 0.33248
# 573/573 [==============================] - 18s 32ms/step - loss: 0.5183 - accuracy: 0.7953 - val_loss: 0.3342 - val_accuracy: 0.8574 - lr: 0.0010
# Epoch 45/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5150 - accuracy: 0.7993
# Epoch 45: val_loss improved from 0.33248 to 0.32883, saving model to output/eff100_best.h5
# 573/573 [==============================] - 16s 28ms/step - loss: 0.5150 - accuracy: 0.7993 - val_loss: 0.3288 - val_accuracy: 0.8593 - lr: 0.0010
# Epoch 46/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5190 - accuracy: 0.7953
# Epoch 46: val_loss did not improve from 0.32883
# 573/573 [==============================] - 17s 29ms/step - loss: 0.5190 - accuracy: 0.7953 - val_loss: 0.3364 - val_accuracy: 0.8515 - lr: 0.0010
# Epoch 47/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5193 - accuracy: 0.7972
# Epoch 47: val_loss improved from 0.32883 to 0.32716, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.5190 - accuracy: 0.7973 - val_loss: 0.3272 - val_accuracy: 0.8644 - lr: 0.0010
# Epoch 48/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5153 - accuracy: 0.7967
# Epoch 48: val_loss improved from 0.32716 to 0.32568, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.5150 - accuracy: 0.7969 - val_loss: 0.3257 - val_accuracy: 0.8661 - lr: 0.0010
# Epoch 49/400
# 573/573 [==============================] - ETA: 0s - loss: 0.5226 - accuracy: 0.7901
# Epoch 49: val_loss did not improve from 0.32568
# 573/573 [==============================] - 18s 31ms/step - loss: 0.5226 - accuracy: 0.7901 - val_loss: 0.3461 - val_accuracy: 0.8558 - lr: 0.0010
# Epoch 50/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4896 - accuracy: 0.8032
# Epoch 50: val_loss improved from 0.32568 to 0.32466, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4902 - accuracy: 0.8032 - val_loss: 0.3247 - val_accuracy: 0.8622 - lr: 0.0010
# Epoch 51/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5170 - accuracy: 0.7957
# Epoch 51: val_loss improved from 0.32466 to 0.32184, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.5171 - accuracy: 0.7957 - val_loss: 0.3218 - val_accuracy: 0.8705 - lr: 0.0010
# Epoch 52/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.5023 - accuracy: 0.8021
# Epoch 52: val_loss did not improve from 0.32184
# 573/573 [==============================] - 18s 31ms/step - loss: 0.5022 - accuracy: 0.8021 - val_loss: 0.3337 - val_accuracy: 0.8593 - lr: 0.0010
# Epoch 53/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4926 - accuracy: 0.8024
# Epoch 53: val_loss improved from 0.32184 to 0.31755, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4931 - accuracy: 0.8023 - val_loss: 0.3176 - val_accuracy: 0.8681 - lr: 0.0010
# Epoch 54/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8089
# Epoch 54: val_loss improved from 0.31755 to 0.31285, saving model to output/eff100_best.h5
# 573/573 [==============================] - 16s 28ms/step - loss: 0.4890 - accuracy: 0.8089 - val_loss: 0.3129 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 55/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4842 - accuracy: 0.8078
# Epoch 55: val_loss did not improve from 0.31285
# 573/573 [==============================] - 16s 29ms/step - loss: 0.4840 - accuracy: 0.8078 - val_loss: 0.3219 - val_accuracy: 0.8665 - lr: 0.0010
# Epoch 56/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4829 - accuracy: 0.8088
# Epoch 56: val_loss did not improve from 0.31285
# 573/573 [==============================] - 17s 29ms/step - loss: 0.4829 - accuracy: 0.8089 - val_loss: 0.3238 - val_accuracy: 0.8637 - lr: 0.0010
# Epoch 57/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4881 - accuracy: 0.8051
# Epoch 57: val_loss did not improve from 0.31285
# 573/573 [==============================] - 16s 29ms/step - loss: 0.4880 - accuracy: 0.8051 - val_loss: 0.3166 - val_accuracy: 0.8681 - lr: 0.0010
# Epoch 58/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4855 - accuracy: 0.8060
# Epoch 58: val_loss did not improve from 0.31285
# 573/573 [==============================] - 17s 29ms/step - loss: 0.4857 - accuracy: 0.8061 - val_loss: 0.3181 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 59/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4778 - accuracy: 0.8097
# Epoch 59: val_loss did not improve from 0.31285
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 573/573 [==============================] - 17s 29ms/step - loss: 0.4778 - accuracy: 0.8097 - val_loss: 0.3218 - val_accuracy: 0.8678 - lr: 0.0010
# Epoch 60/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4740 - accuracy: 0.8112
# Epoch 60: val_loss improved from 0.31285 to 0.30150, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4740 - accuracy: 0.8112 - val_loss: 0.3015 - val_accuracy: 0.8740 - lr: 8.0000e-04
# Epoch 61/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4560 - accuracy: 0.8176
# Epoch 61: val_loss improved from 0.30150 to 0.29552, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 32ms/step - loss: 0.4560 - accuracy: 0.8176 - val_loss: 0.2955 - val_accuracy: 0.8724 - lr: 8.0000e-04
# Epoch 62/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.8149
# Epoch 62: val_loss did not improve from 0.29552
# 573/573 [==============================] - 18s 32ms/step - loss: 0.4681 - accuracy: 0.8149 - val_loss: 0.3045 - val_accuracy: 0.8751 - lr: 8.0000e-04
# Epoch 63/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4510 - accuracy: 0.8237
# Epoch 63: val_loss did not improve from 0.29552
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4514 - accuracy: 0.8237 - val_loss: 0.3131 - val_accuracy: 0.8696 - lr: 8.0000e-04
# Epoch 64/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4465 - accuracy: 0.8251
# Epoch 64: val_loss did not improve from 0.29552
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4463 - accuracy: 0.8253 - val_loss: 0.2976 - val_accuracy: 0.8757 - lr: 8.0000e-04
# Epoch 65/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4490 - accuracy: 0.8183
# Epoch 65: val_loss improved from 0.29552 to 0.29498, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4492 - accuracy: 0.8182 - val_loss: 0.2950 - val_accuracy: 0.8740 - lr: 8.0000e-04
# Epoch 66/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4426 - accuracy: 0.8234
# Epoch 66: val_loss improved from 0.29498 to 0.29464, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4426 - accuracy: 0.8234 - val_loss: 0.2946 - val_accuracy: 0.8779 - lr: 8.0000e-04
# Epoch 67/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4467 - accuracy: 0.8243
# Epoch 67: val_loss did not improve from 0.29464
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4467 - accuracy: 0.8243 - val_loss: 0.2973 - val_accuracy: 0.8759 - lr: 8.0000e-04
# Epoch 68/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4399 - accuracy: 0.8237
# Epoch 68: val_loss improved from 0.29464 to 0.28402, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4399 - accuracy: 0.8237 - val_loss: 0.2840 - val_accuracy: 0.8847 - lr: 8.0000e-04
# Epoch 69/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4372 - accuracy: 0.8280
# Epoch 69: val_loss did not improve from 0.28402
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4378 - accuracy: 0.8278 - val_loss: 0.2983 - val_accuracy: 0.8788 - lr: 8.0000e-04
# Epoch 70/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4388 - accuracy: 0.8243
# Epoch 70: val_loss did not improve from 0.28402
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4388 - accuracy: 0.8243 - val_loss: 0.2946 - val_accuracy: 0.8757 - lr: 8.0000e-04
# Epoch 71/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8259
# Epoch 71: val_loss did not improve from 0.28402
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4365 - accuracy: 0.8259 - val_loss: 0.2972 - val_accuracy: 0.8796 - lr: 8.0000e-04
# Epoch 72/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4348 - accuracy: 0.8261
# Epoch 72: val_loss did not improve from 0.28402
# 573/573 [==============================] - 19s 33ms/step - loss: 0.4346 - accuracy: 0.8263 - val_loss: 0.2915 - val_accuracy: 0.8772 - lr: 8.0000e-04
# Epoch 73/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4321 - accuracy: 0.8270
# Epoch 73: val_loss did not improve from 0.28402
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 573/573 [==============================] - 19s 33ms/step - loss: 0.4321 - accuracy: 0.8270 - val_loss: 0.2993 - val_accuracy: 0.8761 - lr: 8.0000e-04
# Epoch 74/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4303 - accuracy: 0.8293
# Epoch 74: val_loss did not improve from 0.28402
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4307 - accuracy: 0.8292 - val_loss: 0.2883 - val_accuracy: 0.8814 - lr: 6.4000e-04
# Epoch 75/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.4098 - accuracy: 0.8344
# Epoch 75: val_loss did not improve from 0.28402
# 573/573 [==============================] - 17s 29ms/step - loss: 0.4096 - accuracy: 0.8344 - val_loss: 0.2863 - val_accuracy: 0.8803 - lr: 6.4000e-04
# Epoch 76/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4171 - accuracy: 0.8364
# Epoch 76: val_loss improved from 0.28402 to 0.28262, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 29ms/step - loss: 0.4171 - accuracy: 0.8364 - val_loss: 0.2826 - val_accuracy: 0.8807 - lr: 6.4000e-04
# Epoch 77/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4132 - accuracy: 0.8367
# Epoch 77: val_loss improved from 0.28262 to 0.27687, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4130 - accuracy: 0.8368 - val_loss: 0.2769 - val_accuracy: 0.8831 - lr: 6.4000e-04
# Epoch 78/400
# 573/573 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8368
# Epoch 78: val_loss did not improve from 0.27687
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4154 - accuracy: 0.8368 - val_loss: 0.2817 - val_accuracy: 0.8829 - lr: 6.4000e-04
# Epoch 79/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4144 - accuracy: 0.8361
# Epoch 79: val_loss did not improve from 0.27687
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4143 - accuracy: 0.8361 - val_loss: 0.2833 - val_accuracy: 0.8812 - lr: 6.4000e-04
# Epoch 80/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4080 - accuracy: 0.8340
# Epoch 80: val_loss did not improve from 0.27687
# 573/573 [==============================] - 17s 30ms/step - loss: 0.4076 - accuracy: 0.8342 - val_loss: 0.2837 - val_accuracy: 0.8825 - lr: 6.4000e-04
# Epoch 81/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4111 - accuracy: 0.8400
# Epoch 81: val_loss did not improve from 0.27687
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4112 - accuracy: 0.8399 - val_loss: 0.2872 - val_accuracy: 0.8814 - lr: 6.4000e-04
# Epoch 82/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.4105 - accuracy: 0.8372
# Epoch 82: val_loss did not improve from 0.27687
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 573/573 [==============================] - 18s 31ms/step - loss: 0.4103 - accuracy: 0.8373 - val_loss: 0.2815 - val_accuracy: 0.8877 - lr: 6.4000e-04
# Epoch 83/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3986 - accuracy: 0.8395
# Epoch 83: val_loss did not improve from 0.27687
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3986 - accuracy: 0.8394 - val_loss: 0.2769 - val_accuracy: 0.8875 - lr: 5.1200e-04
# Epoch 84/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8421
# Epoch 84: val_loss did not improve from 0.27687
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3989 - accuracy: 0.8421 - val_loss: 0.2791 - val_accuracy: 0.8866 - lr: 5.1200e-04
# Epoch 85/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3918 - accuracy: 0.8478
# Epoch 85: val_loss did not improve from 0.27687
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3918 - accuracy: 0.8478 - val_loss: 0.2825 - val_accuracy: 0.8858 - lr: 5.1200e-04
# Epoch 86/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.8441
# Epoch 86: val_loss did not improve from 0.27687
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3943 - accuracy: 0.8441 - val_loss: 0.2826 - val_accuracy: 0.8799 - lr: 5.1200e-04
# Epoch 87/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3849 - accuracy: 0.8462
# Epoch 87: val_loss did not improve from 0.27687
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3849 - accuracy: 0.8462 - val_loss: 0.2842 - val_accuracy: 0.8834 - lr: 5.1200e-04
# Epoch 88/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3804 - accuracy: 0.8460
# Epoch 88: val_loss did not improve from 0.27687
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3803 - accuracy: 0.8461 - val_loss: 0.2771 - val_accuracy: 0.8847 - lr: 4.0960e-04
# Epoch 89/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3888 - accuracy: 0.8425
# Epoch 89: val_loss improved from 0.27687 to 0.27014, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3886 - accuracy: 0.8426 - val_loss: 0.2701 - val_accuracy: 0.8903 - lr: 4.0960e-04
# Epoch 90/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3715 - accuracy: 0.8538
# Epoch 90: val_loss did not improve from 0.27014
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3715 - accuracy: 0.8538 - val_loss: 0.2740 - val_accuracy: 0.8871 - lr: 4.0960e-04
# Epoch 91/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3770 - accuracy: 0.8490
# Epoch 91: val_loss did not improve from 0.27014
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3770 - accuracy: 0.8490 - val_loss: 0.2755 - val_accuracy: 0.8860 - lr: 4.0960e-04
# Epoch 92/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3792 - accuracy: 0.8484
# Epoch 92: val_loss did not improve from 0.27014
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3792 - accuracy: 0.8485 - val_loss: 0.2743 - val_accuracy: 0.8866 - lr: 4.0960e-04
# Epoch 93/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3796 - accuracy: 0.8463
# Epoch 93: val_loss did not improve from 0.27014
# 573/573 [==============================] - 18s 32ms/step - loss: 0.3793 - accuracy: 0.8464 - val_loss: 0.2746 - val_accuracy: 0.8849 - lr: 4.0960e-04
# Epoch 94/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3811 - accuracy: 0.8472
# Epoch 94: val_loss improved from 0.27014 to 0.26725, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3810 - accuracy: 0.8471 - val_loss: 0.2673 - val_accuracy: 0.8917 - lr: 4.0960e-04
# Epoch 95/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8511
# Epoch 95: val_loss improved from 0.26725 to 0.26635, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3718 - accuracy: 0.8511 - val_loss: 0.2663 - val_accuracy: 0.8873 - lr: 4.0960e-04
# Epoch 96/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3767 - accuracy: 0.8487
# Epoch 96: val_loss did not improve from 0.26635
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3761 - accuracy: 0.8490 - val_loss: 0.2741 - val_accuracy: 0.8879 - lr: 4.0960e-04
# Epoch 97/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3706 - accuracy: 0.8502
# Epoch 97: val_loss did not improve from 0.26635
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3709 - accuracy: 0.8502 - val_loss: 0.2737 - val_accuracy: 0.8890 - lr: 4.0960e-04
# Epoch 98/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3669 - accuracy: 0.8522
# Epoch 98: val_loss did not improve from 0.26635
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3669 - accuracy: 0.8522 - val_loss: 0.2733 - val_accuracy: 0.8862 - lr: 4.0960e-04
# Epoch 99/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3738 - accuracy: 0.8476
# Epoch 99: val_loss improved from 0.26635 to 0.26300, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3737 - accuracy: 0.8477 - val_loss: 0.2630 - val_accuracy: 0.8917 - lr: 4.0960e-04
# Epoch 100/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3749 - accuracy: 0.8483
# Epoch 100: val_loss did not improve from 0.26300
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3749 - accuracy: 0.8483 - val_loss: 0.2800 - val_accuracy: 0.8851 - lr: 4.0960e-04
# Epoch 101/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3639 - accuracy: 0.8534
# Epoch 101: val_loss did not improve from 0.26300
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3638 - accuracy: 0.8535 - val_loss: 0.2764 - val_accuracy: 0.8910 - lr: 4.0960e-04
# Epoch 102/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.8528
# Epoch 102: val_loss did not improve from 0.26300
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3721 - accuracy: 0.8528 - val_loss: 0.2669 - val_accuracy: 0.8923 - lr: 4.0960e-04
# Epoch 103/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3716 - accuracy: 0.8530
# Epoch 103: val_loss did not improve from 0.26300
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3718 - accuracy: 0.8529 - val_loss: 0.2823 - val_accuracy: 0.8869 - lr: 4.0960e-04
# Epoch 104/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3663 - accuracy: 0.8522
# Epoch 104: val_loss did not improve from 0.26300
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3662 - accuracy: 0.8522 - val_loss: 0.2657 - val_accuracy: 0.8882 - lr: 4.0960e-04
# Epoch 105/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3564 - accuracy: 0.8563
# Epoch 105: val_loss improved from 0.26300 to 0.26084, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3566 - accuracy: 0.8562 - val_loss: 0.2608 - val_accuracy: 0.8930 - lr: 3.2768e-04
# Epoch 106/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3526 - accuracy: 0.8592
# Epoch 106: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3526 - accuracy: 0.8593 - val_loss: 0.2668 - val_accuracy: 0.8882 - lr: 3.2768e-04
# Epoch 107/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3668 - accuracy: 0.8518
# Epoch 107: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3670 - accuracy: 0.8517 - val_loss: 0.2702 - val_accuracy: 0.8858 - lr: 3.2768e-04
# Epoch 108/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.8553
# Epoch 108: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3546 - accuracy: 0.8553 - val_loss: 0.2678 - val_accuracy: 0.8908 - lr: 3.2768e-04
# Epoch 109/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3579 - accuracy: 0.8544
# Epoch 109: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3575 - accuracy: 0.8545 - val_loss: 0.2692 - val_accuracy: 0.8877 - lr: 3.2768e-04
# Epoch 110/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.8566
# Epoch 110: val_loss did not improve from 0.26084
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3615 - accuracy: 0.8566 - val_loss: 0.2693 - val_accuracy: 0.8871 - lr: 3.2768e-04
# Epoch 111/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3511 - accuracy: 0.8615
# Epoch 111: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3512 - accuracy: 0.8614 - val_loss: 0.2633 - val_accuracy: 0.8917 - lr: 2.6214e-04
# Epoch 112/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3527 - accuracy: 0.8595
# Epoch 112: val_loss did not improve from 0.26084
# 573/573 [==============================] - 18s 30ms/step - loss: 0.3525 - accuracy: 0.8595 - val_loss: 0.2647 - val_accuracy: 0.8897 - lr: 2.6214e-04
# Epoch 113/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8541
# Epoch 113: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3528 - accuracy: 0.8541 - val_loss: 0.2660 - val_accuracy: 0.8901 - lr: 2.6214e-04
# Epoch 114/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.8628
# Epoch 114: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3429 - accuracy: 0.8628 - val_loss: 0.2705 - val_accuracy: 0.8864 - lr: 2.6214e-04
# Epoch 115/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3562 - accuracy: 0.8599
# Epoch 115: val_loss did not improve from 0.26084
#
# Epoch 115: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3562 - accuracy: 0.8599 - val_loss: 0.2685 - val_accuracy: 0.8897 - lr: 2.6214e-04
# Epoch 116/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3446 - accuracy: 0.8647
# Epoch 116: val_loss did not improve from 0.26084
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3446 - accuracy: 0.8645 - val_loss: 0.2617 - val_accuracy: 0.8919 - lr: 2.0972e-04
# Epoch 117/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8650
# Epoch 117: val_loss did not improve from 0.26084
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3369 - accuracy: 0.8650 - val_loss: 0.2612 - val_accuracy: 0.8919 - lr: 2.0972e-04
# Epoch 118/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3415 - accuracy: 0.8635
# Epoch 118: val_loss did not improve from 0.26084
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3413 - accuracy: 0.8636 - val_loss: 0.2629 - val_accuracy: 0.8899 - lr: 2.0972e-04
# Epoch 119/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8593
# Epoch 119: val_loss improved from 0.26084 to 0.25957, saving model to output/eff100_best.h5
# 573/573 [==============================] - 204s 357ms/step - loss: 0.3470 - accuracy: 0.8593 - val_loss: 0.2596 - val_accuracy: 0.8941 - lr: 2.0972e-04
# Epoch 120/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3437 - accuracy: 0.8641
# Epoch 120: val_loss improved from 0.25957 to 0.25797, saving model to output/eff100_best.h5
# 573/573 [==============================] - 19s 33ms/step - loss: 0.3438 - accuracy: 0.8640 - val_loss: 0.2580 - val_accuracy: 0.8952 - lr: 2.0972e-04
# Epoch 121/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3395 - accuracy: 0.8623
# Epoch 121: val_loss did not improve from 0.25797
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3398 - accuracy: 0.8622 - val_loss: 0.2619 - val_accuracy: 0.8895 - lr: 2.0972e-04
# Epoch 122/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8646
# Epoch 122: val_loss did not improve from 0.25797
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3392 - accuracy: 0.8646 - val_loss: 0.2663 - val_accuracy: 0.8908 - lr: 2.0972e-04
# Epoch 123/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3365 - accuracy: 0.8653
# Epoch 123: val_loss did not improve from 0.25797
# 573/573 [==============================] - 17s 31ms/step - loss: 0.3369 - accuracy: 0.8652 - val_loss: 0.2624 - val_accuracy: 0.8923 - lr: 2.0972e-04
# Epoch 124/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.8647
# Epoch 124: val_loss did not improve from 0.25797
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3385 - accuracy: 0.8647 - val_loss: 0.2623 - val_accuracy: 0.8945 - lr: 2.0972e-04
# Epoch 125/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3412 - accuracy: 0.8643
# Epoch 125: val_loss did not improve from 0.25797
#
# Epoch 125: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3410 - accuracy: 0.8645 - val_loss: 0.2644 - val_accuracy: 0.8925 - lr: 2.0972e-04
# Epoch 126/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3334 - accuracy: 0.8650
# Epoch 126: val_loss improved from 0.25797 to 0.25753, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3334 - accuracy: 0.8650 - val_loss: 0.2575 - val_accuracy: 0.8927 - lr: 1.6777e-04
# Epoch 127/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8658
# Epoch 127: val_loss did not improve from 0.25753
# 573/573 [==============================] - 20s 36ms/step - loss: 0.3347 - accuracy: 0.8658 - val_loss: 0.2639 - val_accuracy: 0.8921 - lr: 1.6777e-04
# Epoch 128/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8638
# Epoch 128: val_loss did not improve from 0.25753
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3358 - accuracy: 0.8638 - val_loss: 0.2590 - val_accuracy: 0.8936 - lr: 1.6777e-04
# Epoch 129/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3359 - accuracy: 0.8687
# Epoch 129: val_loss did not improve from 0.25753
# 573/573 [==============================] - 18s 32ms/step - loss: 0.3365 - accuracy: 0.8686 - val_loss: 0.2588 - val_accuracy: 0.8960 - lr: 1.6777e-04
# Epoch 130/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3329 - accuracy: 0.8663
# Epoch 130: val_loss did not improve from 0.25753
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3329 - accuracy: 0.8663 - val_loss: 0.2588 - val_accuracy: 0.8925 - lr: 1.6777e-04
# Epoch 131/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3348 - accuracy: 0.8654
# Epoch 131: val_loss did not improve from 0.25753
#
# Epoch 131: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3351 - accuracy: 0.8653 - val_loss: 0.2586 - val_accuracy: 0.8912 - lr: 1.6777e-04
# Epoch 132/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3327 - accuracy: 0.8712
# Epoch 132: val_loss improved from 0.25753 to 0.25609, saving model to output/eff100_best.h5
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3328 - accuracy: 0.8712 - val_loss: 0.2561 - val_accuracy: 0.8958 - lr: 1.3422e-04
# Epoch 133/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.8699
# Epoch 133: val_loss did not improve from 0.25609
# 573/573 [==============================] - 21s 36ms/step - loss: 0.3240 - accuracy: 0.8699 - val_loss: 0.2581 - val_accuracy: 0.8927 - lr: 1.3422e-04
# Epoch 134/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3263 - accuracy: 0.8679
# Epoch 134: val_loss did not improve from 0.25609
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3263 - accuracy: 0.8679 - val_loss: 0.2583 - val_accuracy: 0.8934 - lr: 1.3422e-04
# Epoch 135/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3265 - accuracy: 0.8667
# Epoch 135: val_loss did not improve from 0.25609
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3263 - accuracy: 0.8668 - val_loss: 0.2588 - val_accuracy: 0.8936 - lr: 1.3422e-04
# Epoch 136/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3216 - accuracy: 0.8706
# Epoch 136: val_loss improved from 0.25609 to 0.25582, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3214 - accuracy: 0.8707 - val_loss: 0.2558 - val_accuracy: 0.8938 - lr: 1.3422e-04
# Epoch 137/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8729
# Epoch 137: val_loss improved from 0.25582 to 0.25537, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3300 - accuracy: 0.8729 - val_loss: 0.2554 - val_accuracy: 0.8934 - lr: 1.3422e-04
# Epoch 138/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8664
# Epoch 138: val_loss did not improve from 0.25537
# 573/573 [==============================] - 21s 36ms/step - loss: 0.3371 - accuracy: 0.8664 - val_loss: 0.2559 - val_accuracy: 0.8923 - lr: 1.3422e-04
# Epoch 139/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3343 - accuracy: 0.8649
# Epoch 139: val_loss did not improve from 0.25537
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3346 - accuracy: 0.8648 - val_loss: 0.2588 - val_accuracy: 0.8932 - lr: 1.3422e-04
# Epoch 140/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.8696
# Epoch 140: val_loss improved from 0.25537 to 0.25491, saving model to output/eff100_best.h5
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3255 - accuracy: 0.8696 - val_loss: 0.2549 - val_accuracy: 0.8932 - lr: 1.3422e-04
# Epoch 141/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8710
# Epoch 141: val_loss did not improve from 0.25491
# 573/573 [==============================] - 21s 37ms/step - loss: 0.3290 - accuracy: 0.8710 - val_loss: 0.2569 - val_accuracy: 0.8932 - lr: 1.3422e-04
# Epoch 142/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3270 - accuracy: 0.8697
# Epoch 142: val_loss did not improve from 0.25491
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3269 - accuracy: 0.8696 - val_loss: 0.2582 - val_accuracy: 0.8941 - lr: 1.3422e-04
# Epoch 143/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8701
# Epoch 143: val_loss did not improve from 0.25491
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3205 - accuracy: 0.8701 - val_loss: 0.2550 - val_accuracy: 0.8947 - lr: 1.3422e-04
# Epoch 144/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.8671
# Epoch 144: val_loss did not improve from 0.25491
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3350 - accuracy: 0.8671 - val_loss: 0.2567 - val_accuracy: 0.8941 - lr: 1.3422e-04
# Epoch 145/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3266 - accuracy: 0.8693
# Epoch 145: val_loss improved from 0.25491 to 0.25451, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3269 - accuracy: 0.8693 - val_loss: 0.2545 - val_accuracy: 0.8956 - lr: 1.3422e-04
# Epoch 146/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.8665
# Epoch 146: val_loss did not improve from 0.25451
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3234 - accuracy: 0.8665 - val_loss: 0.2589 - val_accuracy: 0.8936 - lr: 1.3422e-04
# Epoch 147/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8688
# Epoch 147: val_loss did not improve from 0.25451
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3274 - accuracy: 0.8688 - val_loss: 0.2549 - val_accuracy: 0.8967 - lr: 1.3422e-04
# Epoch 148/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.8719
# Epoch 148: val_loss improved from 0.25451 to 0.25324, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3226 - accuracy: 0.8719 - val_loss: 0.2532 - val_accuracy: 0.8973 - lr: 1.3422e-04
# Epoch 149/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.8676
# Epoch 149: val_loss did not improve from 0.25324
# 573/573 [==============================] - 21s 36ms/step - loss: 0.3313 - accuracy: 0.8676 - val_loss: 0.2575 - val_accuracy: 0.8934 - lr: 1.3422e-04
# Epoch 150/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3283 - accuracy: 0.8676
# Epoch 150: val_loss did not improve from 0.25324
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3284 - accuracy: 0.8675 - val_loss: 0.2545 - val_accuracy: 0.8956 - lr: 1.3422e-04
# Epoch 151/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3315 - accuracy: 0.8674
# Epoch 151: val_loss did not improve from 0.25324
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3314 - accuracy: 0.8674 - val_loss: 0.2535 - val_accuracy: 0.8954 - lr: 1.3422e-04
# Epoch 152/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.8699
# Epoch 152: val_loss did not improve from 0.25324
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3236 - accuracy: 0.8699 - val_loss: 0.2579 - val_accuracy: 0.8947 - lr: 1.3422e-04
# Epoch 153/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3271 - accuracy: 0.8694
# Epoch 153: val_loss did not improve from 0.25324
#
# Epoch 153: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3269 - accuracy: 0.8694 - val_loss: 0.2540 - val_accuracy: 0.8962 - lr: 1.3422e-04
# Epoch 154/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8724
# Epoch 154: val_loss did not improve from 0.25324
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3155 - accuracy: 0.8724 - val_loss: 0.2564 - val_accuracy: 0.8958 - lr: 1.0737e-04
# Epoch 155/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3206 - accuracy: 0.8685
# Epoch 155: val_loss did not improve from 0.25324
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3206 - accuracy: 0.8686 - val_loss: 0.2560 - val_accuracy: 0.8945 - lr: 1.0737e-04
# Epoch 156/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.8703
# Epoch 156: val_loss did not improve from 0.25324
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3221 - accuracy: 0.8703 - val_loss: 0.2542 - val_accuracy: 0.8986 - lr: 1.0737e-04
# Epoch 157/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8729
# Epoch 157: val_loss improved from 0.25324 to 0.25238, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3188 - accuracy: 0.8729 - val_loss: 0.2524 - val_accuracy: 0.8980 - lr: 1.0737e-04
# Epoch 158/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3189 - accuracy: 0.8718
# Epoch 158: val_loss did not improve from 0.25238
# 573/573 [==============================] - 21s 36ms/step - loss: 0.3189 - accuracy: 0.8718 - val_loss: 0.2533 - val_accuracy: 0.8949 - lr: 1.0737e-04
# Epoch 159/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.8735
# Epoch 159: val_loss improved from 0.25238 to 0.25133, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3113 - accuracy: 0.8735 - val_loss: 0.2513 - val_accuracy: 0.8960 - lr: 1.0737e-04
# Epoch 160/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3186 - accuracy: 0.8725
# Epoch 160: val_loss did not improve from 0.25133
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3184 - accuracy: 0.8726 - val_loss: 0.2521 - val_accuracy: 0.8949 - lr: 1.0737e-04
# Epoch 161/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.8731
# Epoch 161: val_loss improved from 0.25133 to 0.25085, saving model to output/eff100_best.h5
# 573/573 [==============================] - 20s 35ms/step - loss: 0.3153 - accuracy: 0.8731 - val_loss: 0.2508 - val_accuracy: 0.8965 - lr: 1.0737e-04
# Epoch 162/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3237 - accuracy: 0.8742
# Epoch 162: val_loss did not improve from 0.25085
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3237 - accuracy: 0.8742 - val_loss: 0.2509 - val_accuracy: 0.8978 - lr: 1.0737e-04
# Epoch 163/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3150 - accuracy: 0.8757
# Epoch 163: val_loss did not improve from 0.25085
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3150 - accuracy: 0.8757 - val_loss: 0.2531 - val_accuracy: 0.8954 - lr: 1.0737e-04
# Epoch 164/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3226 - accuracy: 0.8679
# Epoch 164: val_loss did not improve from 0.25085
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3224 - accuracy: 0.8681 - val_loss: 0.2525 - val_accuracy: 0.8936 - lr: 1.0737e-04
# Epoch 165/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3194 - accuracy: 0.8691
# Epoch 165: val_loss improved from 0.25085 to 0.25050, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3195 - accuracy: 0.8693 - val_loss: 0.2505 - val_accuracy: 0.8967 - lr: 1.0737e-04
# Epoch 166/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3153 - accuracy: 0.8748
# Epoch 166: val_loss did not improve from 0.25050
# 573/573 [==============================] - 20s 36ms/step - loss: 0.3155 - accuracy: 0.8748 - val_loss: 0.2556 - val_accuracy: 0.8914 - lr: 1.0737e-04
# Epoch 167/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3247 - accuracy: 0.8708
# Epoch 167: val_loss did not improve from 0.25050
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3247 - accuracy: 0.8708 - val_loss: 0.2533 - val_accuracy: 0.8967 - lr: 1.0737e-04
# Epoch 168/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8721
# Epoch 168: val_loss did not improve from 0.25050
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3198 - accuracy: 0.8721 - val_loss: 0.2518 - val_accuracy: 0.8967 - lr: 1.0737e-04
# Epoch 169/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3218 - accuracy: 0.8701
# Epoch 169: val_loss did not improve from 0.25050
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3219 - accuracy: 0.8700 - val_loss: 0.2538 - val_accuracy: 0.8958 - lr: 1.0737e-04
# Epoch 170/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3184 - accuracy: 0.8706
# Epoch 170: val_loss improved from 0.25050 to 0.25004, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3184 - accuracy: 0.8706 - val_loss: 0.2500 - val_accuracy: 0.8973 - lr: 1.0737e-04
# Epoch 171/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8704
# Epoch 171: val_loss did not improve from 0.25004
# 573/573 [==============================] - 21s 36ms/step - loss: 0.3222 - accuracy: 0.8704 - val_loss: 0.2549 - val_accuracy: 0.8908 - lr: 1.0737e-04
# Epoch 172/400
# 571/573 [============================>.] - ETA: 0s - loss: 0.3132 - accuracy: 0.8733
# Epoch 172: val_loss did not improve from 0.25004
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3133 - accuracy: 0.8734 - val_loss: 0.2541 - val_accuracy: 0.8956 - lr: 1.0737e-04
# Epoch 173/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8749
# Epoch 173: val_loss did not improve from 0.25004
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3129 - accuracy: 0.8749 - val_loss: 0.2514 - val_accuracy: 0.8938 - lr: 1.0737e-04
# Epoch 174/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3235 - accuracy: 0.8702
# Epoch 174: val_loss did not improve from 0.25004
# 573/573 [==============================] - 16s 29ms/step - loss: 0.3233 - accuracy: 0.8702 - val_loss: 0.2534 - val_accuracy: 0.8938 - lr: 1.0737e-04
# Epoch 175/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3270 - accuracy: 0.8701
# Epoch 175: val_loss did not improve from 0.25004
#
# Epoch 175: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3270 - accuracy: 0.8701 - val_loss: 0.2532 - val_accuracy: 0.8954 - lr: 1.0737e-04
# Epoch 176/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.8747
# Epoch 176: val_loss did not improve from 0.25004
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3149 - accuracy: 0.8747 - val_loss: 0.2508 - val_accuracy: 0.8991 - lr: 8.5899e-05
# Epoch 177/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.8740
# Epoch 177: val_loss did not improve from 0.25004
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3111 - accuracy: 0.8740 - val_loss: 0.2501 - val_accuracy: 0.8989 - lr: 8.5899e-05
# Epoch 178/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8680
# Epoch 178: val_loss improved from 0.25004 to 0.24866, saving model to output/eff100_best.h5
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3199 - accuracy: 0.8680 - val_loss: 0.2487 - val_accuracy: 0.8978 - lr: 8.5899e-05
# Epoch 179/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3154 - accuracy: 0.8743
# Epoch 179: val_loss did not improve from 0.24866
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3154 - accuracy: 0.8743 - val_loss: 0.2511 - val_accuracy: 0.8925 - lr: 8.5899e-05
# Epoch 180/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3135 - accuracy: 0.8735
# Epoch 180: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3134 - accuracy: 0.8736 - val_loss: 0.2518 - val_accuracy: 0.8958 - lr: 8.5899e-05
# Epoch 181/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8742
# Epoch 181: val_loss did not improve from 0.24866
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3161 - accuracy: 0.8742 - val_loss: 0.2508 - val_accuracy: 0.8965 - lr: 8.5899e-05
# Epoch 182/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8737
# Epoch 182: val_loss did not improve from 0.24866
# 573/573 [==============================] - 20s 35ms/step - loss: 0.3141 - accuracy: 0.8737 - val_loss: 0.2515 - val_accuracy: 0.8947 - lr: 8.5899e-05
# Epoch 183/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8760
# Epoch 183: val_loss did not improve from 0.24866
#
# Epoch 183: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3137 - accuracy: 0.8760 - val_loss: 0.2496 - val_accuracy: 0.8967 - lr: 8.5899e-05
# Epoch 184/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8761
# Epoch 184: val_loss did not improve from 0.24866
# 573/573 [==============================] - 16s 28ms/step - loss: 0.3125 - accuracy: 0.8761 - val_loss: 0.2503 - val_accuracy: 0.8960 - lr: 6.8719e-05
# Epoch 185/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8790
# Epoch 185: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3023 - accuracy: 0.8790 - val_loss: 0.2528 - val_accuracy: 0.8965 - lr: 6.8719e-05
# Epoch 186/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.8742
# Epoch 186: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3180 - accuracy: 0.8742 - val_loss: 0.2532 - val_accuracy: 0.8936 - lr: 6.8719e-05
# Epoch 187/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3103 - accuracy: 0.8746
# Epoch 187: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3104 - accuracy: 0.8746 - val_loss: 0.2531 - val_accuracy: 0.8969 - lr: 6.8719e-05
# Epoch 188/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3173 - accuracy: 0.8757
# Epoch 188: val_loss did not improve from 0.24866
#
# Epoch 188: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3171 - accuracy: 0.8758 - val_loss: 0.2552 - val_accuracy: 0.8962 - lr: 6.8719e-05
# Epoch 189/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.8753
# Epoch 189: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3127 - accuracy: 0.8753 - val_loss: 0.2556 - val_accuracy: 0.8952 - lr: 5.4976e-05
# Epoch 190/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3134 - accuracy: 0.8735
# Epoch 190: val_loss did not improve from 0.24866
# 573/573 [==============================] - 18s 32ms/step - loss: 0.3138 - accuracy: 0.8734 - val_loss: 0.2523 - val_accuracy: 0.8945 - lr: 5.4976e-05
# Epoch 191/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3076 - accuracy: 0.8747
# Epoch 191: val_loss did not improve from 0.24866
# 573/573 [==============================] - 18s 32ms/step - loss: 0.3076 - accuracy: 0.8747 - val_loss: 0.2534 - val_accuracy: 0.8960 - lr: 5.4976e-05
# Epoch 192/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3077 - accuracy: 0.8791
# Epoch 192: val_loss did not improve from 0.24866
# 573/573 [==============================] - 18s 32ms/step - loss: 0.3076 - accuracy: 0.8792 - val_loss: 0.2519 - val_accuracy: 0.8969 - lr: 5.4976e-05
# Epoch 193/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3115 - accuracy: 0.8762
# Epoch 193: val_loss did not improve from 0.24866
#
# Epoch 193: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3114 - accuracy: 0.8762 - val_loss: 0.2498 - val_accuracy: 0.8991 - lr: 5.4976e-05
# Epoch 194/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.8747
# Epoch 194: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3072 - accuracy: 0.8747 - val_loss: 0.2506 - val_accuracy: 0.8954 - lr: 4.3980e-05
# Epoch 195/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.8760
# Epoch 195: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3056 - accuracy: 0.8760 - val_loss: 0.2492 - val_accuracy: 0.8976 - lr: 4.3980e-05
# Epoch 196/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.8735
# Epoch 196: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3122 - accuracy: 0.8735 - val_loss: 0.2540 - val_accuracy: 0.8960 - lr: 4.3980e-05
# Epoch 197/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3030 - accuracy: 0.8768
# Epoch 197: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 29ms/step - loss: 0.3030 - accuracy: 0.8768 - val_loss: 0.2507 - val_accuracy: 0.8965 - lr: 4.3980e-05
# Epoch 198/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3112 - accuracy: 0.8737
# Epoch 198: val_loss did not improve from 0.24866
#
# Epoch 198: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3112 - accuracy: 0.8738 - val_loss: 0.2503 - val_accuracy: 0.8956 - lr: 4.3980e-05
# Epoch 199/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.8769
# Epoch 199: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3037 - accuracy: 0.8769 - val_loss: 0.2508 - val_accuracy: 0.8960 - lr: 3.5184e-05
# Epoch 200/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.8788
# Epoch 200: val_loss did not improve from 0.24866
# 573/573 [==============================] - 17s 30ms/step - loss: 0.3006 - accuracy: 0.8788 - val_loss: 0.2504 - val_accuracy: 0.8965 - lr: 3.5184e-05
# Epoch 201/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3112 - accuracy: 0.8746
# Epoch 201: val_loss did not improve from 0.24866
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3110 - accuracy: 0.8747 - val_loss: 0.2509 - val_accuracy: 0.8971 - lr: 3.5184e-05
# Epoch 202/400
# 572/573 [============================>.] - ETA: 0s - loss: 0.3067 - accuracy: 0.8764
# Epoch 202: val_loss did not improve from 0.24866
# 573/573 [==============================] - 18s 31ms/step - loss: 0.3067 - accuracy: 0.8764 - val_loss: 0.2523 - val_accuracy: 0.8952 - lr: 3.5184e-05
# Epoch 203/400
# 573/573 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8746Restoring model weights from the end of the best epoch: 178.
#
# Epoch 203: val_loss did not improve from 0.24866
#
# Epoch 203: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# 573/573 [==============================] - 22s 38ms/step - loss: 0.3034 - accuracy: 0.8746 - val_loss: 0.2533 - val_accuracy: 0.8976 - lr: 3.5184e-05
# Epoch 203: early stopping

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
model = keras.models.load_model(model_filename + '_best.h5')
false_predicted_files = predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data, 
                                            max_delta=0.)
fpf = pd.DataFrame(false_predicted_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeterdigits --labelfile=output/dig-s1-md_false_predicted.csv
fpf.to_csv(model_filename + '_false_predicted.csv')
# Out:
# 516/516 [==============================] - 4s 8ms/step
# Tested images: 16500. 1897 false predicted. Accuracy is: 0.8850303030303031

# %% [markdown]
# ### 2nd train
#
# Now the model will be trained like transfer learning <https://keras.io/guides/transfer_learning/>.
#
# All layers except the top layer will be fixed and not trained in the 2nd training.
#
# As dataset the digit meter images are used.

# %%
import numpy as np

model = keras.models.load_model(model_filename + '_best.h5')

# now whith meter digits
train_iterator = augmentation(xz_train, yz_train)
validation_iterator = no_augmentation(xz_test, yz_test)

# train data
print("Train data")
plot_dataset_it(train_iterator)     

# validation data
print("Validation data")
plot_dataset_it(validation_iterator) 

# only the last layer is now trainable
for layer in model.layers[:-1]:
    layer.trainable=False

mc = ModelCheckpoint(model_filename + '_best_transfer.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, initial_value_threshold=.9)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer="adam", metrics = ["accuracy"])

history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = 20,
                callbacks=[earlystop, mc, reduce_lr],
                verbose=2)


model.save(model_filename + "_best_transfer.h5")

plot_acc_loss(history, "Trainingsresults")
# Out:
# Train data
# Validation data
# Epoch 1/20
#
# Epoch 1: val_loss improved from 0.90000 to 0.45632, saving model to output/eff100_best_transfer.h5
# 413/413 - 8s - loss: 0.5096 - accuracy: 0.7933 - val_loss: 0.4563 - val_accuracy: 0.8218 - lr: 0.0010 - 8s/epoch - 19ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.45632 to 0.44669, saving model to output/eff100_best_transfer.h5
# 413/413 - 11s - loss: 0.4956 - accuracy: 0.8019 - val_loss: 0.4467 - val_accuracy: 0.8261 - lr: 0.0010 - 11s/epoch - 26ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.44669
# 413/413 - 7s - loss: 0.5081 - accuracy: 0.7992 - val_loss: 0.4481 - val_accuracy: 0.8270 - lr: 0.0010 - 7s/epoch - 18ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.44669
# 413/413 - 7s - loss: 0.5031 - accuracy: 0.7971 - val_loss: 0.4506 - val_accuracy: 0.8224 - lr: 0.0010 - 7s/epoch - 16ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.44669
# 413/413 - 7s - loss: 0.5033 - accuracy: 0.7955 - val_loss: 0.4494 - val_accuracy: 0.8248 - lr: 0.0010 - 7s/epoch - 17ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.44669 to 0.44489, saving model to output/eff100_best_transfer.h5
# 413/413 - 7s - loss: 0.4893 - accuracy: 0.8002 - val_loss: 0.4449 - val_accuracy: 0.8285 - lr: 0.0010 - 7s/epoch - 16ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.44489 to 0.44277, saving model to output/eff100_best_transfer.h5
# 413/413 - 10s - loss: 0.5093 - accuracy: 0.7905 - val_loss: 0.4428 - val_accuracy: 0.8264 - lr: 0.0010 - 10s/epoch - 25ms/step
# Epoch 8/20
#
# Epoch 8: val_loss did not improve from 0.44277
# 413/413 - 7s - loss: 0.5054 - accuracy: 0.7896 - val_loss: 0.4506 - val_accuracy: 0.8242 - lr: 0.0010 - 7s/epoch - 18ms/step
# Epoch 9/20
#
# Epoch 9: val_loss did not improve from 0.44277
# 413/413 - 7s - loss: 0.5072 - accuracy: 0.7948 - val_loss: 0.4454 - val_accuracy: 0.8261 - lr: 0.0010 - 7s/epoch - 16ms/step
# Epoch 10/20
#
# Epoch 10: val_loss did not improve from 0.44277
# 413/413 - 7s - loss: 0.5013 - accuracy: 0.7996 - val_loss: 0.4458 - val_accuracy: 0.8261 - lr: 0.0010 - 7s/epoch - 16ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.44277
# 413/413 - 7s - loss: 0.5015 - accuracy: 0.7947 - val_loss: 0.4458 - val_accuracy: 0.8264 - lr: 0.0010 - 7s/epoch - 16ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.44277
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 413/413 - 7s - loss: 0.5017 - accuracy: 0.7940 - val_loss: 0.4469 - val_accuracy: 0.8239 - lr: 0.0010 - 7s/epoch - 18ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.44277
# 413/413 - 7s - loss: 0.5035 - accuracy: 0.8008 - val_loss: 0.4484 - val_accuracy: 0.8239 - lr: 8.0000e-04 - 7s/epoch - 16ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.44277
# 413/413 - 7s - loss: 0.4957 - accuracy: 0.7943 - val_loss: 0.4446 - val_accuracy: 0.8233 - lr: 8.0000e-04 - 7s/epoch - 16ms/step
# Epoch 15/20
#
# Epoch 15: val_loss improved from 0.44277 to 0.43924, saving model to output/eff100_best_transfer.h5
# 413/413 - 7s - loss: 0.5060 - accuracy: 0.7982 - val_loss: 0.4392 - val_accuracy: 0.8312 - lr: 8.0000e-04 - 7s/epoch - 16ms/step
# Epoch 16/20
#
# Epoch 16: val_loss improved from 0.43924 to 0.43689, saving model to output/eff100_best_transfer.h5
# 413/413 - 10s - loss: 0.4997 - accuracy: 0.7998 - val_loss: 0.4369 - val_accuracy: 0.8291 - lr: 8.0000e-04 - 10s/epoch - 25ms/step
# Epoch 17/20
#
# Epoch 17: val_loss did not improve from 0.43689
# 413/413 - 7s - loss: 0.4983 - accuracy: 0.8016 - val_loss: 0.4403 - val_accuracy: 0.8233 - lr: 8.0000e-04 - 7s/epoch - 17ms/step
# Epoch 18/20
#
# Epoch 18: val_loss did not improve from 0.43689
# 413/413 - 7s - loss: 0.4883 - accuracy: 0.8032 - val_loss: 0.4412 - val_accuracy: 0.8248 - lr: 8.0000e-04 - 7s/epoch - 16ms/step
# Epoch 19/20
#
# Epoch 19: val_loss did not improve from 0.43689
# 413/413 - 7s - loss: 0.4992 - accuracy: 0.7989 - val_loss: 0.4423 - val_accuracy: 0.8255 - lr: 8.0000e-04 - 7s/epoch - 16ms/step
# Epoch 20/20
#
# Epoch 20: val_loss did not improve from 0.43689
# 413/413 - 7s - loss: 0.4982 - accuracy: 0.7988 - val_loss: 0.4419 - val_accuracy: 0.8261 - lr: 8.0000e-04 - 7s/epoch - 16ms/step

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation

# %%
model = keras.models.load_model(model_filename + "_best_transfer.h5")
false_predicted_files = predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data, 
                                            max_delta=0.)
fpf = pd.DataFrame(false_predicted_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeterdigits --labelfile=output/dig-s1-md_false_predicted.csv
fpf.to_csv(model_filename + '_false_predicted.csv')
# Out:
# 516/516 [==============================] - 4s 8ms/step
# Tested images: 16500. 1900 false predicted. Accuracy is: 0.8848484848484849
